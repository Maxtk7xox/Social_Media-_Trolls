# %%
#Importing packages we want
import pandas as pd
import numpy as np
import collections
import re

# %%
#Reading data
df = pd.read_csv('twitter.csv')
# Out:
# /anaconda3/lib/python3.6/site-packages/IPython/core/interactiveshell.py:3018: DtypeWarning: Columns (1,11,16,21) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
df.head()
# Out:
#    Unnamed: 0  external_author_id  author  \
# 0           0  906000000000000000  10_GOP
# 1           1  906000000000000000  10_GOP
# 2           2  906000000000000000  10_GOP
# 3           3  906000000000000000  10_GOP
# 4           4  906000000000000000  10_GOP
#
#                                              content   region language  \
# 0  "We have a sitting Democrat US Senator on tria...  Unknown  English
# 1  Marshawn Lynch arrives to game in anti-Trump s...  Unknown  English
# 2  Daughter of fallen Navy Sailor delivers powerf...  Unknown  English
# 3  JUST IN: President Trump dedicates Presidents ...  Unknown  English
# 4  19,000 RESPECTING our National Anthem! #StandF...  Unknown  English
#
#       publish_date   harvested_date  following  followers    ...      \
# 0  10/1/2017 19:58  10/1/2017 19:59       1052       9636    ...
# 1  10/1/2017 22:43  10/1/2017 22:43       1054       9637    ...
# 2  10/1/2017 22:50  10/1/2017 22:51       1054       9637    ...
# 3  10/1/2017 23:52  10/1/2017 23:52       1062       9642    ...
# 4   10/1/2017 2:13   10/1/2017 2:13       1050       9645    ...
#
#    account_type retweet account_category  new_june_2018     alt_external_id  \
# 0         Right       0       RightTroll              0  905874659358453760
# 1         Right       0       RightTroll              0  905874659358453760
# 2         Right       1       RightTroll              0  905874659358453760
# 3         Right       0       RightTroll              0  905874659358453760
# 4         Right       1       RightTroll              0  905874659358453760
#
#              tweet_id                                        article_url  \
# 0  914580356430536707  http://twitter.com/905874659358453760/statuses...
# 1  914621840496189440  http://twitter.com/905874659358453760/statuses...
# 2  914623490375979008  http://twitter.com/905874659358453760/statuses...
# 3  914639143690555392  http://twitter.com/905874659358453760/statuses...
# 4  914312219952861184  http://twitter.com/905874659358453760/statuses...
#
#                                           tco1_step1 tco2_step1 tco3_step1
# 0  https://twitter.com/10_gop/status/914580356430...        NaN        NaN
# 1  https://twitter.com/damienwoody/status/9145685...        NaN        NaN
# 2  https://twitter.com/10_gop/status/913231923715...        NaN        NaN
# 3  https://twitter.com/10_gop/status/914639143690...        NaN        NaN
# 4  https://twitter.com/realDonaldTrump/status/914...        NaN        NaN
#
# [5 rows x 22 columns]

# %%
# Dropping some columns which may not be significant for our further analysis
df.drop(columns = ['Unnamed: 0', 'external_author_id', 'article_url', 'harvested_date', 'tweet_id'], axis = 1, inplace = True)

# %%
df.isnull().sum()
# Out:
# author                    0
# content                   1
# region                 8818
# language                  0
# publish_date              0
# following                 0
# followers                 0
# updates                   0
# post_type           1648625
# account_type              0
# retweet                   0
# account_category          0
# new_june_2018             0
# alt_external_id           0
# tco1_step1           845971
# tco2_step1          2235090
# tco3_step1          2931207
# dtype: int64

# %%
# Since there are too many null values in ['tco2_step1', 'tco3_step1'] columns, we can drop them 
df.drop(columns = ['tco2_step1', 'tco3_step1'], axis = 1, inplace = True)

# %%
# Getting the percentage of how many tweets come from the United States
print(df.region.unique())
print(len(df[df['region'] == 'United States']) / len(df))
# Out:
# ['Unknown' nan 'United States' 'Italy' 'United Arab Emirates' 'Japan'
#  'Israel' 'Azerbaijan' 'Egypt' 'United Kingdom' 'Russian Federation'
#  'Turkey' 'Iraq' 'Germany' 'France' 'Ukraine' 'Serbia' 'Hong Kong'
#  'Austria' 'Belarus' 'Malaysia' 'Spain' 'Samoa' 'India' 'Afghanistan'
#  'Saudi Arabia' 'Iran, Islamic Republic of' 'Mexico' 'Canada' 'Greece'
#  'Czech Republic' 'Finland' 'Latvia' 'Estonia' 'Sweden' 'Denmark'
#  'Switzerland']
# 0.6946928712069451

# %%
# Getting the percentage of how many tweets are English
print(df.language.unique())
print(len(df[df['language'] == 'English']) / len(df))
# Out:
# ['English' 'Russian' 'Serbian' 'Ukrainian' 'Tagalog (Filipino)' 'Albanian'
#  'Italian' 'Romanian' 'Spanish' 'Catalan' 'German' 'Estonian' 'French'
#  'Norwegian' 'Vietnamese' 'Dutch' 'Arabic' 'Uzbek' 'Bulgarian'
#  'Macedonian' 'Farsi (Persian)' 'Turkish' 'LANGUAGE UNDEFINED' 'Czech'
#  'Somali' 'Lithuanian' 'Croatian' 'Slovak' 'Icelandic' 'Slovenian'
#  'Japanese' 'Indonesian' 'Pushto' 'Hungarian' 'Finnish' 'Latvian'
#  'Portuguese' 'Danish' 'Swedish' 'Malay' 'Polish' 'Korean' 'Hebrew' 'Urdu'
#  'Kurdish' 'Hindi' 'Greek' 'Simplified Chinese' 'Thai' 'Bengali'
#  'Traditional Chinese' 'Gujarati' 'Kannada' 'Tamil' 'Telugu' 'Malayalam']
# 0.7185058619438485

# %%
df = df[df['language'] == 'English']
df = df[df['region'] == 'United States']

# %%
def get_mdy(string):
    return string.split()[0]
def get_hm(string):
    return string.split()[1]

# %%
df['pb_mdy_info'] = df.publish_date.apply(get_mdy)
df['pb_hm_info'] = df.publish_date.apply(get_hm)

# %%
def get_month(string):
    return string.split('/')[0]
def get_date(string):
    return string.split('/')[1]
def get_hour(string):
    return string.split(':')[0]

# %%
df['pb_month'] = df.pb_mdy_info.apply(get_month)
df['pb_date'] = df.pb_mdy_info.apply(get_date)
df['pb_hour'] = df.pb_hm_info.apply(get_hour)

# %%
df.head()
# Out:
#          author                                            content  \
# 424  1D_NICOLE_  #FoodPoisoning is not a joke! #Walmart #KochFa...
# 425  1D_NICOLE_  Thanks God that #turkey i ate few days ago was...
# 426  1D_NICOLE_  I hurt easy, I just don't show it. You can hur...
# 428  1D_NICOLE_  who's got the worst make up ever, don't tell m...
# 429  1D_NICOLE_     jade doesn`t love her! https://t.co/fEOsiKho7C
#
#             region language      publish_date  following  followers  updates  \
# 424  United States  English  11/26/2015 22:20         48         40      394
# 425  United States  English  11/26/2015 22:35         48         40      395
# 426  United States  English   5/25/2015 12:38         59         51      354
# 428  United States  English   5/25/2015 12:38         59         51      352
# 429  United States  English   5/25/2015 12:39         59         51      357
#
#     post_type account_type  retweet account_category  new_june_2018  \
# 424   RETWEET         Koch        1       Fearmonger              0
# 425   RETWEET         Koch        1       Fearmonger              0
# 426       NaN         Koch        0       Fearmonger              0
# 428       NaN         Koch        0       Fearmonger              0
# 429       NaN         Koch        0       Fearmonger              0
#
#     alt_external_id                                         tco1_step1  \
# 424      2535564756  https://twitter.com/Ina_Malone/status/67000248...
# 425      2535564756  https://twitter.com/Willie_BigN/status/6700043...
# 426      2535564756                                                NaN
# 428      2535564756                                                NaN
# 429      2535564756                      https://vine.co/v/OIPJQ21bwg9
#
#     pb_mdy_info pb_hm_info pb_month pb_date pb_hour
# 424  11/26/2015      22:20       11      26      22
# 425  11/26/2015      22:35       11      26      22
# 426   5/25/2015      12:38        5      25      12
# 428   5/25/2015      12:38        5      25      12
# 429   5/25/2015      12:39        5      25      12

# %%
# Getting hash tags(may have better way)

# %%
contents = df['content'].tolist()

# %%
pattern = '#\w+'

# %%
def get_hash_tags(pattern, contents):
    word_list = []
    for sentence in contents:
        if isinstance(sentence, str):
            word_list += re.findall(pattern, sentence)
    return word_list

# %%
#Test 
test = df['content'].head()
get_hash_tags(pattern, test)
# Out:
# ['#FoodPoisoning', '#Walmart', '#KochFarms', '#turkey', '#KochFarms']

# %%
hash_tags = get_hash_tags(pattern, contents)

# %%
hash_tags
# Out:
# ['#FoodPoisoning',
#  '#Walmart',
#  '#KochFarms',
#  '#turkey',
#  '#KochFarms',
#  '#JasonAldean',
#  '#hungry',
#  '#DumbGenieWishes',
#  '#DumbGenieWishes',
#  '#YoLandi',
#  '#DumbGenieWishes',
#  '#petition',
#  '#NoGunsForCriminals',
#  '#black',
#  '#NoGunsForCriminals',
#  '#Raiders',
#  '#Carr',
#  '#RaiderNation',
#  '#Raiders',
#  '#MikeAndMolly',
#  '#CaitlynJenner',
#  '#ConversationWithAlanis',
#  '#HOLYPOOPICANPUTT',
#  '#WillSmith',
#  '#DearSugarRadio',
#  '#ConversationWithAlanis',
#  '#GOPDebate',
#  '#VegasGOPDebate',
#  '#GOPDebate',
#  '#VegasGOPDebate',
#  '#VegasGOPDebate',
#  '#Cruz',
#  '#VegasGOPDebate',
#  '#Bush',
#  '#GOPDebate',
#  '#VegasGOPDebate',
#  '#VegasGOPDebate',
#  '#GOPDebate',
#  '#VegasGOPDebate',
#  '#CNNDebate',
#  '#VegasGOPDebate',
#  '#GOPDebate',
#  '#CNNDebate',
#  '#GOPDebate',
#  '#VegasGOPDebate',
#  '#GOPDebate',
#  '#VegasGOPDebate',
#  '#VegasGOPDebate',
#  '#CNNDebate',
#  '#VegasGOPDebate',
#  '#GOPDebate',
#  '#GOPDebate',
#  '#VegasGOPDebate',
#  '#CNNDebate',
#  '#GOPDebate',
#  '#VegasGOPDebate',
#  '#GOPDebate',
#  '#VegasGOPDebate',
#  '#VegasGOPDebate',
#  '#VegasGOPDebate',
#  '#VegasGOPDebate',
#  '#GOPDebate',
#  '#GOPDebate',
#  '#VegasGOPDebate',
#  '#Power100',
#  '#WCW',
#  '#wordsofwisdom',
#  '#quoteoftheday',
#  '#IslamKills',
#  '#IslamKills',
#  '#tousensemble',
#  '#prayforbrussels',
#  '#Brussels',
#  '#IslamKills',
#  '#prayforBrussels',
#  '#IslamKills',
#  '#StopIslam',
#  '#Brussels',
#  '#tcot',
#  '#IslamKills',
#  '#IslamKills',
#  '#StopIslam',
#  '#IslamKills',
#  '#Brussels',
#  '#IslamKills',
#  '#IslamKills',
#  '#PrayForBrussels',
#  '#IslamKills',
#  '#PrayForBrussels',
#  '#Brussels',
#  '#IslamKills',
#  '#refugees',
#  '#Brussels',
#  '#IslamKills',
#  '#IslamKills',
#  '#Brussels',
#  '#IslamKills',
#  '#IslamKills',
#  '#StopIslam',
#  '#IslamKills',
#  '#IslamKills',
#  '#PrayforBrussels',
#  '#Brussels',
#  '#IslamKills',
#  '#PrayForBrussels',
#  '#StopIslam',
#  '#StopIslam',
#  '#IslamKills',
#  '#PrayForBrussels',
#  '#Brussels',
#  '#IslamKills',
#  '#Brussels',
#  '#IslamKills',
#  '#blacklivesmatter',
#  '#blm',
#  '#equality',
#  '#equalrights',
#  '#blacktwitter',
#  '#RacistScum',
#  '#idiot',
#  '#BLM',
#  '#policebrutality',
#  '#blacklivesmatter',
#  '#policestate',
#  '#policebrutality',
#  '#policebrutality',
#  '#policestate',
#  '#equality',
#  '#equalrights',
#  '#BLM',
#  '#policestate',
#  '#policebrutality',
#  '#incarceration',
#  '#blacktwitter',
#  '#policestate',
#  '#policebrutality',
#  '#policestate',
#  '#black',
#  '#moron',
#  '#policestate',
#  '#stopcops',
#  '#BlackLivesMatter',
#  '#racism',
#  '#blaclivesmatter',
#  '#blacktivist',
#  '#blactwitter',
#  '#Justice',
#  '#equality',
#  '#racism',
#  '#policestate',
#  '#incarceration',
#  '#prison',
#  '#BlackLivesMatter',
#  '#black',
#  '#art',
#  '#black',
#  '#art',
#  '#blackgirlmagic',
#  '#CedrickChatman',
#  '#blacklivesmatter',
#  '#blackToLive',
#  '#OscarsStillSoWhite',
#  '#OscarsSoWhite',
#  '#CedrickChatman',
#  '#BlackLivesMatter',
#  '#policestate',
#  '#AskPOTUS',
#  '#BlackLivesMatter',
#  '#FreddieGray',
#  '#BlackLivesMatter',
#  '#GOPDebate',
#  '#blahblahblah',
#  '#BS',
#  '#policebrutality',
#  '#acab',
#  '#PoliceState',
#  '#acab',
#  '#acab',
#  '#policestate',
#  '#racism',
#  '#acab',
#  '#BlackLivesMatter',
#  '#blacklivesmatter',
#  '#equality',
#  '#GOPDebate',
#  '#BlackLivesMatter',
#  '#GOPDebate',
#  '#BLM',
#  '#acab',
#  '#ImProtestingBecause',
#  '#NoJusticeNoPeace',
#  '#BlackLivesMatters',
#  '#Blacklivesmatter',
#  '#blm',
#  '#equality',
#  '#BlackLivesMatter',
#  '#acab',
#  '#policestate',
#  '#ReclaimMLK',
#  '#SayTheirNames',
#  '#BlackLivesMatter',
#  '#ReclaimMLK',
#  '#BlackLivesMatter',
#  '#acab',
#  '#BLM',
#  '#policestate',
#  '#policebrutality',
#  '#BlackLivesMatter',
#  '#policestate',
#  '#MLKDay',
#  '#MLKDay',
#  '#BibleTrumping',
#  '#TwoCorinthians',
#  '#DemDebate',
#  '#BLM',
#  '#MichaelBrown',
#  '#BlackLivesMatter',
#  '#policestate',
#  '#policebrutality',
#  '#BlackLivesMatter',
#  '#BLM',
#  '#MLKDay',
#  '#MLKNOW',
#  '#OscarGrant',
#  '#BLM',
#  '#PoliceBrutality',
#  '#policestate',
#  '#acab',
#  '#BLM',
#  '#BlackLivesMatter',
#  '#danielholtzclaw',
#  '#BlackLivesMatter',
#  '#OscarsSoWhite',
#  '#OscarsBoycott',
#  '#OscarsSoWhite',
#  '#OscarsBoycott',
#  '#GrandJuryWatch',
#  '#AnthonyHill',
#  '#MentalIllnessIsNotACrime',
#  '#policebrutality',
#  '#acab',
#  '#AnthonyHill',
#  '#GrandJuryWatch',
#  '#AnthonyHill',
#  '#GrandJuryWatch',
#  '#AnthonyHill',
#  '#allsixcounts',
#  '#BlackLivesMatter',
#  '#policebrutality',
#  '#acab',
#  '#BlackLivesMatter',
#  '#Policestate',
#  '#selfless',
#  '#AnthonyHill',
#  '#AnthonyHill',
#  '#BlackLivesMatter',
#  '#OscarsSoWhite',
#  '#OscarsBoycott',
#  '#Black',
#  '#Friends',
#  '#FriendsReunion',
#  '#BlackLivesMatter',
#  '#equality',
#  '#discrimination',
#  '#whiteprivilege',
#  '#BlackLivesMatter',
#  '#ResignRahm',
#  '#Blacktwitter',
#  '#Roe43',
#  '#prolifemarch',
#  '#BlackLivesMatter',
#  '#BlackTwitter',
#  '#BlackLivesMatter',
#  '#Blacktwitter',
#  '#LaquanMcDonald',
#  '#KKK',
#  '#BlackLivesMatter',
#  '#slavery',
#  '#BlackLivesMatter',
#  '#BlackLivesMatter',
#  '#KKK',
#  '#BlackLivesMatter',
#  '#Justice',
#  '#FlintWaterCrisis',
#  '#BlackTwitter',
#  '#danielholtzclaw',
#  '#BlackLivesMatter',
#  '#Blacktwitter',
#  '#OscarsSoWhite',
#  '#BlackTwitter',
#  '#equality',
#  '#BlackLivesMatter',
#  '#BlackTwitter',
#  '#BlackLivesMatter',
#  '#OscarsSoWhite',
#  '#BLM',
#  '#BlackTwitter',
#  '#BlackLivesMatter',
#  '#BlackLivesMatter',
#  '#BlackTwitter',
#  '#OscarsSoWhite',
#  '#OscarsBoycott',
#  '#equality',
#  '#racism',
#  '#TamirRice',
#  '#BLM',
#  '#FlintWaterCrisis',
#  '#Flint',
#  '#Policestate',
#  '#acab',
#  '#Cops',
#  '#policestate',
#  '#BlackLivesMatter',
#  '#Blacktwitter',
#  '#TamirRice',
#  '#BlackLivesMatter',
#  '#BlackLivesMatter',
#  '#FlintWaterCrisis',
#  '#BlackLivesMatter',
#  '#PoliceState',
#  '#FlintWaterCrisis',
#  '#PoliceState',
#  '#CopsBeLike',
#  '#Policestate',
#  '#Policebrutality',
#  '#ACAB',
#  '#FlintWaterCrisis',
#  '#Flint',
#  '#cops',
#  '#ACAB',
#  '#reparations',
#  '#Blacklivesmatter',
#  '#BernieSanders',
#  '#slavery',
#  '#Blacktwitter',
#  '#OscarsSoWhite',
#  '#Oscar2016',
#  '#BlackLivesMatter',
#  '#TamirRice',
#  '#WhitePrivilege',
#  '#BlackLivesMatter',
#  '#Blacktwitter',
#  '#BlackLivesMatter',
#  '#Policebrutality',
#  '#SandraBland',
#  '#TamirRice',
#  '#LaquanMcDonald',
#  '#Black',
#  '#White',
#  '#Ferguson',
#  '#Oregon',
#  '#racism',
#  '#hypocrisy',
#  '#BlackLivesMatter',
#  '#Black',
#  '#BlackLivesMatter',
#  '#PlannedParenthood',
#  '#Black',
#  '#BlackLivesMatter',
#  '#blackbeauty',
#  '#FlintWaterCrisis',
#  '#FlintWater',
#  '#Blacklivesmatter',
#  '#protect',
#  '#serve',
#  '#AkaiGurley',
#  '#BlackLivesMatter',
#  '#Policebrutality',
#  '#BlackTwitter',
#  '#DonateWater2Flint',
#  '#FlintWaterCrisis',
#  '#BlackLivesMatter',
#  '#Blacktwitter',
#  '#BlackLivesMatter',
#  '#BlackLivesMatter',
#  '#BlackLivesMatter',
#  '#BLM',
#  '#JusticeForDontay',
#  '#DontayIvy',
#  '#QuintonioLeGrier',
#  '#cops',
#  '#BlackLivesMatter',
#  '#blizzard2016',
#  '#BlackLivesMatter',
#  '#AngelaDavis',
#  '#BlackLivesMatter',
#  '#FlintWaterCrisis',
#  '#Policestate',
#  '#KaliefBrowder',
#  '#BlackLivesMatter',
#  '#racist',
#  '#Racism',
#  '#cops',
#  '#Policebrutality',
#  '#AngelaDavis',
#  '#BlackLivesMatter',
#  '#Blacktwitter',
#  '#Racism',
#  '#BlackLivesMatter',
#  '#WakeUp',
#  '#BlackLivesMatter',
#  '#FlintWaterCrisis',
#  '#whiteprivilage',
#  '#Blacklivesmatter',
#  '#RacismMustFall',
#  '#equality',
#  '#Black',
#  '#sandrabland',
#  '#blacklivesmatter',
#  '#rip',
#  '#black',
#  '#Blackpower',
#  '#Blacklivesmatter',
#  '#BlackTwitter',
#  '#Flint',
#  '#Ferguson',
#  '#Baltimore',
#  '#Ferguson',
#  '#Blacklivesmatter',
#  '#policestate',
#  '#137shots',
#  '#PoliceBrutality',
#  '#MLKDay',
#  '#BLM',
#  '#Ferguson',
#  '#BlackLivesMatter',
#  '#Blacktwitter',
#  '#BlackLivesMatter',
#  '#Policebrutality',
#  '#Policestate',
#  '#EricGarner',
#  '#BlackLivesMatter',
#  '#FlashbackFriday',
#  '#BlackLivesMatter',
#  '#BlackLivesMatter',
#  '#FlintWaterCrisis',
#  '#BLM',
#  '#LaquanMcDonald',
#  '#BlackLivesMatter',
#  '#Blacktwitter',
#  '#BlackLivesMatter',
#  '#policestate',
#  '#policebrutality',
#  '#BlackLivesMatter',
#  '#KKK',
#  '#BlackLivesMatter',
#  '#Policebrutality',
#  '#Policestate',
#  '#racism',
#  '#Idiots',
#  '#JusticeForTamir',
#  '#OregonUnderAttack',
#  '#OregonUnderAttack',
#  '#BlackLivesMatter',
#  '#OregonUnderAttack',
#  '#OregonUnderAttack',
#  '#BlackLivesMatter',
#  '#equality',
#  '#OregonUnderAttack',
#  '#BlackLivesMatter',
#  '#TamirRice',
#  '#JusticeForTamir',
#  '#OregonUnderAttack',
#  '#BlackLivesMatter',
#  '#Policebrutality',
#  '#racism',
#  '#Black',
#  '#Black',
#  '#DoJ',
#  '#Ferguson',
#  '#BlackLivesMatter',
#  '#MichaelBrown',
#  '#MLK',
#  '#MLKDay',
#  '#BlackLivesMatter',
#  '#BlackLivesMatter',
#  '#Equality',
#  '#Policebrutality',
#  '#Policestate',
#  '#NewYorkCity',
#  '#BlackLivesMatter',
#  '#RamarleyGraham',
#  '#FlintWaterCrisis',
#  '#cops',
#  '#Holtzclaw',
#  '#rapist',
#  '#Policestate',
#  '#blacktwitter',
#  '#BlackLivesMatters',
#  '#BlackPanther',
#  '#BLM',
#  '#BLM',
#  '#BlackLivesMatters',
#  '#BlackLivesMatters',
#  '#StopKillingOurKids',
#  '#TamirRice',
#  '#BlackLivesMatter',
#  '#BlackLivesMatter',
#  '#BlackLivesMatter',
#  '#policestate',
#  '#cops',
#  '#BLM',
#  '#policestate',
#  '#policebrutality',
#  '#policestate',
#  '#policebrutality',
#  '#acab',
#  '#Police',
#  '#MentalIllness',
#  '#Blackwomen',
#  '#Sheriff',
#  '#Shot',
#  '#Cop',
#  '#Cops',
#  '#Police',
#  '#PoliceBrutality',
#  '#US',
#  '#Cops',
#  '#Police',
#  '#PoliceBrutality',
#  '#Shooting',
#  '#StayWoke',
#  '#JusticeOrElse',
#  '#cops',
#  '#PoliceBrutality',
#  '#policeabuse',
#  '#BlackLivesMatter',
#  '#Ferguson',
#  '#4mysquad',
#  '#IOIOIS',
#  '#MillionManMarch',
#  '#ClevelandDA',
#  '#TamirRice',
#  '#Cop',
#  '#iLoveMakonnen',
#  '#Geeking',
#  '#PoliceBrutality',
#  '#PoliceAbuse',
#  '#CopBlock',
#  '#JusticeOrElse',
#  '#TamirRice',
#  '#MillionManMarch',
#  '#Washington',
#  '#JusticeOrElse',
#  '#BlackLivesMatter',
#  '#StayWoke',
#  '#PoliceBrutality',
#  '#PoliceRacism',
#  '#PoliceBravery',
#  '#PoliceBrutality',
#  '#JusticeOrElse',
#  '#OpenCarry',
#  '#TamirRice',
#  '#StayWoke',
#  '#Police',
#  '#Cowards',
#  '#Psychos',
#  '#OpenCarry',
#  '#TamirRice',
#  '#StayWoke',
#  '#RacialJustice',
#  '#BernieSanders',
#  '#TX',
#  '#cop',
#  '#GyasiHughes',
#  '#TamirRice',
#  '#cop',
#  '#MillionMamMarch',
#  '#BlackLivesMatter',
#  '#BlackTwitter',
#  '#POWER',
#  '#MillionManMarch',
#  '#BlackLivesMatter',
#  '#Cute',
#  '#BlackTwitter',
#  '#Aerosmith',
#  '#DonaldTrump',
#  '#MillionManMarch',
#  '#feminist',
#  '#feminism',
#  '#MillionManMarch',
#  '#feminist',
#  '#feminism',
#  '#BlackLivesMatter',
#  '#KaldrickDonald',
#  '#blacklivesmatter',
#  '#justiceorelse',
#  '#millionmanmarch',
#  '#Police',
#  '#bodycameras',
#  '#Justice',
#  '#DarkTimes',
#  '#Cop',
#  '#Raping',
#  '#BlackTwitter',
#  '#50Cent',
#  '#Bankruptcy',
#  '#FTP',
#  '#Iaintnever',
#  '#Police',
#  '#JusticeOrElse',
#  '#MillionManMarch',
#  '#BlackLivesMatter',
#  '#BlackTwitter',
#  '#blackpeopletwitter',
#  '#policebrutality',
#  '#acab',
#  '#cops',
#  '#BlackLivesMatter',
#  '#blackpeople',
#  '#cops',
#  '#PoliceBrutality',
#  '#WhiteSupremacy',
#  '#black',
#  '#DerayMcKesson',
#  '#WhitePrivilege',
#  '#blackpower',
#  '#BlackLivesMatter',
#  '#Selma50',
#  '#RIP',
#  '#TamirRice',
#  '#PoliceBrutality',
#  '#cops',
#  '#policeViolence',
#  '#SandraBland',
#  '#Ferguson',
#  '#policeAbuse',
#  '#PoliceBrutality',
#  '#cops',
#  '#BlackLivesMatter',
#  '#BlackTwitter',
#  '#BlackLivesMatter',
#  '#blackpeopletwitter',
#  '#BlackTwitter',
#  '#BeautifullyBkack',
#  '#GrowingEconomy',
#  '#Unarmed',
#  '#Black',
#  '#cops',
#  '#FilmingArrest',
#  '#BlackLivesMatter',
#  '#JusticeOfElse',
#  '#BlackTwitter',
#  '#MillionManMarch',
#  '#JusticeOrElse',
#  '#Police',
#  '#cops',
#  '#BlackTwitter',
#  '#Cop',
#  '#cops',
#  '#acab',
#  '#police',
#  '#race',
#  '#PoliceBrutality',
#  '#Police',
#  '#California',
#  '#cops',
#  '#acab',
#  '#BLM',
#  '#cops',
#  '#PoliceBrutality',
#  '#BlackLivesMatter',
#  '#BlackTwitter',
#  '#racism',
#  '#acab',
#  '#Jailhouse',
#  '#MatthewAjibade',
#  '#cops',
#  '#acab',
#  '#PoliceBrutality',
#  '#BLM',
#  '#BlackTwitter',
#  '#Officer',
#  '#Shooting',
#  '#TamarRice',
#  '#cops',
#  '#policeBrutality',
#  '#acab',
#  '#policeViolence',
#  '#BlackTwitter',
#  '#Texas',
#  '#SandraBland',
#  '#BLM',
#  '#BlackLivesMatter',
#  '#acab',
#  '#PoliceBrutality',
#  '#BlackTwitter',
#  '#BlackPeopleRules',
#  '#cop',
#  '#badcop',
#  '#BlackLivesMatter',
#  '#racists',
#  '#racism',
#  '#BlackTwitter',
#  '#blackpeopletwitter',
#  '#cops',
#  '#blackout',
#  '#BLM',
#  '#hard',
#  '#BlackTwitter',
#  '#BlackLivesMatter',
#  '#BlackPeopleRules',
#  '#blackpeopletwitter',
#  '#PoliceBrutality',
#  '#BlackLivesMatter',
#  '#HillaryClinton',
#  '#BlackTwitter',
#  '#blackpeopletwitter',
#  '#acab',
#  '#white',
#  '#America',
#  '#Black',
#  '#blackpeopletwitter',
#  '#BlackTwitter',
#  '#BlackPower',
#  '#BlackLivesMatter',
#  '#police',
#  '#BlackLivesMatter',
#  '#BlackTwitter',
#  '#blackpeopletwitter',
#  '#BlackPower',
#  '#acab',
#  '#wherewasthethreat',
#  '#blm',
#  '#JeremyMcDole',
#  '#checkthetag',
#  '#alllivesmatter',
#  '#BlackLivesMatter',
#  '#BlackTwitter',
#  '#blackpeopletwitter',
#  '#BlackPower',
#  '#BlackLivesMatter',
#  '#blackpeopletwitter',
#  '#BlackTwitter',
#  '#acab',
#  '#PoliceBrutality',
#  '#BlackLivesMatter',
#  '#cops',
#  '#acab',
#  '#PoliceBrutality',
#  '#blackpeople',
#  '#America',
#  '#usa',
#  '#BlackLivesMatter',
#  '#blackpeopletwitter',
#  '#BlackTwitter',
#  '#BlackPower',
#  '#cops',
#  '#PoliceBrutality',
#  '#justice',
#  '#BlackLivesMatter',
#  '#BlackTwitter',
#  '#PoliceBrutality',
#  '#Black',
#  '#BlackLivesMatter',
#  '#blackpeople',
#  '#FinesAndFees',
#  '#AtlantaFX',
#  '#AvaEllis',
#  '#PoliceBrutality',
#  '#Cops',
#  '#BlackLivesMatter',
#  '#police',
#  '#MatthewAjibade',
#  '#PoliceBrutality',
#  '#Cop',
#  '#PoliceBrutality',
#  '#acab',
#  '#acab',
#  '#cops',
#  '#PoliceBrutality',
#  '#police',
#  '#PoliceBrutality',
#  '#policeViolence',
#  '#BlackLivesMatter',
#  '#BlackLivesMatter',
#  '#acab',
#  '#BlackTwitter',
#  '#PoliceBrutality',
#  '#Cop',
#  '#police',
#  '#gun',
#  '#PoliceBrutality',
#  '#acab',
#  '#BlackLivesMatter',
#  '#BlackPeopleProblems',
#  '#race',
#  '#PoliceBrutality',
#  '#cops',
#  '#policeviolence',
#  '#BlackLivesMatter',
#  '#Cops',
#  '#Police',
#  '#Abuse',
#  '#CorruptedCops',
#  '#BlackLivesMatter',
#  '#cops',
#  '#acab',
#  '#PoliceBrutality',
#  '#PoliceBrutality',
#  '#cops',
#  '#policeviolence',
#  '#Cops',
#  '#black',
#  '#Texas',
#  '#SandraBland',
#  '#PoliceBrutality',
#  '#Black',
#  '#BlackLivesMatter',
#  '#cops',
#  '#acab',
#  '#Police',
#  '#TamirRice',
#  '#JusticeOrElse',
#  '#racism',
#  '#BlackLivesMatter',
#  '#Texas',
#  '#Crime',
#  '#SandraBland',
#  '#BlackLivesMatter',
#  '#acab',
#  '#justice',
#  '#BlackLivesMatter',
#  '#acab',
#  '#racism',
#  '#BlackTwitter',
#  '#Blackpeoplebelike',
#  '#America',
#  '#BlackLivesMatter',
#  '#Blackpeoplebelike',
#  '#BlackTwitter',
#  '#acab',
#  '#BLM',
#  '#BlackBeauty',
#  '#BlackPower',
#  '#BlackWomen',
#  '#blackgirls',
#  '#BlackLivesMatter',
#  '#BlackTwitter',
#  '#Blackpeoplebelike',
#  '#blackgirls',
#  '#blackbeauty',
#  '#BlackWomenAreGorgeous',
#  '#BlackTwitter',
#  '#Blackpeoplebelike',
#  '#Drunk',
#  '#dance',
#  '#beyonce',
#  '#Blackgirls',
#  '#BlackWomenAreGorgeous',
#  '#drake',
#  '#asaprocky',
#  '#Blackpeoplebelike',
#  '#rappers',
#  '#blacktwitter',
#  '#nigga',
#  '#blackBeauty',
#  '#blackgirls',
#  '#BlackWomenAreGorgeous',
#  '#BlackLivesMatter',
#  '#BlackTwitter',
#  '#Blackpeoplebelike',
#  '#weed',
#  '#nigga',
#  '#Blackpeoplebelike',
#  '#BlackTwitter',
#  '#BlackWomen',
#  '#blackgirls',
#  '#Blackpeoplebelike',
#  '#BlackBeauty',
#  '#BlackLivesMatter',
#  '#drake',
#  '#music',
#  '#everyday',
#  '#hello',
#  '#motherfuckers',
#  '#boy',
#  '#nigga',
#  '#BlackTwitter',
#  '#Blackpeoplebelike',
#  '#blackpower',
#  '#Blackpeoplebelike',
#  '#BlackPeopleTwitter',
#  '#BlackLivesMatter',
#  '#BlackTwitter',
#  '#BlackPeopleProblems',
#  '#Blackpeoplebelike',
#  '#black',
#  '#blacktwitter',
#  '#morning',
#  '#happyday',
#  '#BlackTwitter',
#  '#Blackpeoplebelike',
#  '#Justice',
#  '#Blackpeoplebelike',
#  '#BlackTwitter',
#  '#BlackLivesMatter',
#  '#JusticeOrElse',
#  '#racism',
#  '#america',
#  '#BlackPeopleBeLike',
#  '#BlackLivesMatter',
#  '#BlackTwitter',
#  '#racism',
#  '#stopracism',
#  '#ATLANTAFX',
#  '#MaryHawkes',
#  '#Boost',
#  '#PoliceLies',
#  '#PoliceBrutality',
#  '#StayWoke',
#  '#Cops',
#  '#Shoot',
#  '#kill',
#  '#DevenGuilford',
#  '#Cop',
#  '#PoliceShooting',
#  '#BlackLivesMatter',
#  '#usa',
#  '#Police',
#  '#Philly',
#  '#police',
#  '#BLACKLIVESMATTER',
#  '#BlackLivesMatter',
#  '#Bernie2016',
#  '#BlackLivesMatter',
#  '#StayWoke',
#  '#BlackTwitter',
#  '#Bernie2016',
#  '#BlackLivesMatter',
#  '#police',
#  '#warrant',
#  '#stingray',
#  '#StayWoke',
#  '#BlackLivesMatter',
#  '#MMIW',
#  '#Indigenous',
#  '#HRV',
#  '#Truth',
#  '#BlackLivesMatter',
#  '#PoliceLies',
#  '#ZacharyHammond',
#  '#StayStrong',
#  '#BlackLivesMatter',
#  '#cops',
#  '#Colorado',
#  '#black',
#  '#BlackLivesMatter',
#  '#FeelTheBern',
#  '#CopsLie',
#  '#WhyWomenDontReport',
#  '#notokay',
#  '#BlackTwitter',
#  '#Nudes',
#  '#Bae',
#  '#BlackGirl',
#  '#Cute',
#  '#Tattoo',
#  '#StayWoke',
#  '#Racism',
#  '#blacklivesmatter',
#  '#NWA',
#  '#FuckThePolice',
#  '#ACAB',
#  '#ACAB',
#  '#FuckTheCops',
#  '#BlackLivesMatter',
#  '#Cops',
#  '#BluePrivilege',
#  '#QueenslandPolice',
#  '#WhileBlack',
#  '#DonaldTrump',
#  '#PoliceBrutality',
#  '#PoliceIncompetence',
#  '#DontCall911',
#  '#ACAB',
#  '#FuckThePolice',
#  '#GyasiHughes',
#  '#BlackLivesMatter',
#  '#The6ix',
#  '#PrayingHads',
#  '#Drake',
#  '#JustALittleStoner',
#  '#Police',
#  '#TylerDeburgo',
#  '#RhodeIsland',
#  '#NYPD',
#  '#EastHarlem',
#  '#ShootCops',
#  '#BlackLivesMatter',
#  '#BU',
#  '#BlackLivesMatter',
#  '#BlackAndProud',
#  '#MLK',
#  '#NobelPeacePrize',
#  '#FuckThaPolice',
#  '#PoliceAbuse',
#  '#BlackLivesMatter',
#  '#RemainSilent',
#  '#FuckThaPolice',
#  ...]

# %%
def count_hashtags(hash_tags):
    tag_to_num = collections.defaultdict(int)
    for hashtag in hash_tags:
        tag_to_num[hashtag] += 1 
    return tag_to_num

# %%
tag_to_num = count_hashtags(hash_tags)

# %%
tag_to_num
# Out:
# defaultdict(int,
#             {'#FoodPoisoning': 772,
#              '#Walmart': 960,
#              '#KochFarms': 3748,
#              '#turkey': 885,
#              '#JasonAldean': 40,
#              '#hungry': 10,
#              '#DumbGenieWishes': 280,
#              '#YoLandi': 1,
#              '#petition': 93,
#              '#NoGunsForCriminals': 432,
#              '#black': 237,
#              '#Raiders': 21,
#              '#Carr': 2,
#              '#RaiderNation': 32,
#              '#MikeAndMolly': 3,
#              '#CaitlynJenner': 75,
#              '#ConversationWithAlanis': 13,
#              '#HOLYPOOPICANPUTT': 2,
#              '#WillSmith': 11,
#              '#DearSugarRadio': 2,
#              '#GOPDebate': 3864,
#              '#VegasGOPDebate': 2320,
#              '#Cruz': 165,
#              '#Bush': 66,
#              '#CNNDebate': 220,
#              '#Power100': 2,
#              '#WCW': 334,
#              '#wordsofwisdom': 5,
#              '#quoteoftheday': 37,
#              '#IslamKills': 3955,
#              '#tousensemble': 8,
#              '#prayforbrussels': 347,
#              '#Brussels': 1973,
#              '#prayforBrussels': 55,
#              '#StopIslam': 1563,
#              '#tcot': 11260,
#              '#PrayForBrussels': 621,
#              '#refugees': 298,
#              '#PrayforBrussels': 116,
#              '#blacklivesmatter': 1587,
#              '#blm': 712,
#              '#equality': 55,
#              '#equalrights': 5,
#              '#blacktwitter': 1034,
#              '#RacistScum': 1,
#              '#idiot': 13,
#              '#BLM': 1478,
#              '#policebrutality': 577,
#              '#policestate': 166,
#              '#incarceration': 4,
#              '#moron': 6,
#              '#stopcops': 1,
#              '#BlackLivesMatter': 11418,
#              '#racism': 775,
#              '#blaclivesmatter': 1,
#              '#blacktivist': 5,
#              '#blactwitter': 1,
#              '#Justice': 159,
#              '#prison': 28,
#              '#art': 1555,
#              '#blackgirlmagic': 46,
#              '#CedrickChatman': 7,
#              '#blackToLive': 2,
#              '#OscarsStillSoWhite': 1,
#              '#OscarsSoWhite': 682,
#              '#AskPOTUS': 13,
#              '#FreddieGray': 521,
#              '#blahblahblah': 1,
#              '#BS': 10,
#              '#acab': 376,
#              '#PoliceState': 66,
#              '#ImProtestingBecause': 89,
#              '#NoJusticeNoPeace': 49,
#              '#BlackLivesMatters': 53,
#              '#Blacklivesmatter': 604,
#              '#ReclaimMLK': 54,
#              '#SayTheirNames': 37,
#              '#MLKDay': 171,
#              '#BibleTrumping': 1,
#              '#TwoCorinthians': 2,
#              '#DemDebate': 2837,
#              '#MichaelBrown': 97,
#              '#MLKNOW': 6,
#              '#OscarGrant': 11,
#              '#PoliceBrutality': 1646,
#              '#danielholtzclaw': 3,
#              '#OscarsBoycott': 7,
#              '#GrandJuryWatch': 3,
#              '#AnthonyHill': 13,
#              '#MentalIllnessIsNotACrime': 1,
#              '#allsixcounts': 1,
#              '#Policestate': 26,
#              '#selfless': 1,
#              '#Black': 285,
#              '#Friends': 10,
#              '#FriendsReunion': 2,
#              '#discrimination': 11,
#              '#whiteprivilege': 70,
#              '#ResignRahm': 163,
#              '#Blacktwitter': 132,
#              '#Roe43': 1,
#              '#prolifemarch': 1,
#              '#BlackTwitter': 2035,
#              '#LaquanMcDonald': 279,
#              '#KKK': 122,
#              '#slavery': 96,
#              '#FlintWaterCrisis': 369,
#              '#TamirRice': 458,
#              '#Flint': 189,
#              '#Cops': 223,
#              '#CopsBeLike': 1,
#              '#Policebrutality': 62,
#              '#ACAB': 427,
#              '#cops': 577,
#              '#reparations': 22,
#              '#BernieSanders': 332,
#              '#Oscar2016': 5,
#              '#WhitePrivilege': 131,
#              '#SandraBland': 322,
#              '#White': 21,
#              '#Ferguson': 490,
#              '#Oregon': 72,
#              '#hypocrisy': 28,
#              '#PlannedParenthood': 306,
#              '#blackbeauty': 15,
#              '#FlintWater': 9,
#              '#protect': 3,
#              '#serve': 3,
#              '#AkaiGurley': 28,
#              '#DonateWater2Flint': 1,
#              '#JusticeForDontay': 1,
#              '#DontayIvy': 1,
#              '#QuintonioLeGrier': 12,
#              '#blizzard2016': 41,
#              '#AngelaDavis': 16,
#              '#KaliefBrowder': 62,
#              '#racist': 122,
#              '#Racism': 194,
#              '#WakeUp': 75,
#              '#whiteprivilage': 2,
#              '#RacismMustFall': 35,
#              '#sandrabland': 7,
#              '#rip': 17,
#              '#Blackpower': 12,
#              '#Baltimore': 564,
#              '#137shots': 2,
#              '#EricGarner': 236,
#              '#FlashbackFriday': 317,
#              '#Idiots': 7,
#              '#JusticeForTamir': 4,
#              '#OregonUnderAttack': 169,
#              '#DoJ': 3,
#              '#MLK': 193,
#              '#Equality': 53,
#              '#NewYorkCity': 31,
#              '#RamarleyGraham': 50,
#              '#Holtzclaw': 6,
#              '#rapist': 2,
#              '#BlackPanther': 117,
#              '#StopKillingOurKids': 1,
#              '#Police': 443,
#              '#MentalIllness': 2,
#              '#Blackwomen': 4,
#              '#Sheriff': 5,
#              '#Shot': 7,
#              '#Cop': 173,
#              '#US': 2435,
#              '#Shooting': 33,
#              '#StayWoke': 1508,
#              '#JusticeOrElse': 94,
#              '#policeabuse': 66,
#              '#4mysquad': 41,
#              '#IOIOIS': 12,
#              '#MillionManMarch': 18,
#              '#ClevelandDA': 1,
#              '#iLoveMakonnen': 1,
#              '#Geeking': 1,
#              '#PoliceAbuse': 57,
#              '#CopBlock': 15,
#              '#Washington': 110,
#              '#PoliceRacism': 2,
#              '#PoliceBravery': 3,
#              '#OpenCarry': 15,
#              '#Cowards': 3,
#              '#Psychos': 1,
#              '#RacialJustice': 2,
#              '#TX': 32,
#              '#cop': 170,
#              '#GyasiHughes': 2,
#              '#MillionMamMarch': 1,
#              '#POWER': 4,
#              '#Cute': 4,
#              '#Aerosmith': 1,
#              '#DonaldTrump': 720,
#              '#feminist': 44,
#              '#feminism': 64,
#              '#KaldrickDonald': 1,
#              '#justiceorelse': 7,
#              '#millionmanmarch': 5,
#              '#bodycameras': 6,
#              '#DarkTimes': 1,
#              '#Raping': 2,
#              '#50Cent': 7,
#              '#Bankruptcy': 4,
#              '#FTP': 150,
#              '#Iaintnever': 1,
#              '#blackpeopletwitter': 152,
#              '#blackpeople': 37,
#              '#WhiteSupremacy': 49,
#              '#DerayMcKesson': 1,
#              '#blackpower': 95,
#              '#Selma50': 4,
#              '#RIP': 204,
#              '#policeViolence': 35,
#              '#policeAbuse': 22,
#              '#BeautifullyBkack': 1,
#              '#GrowingEconomy': 1,
#              '#Unarmed': 6,
#              '#FilmingArrest': 1,
#              '#JusticeOfElse': 1,
#              '#police': 476,
#              '#race': 45,
#              '#California': 252,
#              '#Jailhouse': 1,
#              '#MatthewAjibade': 4,
#              '#Officer': 21,
#              '#TamarRice': 1,
#              '#policeBrutality': 107,
#              '#Texas': 2621,
#              '#BlackPeopleRules': 30,
#              '#badcop': 4,
#              '#racists': 18,
#              '#blackout': 17,
#              '#hard': 1,
#              '#HillaryClinton': 1118,
#              '#white': 13,
#              '#America': 877,
#              '#BlackPower': 175,
#              '#wherewasthethreat': 1,
#              '#JeremyMcDole': 15,
#              '#checkthetag': 1,
#              '#alllivesmatter': 34,
#              '#usa': 228,
#              '#justice': 155,
#              '#FinesAndFees': 1,
#              '#AtlantaFX': 21,
#              '#AvaEllis': 2,
#              '#gun': 87,
#              '#BlackPeopleProblems': 16,
#              '#policeviolence': 87,
#              '#Abuse': 5,
#              '#CorruptedCops': 3,
#              '#Crime': 336,
#              '#Blackpeoplebelike': 20,
#              '#BlackBeauty': 30,
#              '#BlackWomen': 77,
#              '#blackgirls': 6,
#              '#BlackWomenAreGorgeous': 12,
#              '#Drunk': 1,
#              '#dance': 29,
#              '#beyonce': 33,
#              '#Blackgirls': 3,
#              '#drake': 7,
#              '#asaprocky': 2,
#              '#rappers': 24,
#              '#nigga': 7,
#              '#blackBeauty': 2,
#              '#weed': 16,
#              '#music': 1346,
#              '#everyday': 5,
#              '#hello': 1,
#              '#motherfuckers': 1,
#              '#boy': 3,
#              '#BlackPeopleTwitter': 14,
#              '#morning': 21,
#              '#happyday': 1,
#              '#america': 148,
#              '#BlackPeopleBeLike': 1,
#              '#stopracism': 10,
#              '#ATLANTAFX': 2,
#              '#MaryHawkes': 1,
#              '#Boost': 38,
#              '#PoliceLies': 13,
#              '#Shoot': 1,
#              '#kill': 6,
#              '#DevenGuilford': 1,
#              '#PoliceShooting': 5,
#              '#Philly': 57,
#              '#BLACKLIVESMATTER': 108,
#              '#Bernie2016': 141,
#              '#warrant': 2,
#              '#stingray': 1,
#              '#MMIW': 14,
#              '#Indigenous': 18,
#              '#HRV': 2,
#              '#Truth': 157,
#              '#ZacharyHammond': 6,
#              '#StayStrong': 29,
#              '#Colorado': 105,
#              '#FeelTheBern': 1244,
#              '#CopsLie': 5,
#              '#WhyWomenDontReport': 31,
#              '#notokay': 8,
#              '#Nudes': 1,
#              '#Bae': 3,
#              '#BlackGirl': 4,
#              '#Tattoo': 3,
#              '#NWA': 9,
#              '#FuckThePolice': 57,
#              '#FuckTheCops': 1,
#              '#BluePrivilege': 3,
#              '#QueenslandPolice': 1,
#              '#WhileBlack': 3,
#              '#PoliceIncompetence': 7,
#              '#DontCall911': 1,
#              '#The6ix': 1,
#              '#PrayingHads': 1,
#              '#Drake': 34,
#              '#JustALittleStoner': 1,
#              '#TylerDeburgo': 1,
#              '#RhodeIsland': 8,
#              '#NYPD': 237,
#              '#EastHarlem': 1,
#              '#ShootCops': 1,
#              '#BU': 4,
#              '#BlackAndProud': 4,
#              '#NobelPeacePrize': 22,
#              '#FuckThaPolice': 2,
#              '#RemainSilent': 2,
#              '#StopBlackGenocide': 1,
#              '#shooting': 135,
#              '#FuckHer': 1,
#              '#QueenSugar': 127,
#              '#NYTimes': 26,
#              '#StandForSomething': 1,
#              '#Lakisha': 3,
#              '#American': 92,
#              '#blackwomen': 33,
#              '#beautiful': 125,
#              '#beautifulblacksistas': 1,
#              '#blackporn': 1,
#              '#IfHogwartsWasAnHBCU': 1,
#              '#comingtoamerica': 3,
#              '#hogwarts': 1,
#              '#MalcolmX': 121,
#              '#truth': 224,
#              '#truthbetold': 3,
#              '#BlackUNITY': 1,
#              '#blacktumblr': 6,
#              '#Bmore': 1,
#              '#BaltimoreCity': 1,
#              '#balckLabsMatter': 1,
#              '#grandma': 1,
#              '#rihanna': 1,
#              '#billcosby': 21,
#              '#imdead': 1,
#              '#lmao': 18,
#              '#pope': 4,
#              '#Amerikkka': 14,
#              '#Stopkillingalbinos': 1,
#              '#LAPD': 46,
#              '#CrimeStats': 1,
#              '#BlackTw': 16,
#              '#blackpeopleproblems': 57,
#              '#Acab': 6,
#              '#brutally': 1,
#              '#Florida': 404,
#              '#BlackWomenMatter': 18,
#              '#nyc': 84,
#              '#BlaclPower': 5,
#              '#PoliceOfficer': 5,
#              '#RadazzHearns': 3,
#              '#force': 5,
#              '#BlackPeople': 56,
#              '#POLICE': 21,
#              '#blackpeoplebelike': 1,
#              '#NotWithHer': 18,
#              '#AmeriKKKa': 68,
#              '#nudes': 4,
#              '#bae': 9,
#              '#SendNudes': 2,
#              '#Moodboard': 1,
#              '#queen': 18,
#              '#Evidence': 3,
#              '#EndTransPhobia': 1,
#              '#TransLivesMatter': 4,
#              '#AndiePauly': 1,
#              '#ZellaZiona': 2,
#              '#KieshaJenkins': 2,
#              '#TamaraDominguez': 2,
#              '#AmberMonroe': 1,
#              '#Chicago': 3289,
#              '#AntiPolice': 5,
#              '#BlackLivesFuckingMatter': 1,
#              '#UnderwaterRacism': 1,
#              '#FuckYourBadge': 2,
#              '#Durham': 25,
#              '#StayUnited': 1,
#              '#Guns': 128,
#              '#Comics': 23,
#              '#Poster': 1,
#              '#CoreyJones': 12,
#              '#POC': 24,
#              '#BlackFamily': 33,
#              '#SanFrancisco': 260,
#              '#Nigga': 1,
#              '#FeesMustFall': 9,
#              '#PrayForJustice': 1,
#              '#realtalk': 47,
#              '#BlackTransWoman': 1,
#              '#blc': 76,
#              '#racismInAmerica': 1,
#              '#tyke': 1,
#              '#sleeponit': 1,
#              '#BlacklivesMatter': 27,
#              '#System': 1,
#              '#TheForceAwakens': 30,
#              '#BlackFolk': 1,
#              '#blackTwitter': 7,
#              '#philly': 8,
#              '#Aiyana': 2,
#              '#FootballStar': 1,
#              '#BlackPpl': 8,
#              '#Michigan': 159,
#              '#JCole': 9,
#              '#BlackProblems': 1,
#              '#October': 5,
#              '#NationalShutdown': 1,
#              '#breakfastclub': 7,
#              '#BlackDream': 1,
#              '#BlackandWhite': 4,
#              '#Brutality': 7,
#              '#AlSmithDinner': 36,
#              '#tytlive': 22,
#              '#Blacktivist': 37,
#              '#1': 904,
#              '#MSNBC': 130,
#              '#CNN': 349,
#              '#Foxnews': 119,
#              '#Demexit': 37,
#              '#JillStein': 60,
#              '#collage': 1,
#              '#portraits': 12,
#              '#NoDAPL': 1542,
#              '#HillarysEmails': 171,
#              '#MAGA': 10139,
#              '#JusticeForWilliamChapman': 2,
#              '#Facts': 42,
#              '#policeshootings': 9,
#              '#deray': 4,
#              '#deraymckesson': 3,
#              '#NatashaMcKenna': 10,
#              '#BrandonJohnson': 1,
#              '#Deray': 15,
#              '#Blackpeopleconfessions': 1,
#              '#WalterScott': 147,
#              '#jail': 17,
#              '#bastard': 1,
#              '#NYC': 1225,
#              '#sos': 1,
#              '#Oklahoma': 32,
#              '#staywoke': 1080,
#              '#San': 2,
#              '#SanDiego': 2441,
#              '#Virginia': 117,
#              '#DontShoot': 29,
#              '#BlackFam': 16,
#              '#NativeLivesMatter': 6,
#              '#NY': 965,
#              '#POLICEBRUTALITY': 6,
#              '#BLACK': 14,
#              '#criminal': 11,
#              '#YvetteSmith': 4,
#              '#Alabama': 117,
#              '#schoolchildren': 1,
#              '#JamesBaldwin': 11,
#              '#BlackLivesAreImportant': 1,
#              '#whiteness': 2,
#              '#blackandwhite': 29,
#              '#nipseyhussle': 1,
#              '#blackPeopletwitter': 1,
#              '#us': 15,
#              '#stayWoke': 24,
#              '#protests': 11,
#              '#activism': 9,
#              '#riot': 29,
#              '#TrayvonMartin': 221,
#              '#BlackLivesareimportant': 1,
#              '#blacksareimportant': 3,
#              '#woke': 11,
#              '#OneLove': 15,
#              '#NewYorkDailyNews': 1,
#              '#ShaunKing': 10,
#              '#Slavery': 50,
#              '#WakeUpCall': 2,
#              '#Lies': 22,
#              '#politics': 39519,
#              '#Hoodie': 2,
#              '#awesome': 76,
#              '#DemBoys': 1,
#              '#FuckDaPolice': 3,
#              '#important': 7,
#              '#Detroit': 787,
#              '#MentallyDisabled': 1,
#              '#shoot': 7,
#              '#gif': 4,
#              '#DrDre': 5,
#              '#Dre': 1,
#              '#movement': 4,
#              '#cnn': 153,
#              '#WhiteOnWhite': 1,
#              '#MassShootings': 8,
#              '#BREAKING': 702,
#              '#kills': 1,
#              '#shotgun': 3,
#              '#WhitePine': 1,
#              '#Gunsense': 23,
#              '#doublestandards': 8,
#              '#Politics': 124,
#              '#SnoopDogg': 17,
#              '#Gun': 26,
#              '#KillerCops': 99,
#              '#nojustice': 7,
#              '#StephenVineyard': 1,
#              '#Poet': 1,
#              '#AjaMonet': 1,
#              '#waroncops': 3,
#              '#DLM': 1,
#              '#September': 3,
#              '#hatecops': 1,
#              '#Blackpeopleproblems': 3,
#              '#victim': 10,
#              '#blackPower': 11,
#              '#blackPride': 2,
#              '#DariusPinex': 5,
#              '#COPS': 7,
#              '#copshooting': 1,
#              '#BBC': 34,
#              '#POLICEOFFICER': 1,
#              '#blackPeopleProblems': 1,
#              '#weapons': 16,
#              '#activist': 19,
#              '#ItDoesntMatter': 10,
#              '#nobodyforapresident': 1,
#              '#BlackPeopleAreMagic': 6,
#              '#OregonShooting': 41,
#              '#NeverForget': 358,
#              '#UCCShooting': 7,
#              '#violence': 94,
#              '#MassShooting': 30,
#              '#StandUnitedAgainstTerrorism': 1,
#              '#WhiteTerrorists': 6,
#              '#shaunKing': 6,
#              '#niggaz': 5,
#              '#lol': 79,
#              '#fun': 47,
#              '#humor': 48,
#              '#Blackpeople': 16,
#              '#funny': 135,
#              '#reddit': 3,
#              '#Blc': 15,
#              '#freedom': 126,
#              '#BlackActivists': 2,
#              '#Activist': 2,
#              '#ElizabethWarren': 14,
#              '#SmartNews': 9,
#              '#BLACKTIVIST': 2,
#              '#Anonymous': 105,
#              '#STOPRACISM2015': 9,
#              '#racisminAmerica': 5,
#              '#nojusticenopeace': 8,
#              '#chrisRock': 5,
#              '#powerfulepisode': 1,
#              '#racialproblems': 1,
#              '#socialproblems': 3,
#              '#BlackPride': 64,
#              '#wisewords': 5,
#              '#officer': 19,
#              '#Ohio': 169,
#              '#JamesBlake': 8,
#              '#COP': 19,
#              '#abusing': 2,
#              '#authority': 5,
#              '#government': 44,
#              '#BlackLove': 61,
#              '#brutality': 17,
#              '#AmericanSociety': 1,
#              '#2pack': 5,
#              '#blackness': 7,
#              '#Violence': 24,
#              '#MURDERERS': 6,
#              '#Orlando': 384,
#              '#victims': 8,
#              '#KanyeWest': 41,
#              '#gay': 18,
#              '#4mySquad': 3,
#              '#ChurchOfEquality': 2,
#              '#Jokes': 8,
#              '#ayylmao': 2,
#              '#Weed': 11,
#              '#pot': 11,
#              '#HaydenLong': 1,
#              '#CriminalizingChildhood': 3,
#              '#Lying': 7,
#              '#illegal': 30,
#              '#FilmPolice': 1,
#              '#Breckinridge': 1,
#              '#ToddPate': 1,
#              '#BlackMen': 11,
#              '#BlackTransLivesMatter': 23,
#              '#guns': 310,
#              '#racistpolicies': 1,
#              '#history': 270,
#              '#FOXNews': 9,
#              '#Staywoke': 90,
#              '#murder': 25,
#              '#Taxpayer': 7,
#              '#today': 9,
#              '#WeAreBulletProof': 1,
#              '#fight': 5,
#              '#policeState': 2,
#              '#TheyDontCare': 1,
#              '#RekiaBoyd': 22,
#              '#Artists': 379,
#              '#PoliceViolence': 68,
#              '#BlackCommunity': 22,
#              '#AiyanaJones': 46,
#              '#handsupdontshoot': 7,
#              '#handsup': 5,
#              '#BackAndWhitte': 1,
#              '#BrandonTateBrown': 2,
#              '#KevinMoore': 1,
#              '#FreedieGray': 1,
#              '#arrested': 13,
#              '#Art': 84,
#              '#NotForgotten': 1,
#              '#blackCommunity': 1,
#              '#HankWillisThomas': 1,
#              '#FannieLouHamer': 19,
#              '#BlackpeopleProblems': 1,
#              '#feminists': 10,
#              '#PissForEquality': 1,
#              '#joke': 11,
#              '#ornothumor': 6,
#              '#ornotjoke': 6,
#              '#BackTwitter': 1,
#              '#raping': 6,
#              '#FloodTheStreets': 1,
#              '#Dashcam': 5,
#              '#RAPE': 2,
#              '#JailNurse': 2,
#              '#LoveStory': 2,
#              '#AllDay': 3,
#              '#Boooost': 3,
#              '#BlackLivesMatterTextbook': 1,
#              '#BlackHistory': 382,
#              '#ScareMeIn3Words': 117,
#              '#SignalBoost': 5,
#              '#FirstAmendment': 12,
#              '#1A': 319,
#              '#FilmCops': 1,
#              '#DiquanFedee': 1,
#              '#CopCaughtOnTape': 1,
#              '#unarmed': 10,
#              '#Homicides': 3,
#              '#Protester': 1,
#              '#KamalGelle': 1,
#              '#policeShootings': 8,
#              '#Policeofficers': 1,
#              '#Americans': 96,
#              '#ISIS': 2730,
#              '#Ebola': 42,
#              '#BLC': 3,
#              '#comparisson': 1,
#              '#shootings': 10,
#              '#SouthCarolina': 79,
#              '#CampaignZero': 11,
#              '#killed': 17,
#              '#gunman': 6,
#              '#NewJersey': 68,
#              '#Blackwoman': 1,
#              '#rioters': 3,
#              '#USA': 1286,
#              '#AllLivesMatter': 388,
#              '#PoliceShootings': 2,
#              '#JackNicolson': 1,
#              '#CPR': 1,
#              '#hot': 13,
#              '#AbolishPolice': 9,
#              '#policebelike': 14,
#              '#lutherking': 1,
#              '#Oregonshooting': 1,
#              '#MiztirE': 1,
#              '#criminals': 11,
#              '#americabelike': 1,
#              '#policemisconduct': 5,
#              '#EricParker': 1,
#              '#PoliceKillings': 2,
#              '#MSM': 373,
#              '#injustice': 21,
#              '#SammyYatim': 3,
#              '#Video': 493,
#              '#Livestream': 3,
#              '#30ToLife': 1,
#              '#blackFam': 1,
#              '#tellemtuesdays': 1,
#              '#Time': 8,
#              '#TimeMagazine': 5,
#              '#Rights': 9,
#              '#LawEnforcement': 17,
#              '#PoliceMisconduct': 2,
#              '#Sherriff': 1,
#              '#Murder': 28,
#              '#CAMERAS': 1,
#              '#HowardFriedman': 1,
#              '#DavidWilliams': 1,
#              '#MikeBrown': 510,
#              '#HandsUpDontShoot': 12,
#              '#allbearsmatter': 1,
#              '#Arizona': 134,
#              '#4ms': 12,
#              '#420blazeit': 4,
#              '#Woman': 8,
#              '#MothersAgainst': 1,
#              '#DrunkDriving': 1,
#              '#4MySquad': 2,
#              '#Portland': 24,
#              '#marijuana': 64,
#              '#legalization': 7,
#              '#Marksville': 2,
#              '#LA': 1042,
#              '#Austin': 61,
#              '#Prison': 6,
#              '#HoodsOff': 1,
#              '#OpKKK': 14,
#              '#4Ms': 2,
#              '#Hack': 5,
#              '#prisonerPhone': 1,
#              '#Boston': 85,
#              '#VA': 71,
#              '#Bodycamera': 2,
#              '#PalmBeach': 3,
#              '#NoumanRaja': 2,
#              '#ACLU': 22,
#              '#BodyCam': 3,
#              '#420': 40,
#              '#CrookedCops': 3,
#              '#JamarClark': 61,
#              '#bodycam': 2,
#              '#killing': 14,
#              '#dog': 74,
#              '#DriveSafe': 2,
#              '#Islamophobia': 123,
#              '#PhilandoCastile': 510,
#              '#StealingDrugs': 1,
#              '#BeatingSuspect': 1,
#              '#SexualAbuse': 2,
#              '#Rape': 19,
#              '#Miami': 3440,
#              '#MPD': 3,
#              '#StudentBlackout': 1,
#              '#TSA': 30,
#              '#TakingToyFrom5yo': 2,
#              '#NationalSecurity': 16,
#              '#Justice4Jamar': 53,
#              '#Niggas': 1,
#              '#4thPrecinctShutDown': 38,
#              '#NoJustice': 14,
#              '#Minneapolis': 79,
#              '#4thprecinctshutdown': 2,
#              '#Injustice': 16,
#              '#NoKnockRaids': 2,
#              '#JamesMeans': 27,
#              '#Aleppo': 302,
#              '#thugs': 3,
#              '#policebrutallity': 1,
#              '#Thanksgiving': 259,
#              '#EverybodyEats': 4,
#              '#WillSims': 12,
#              '#KajuanRaye': 13,
#              '#Racist': 94,
#              '#Maryland': 131,
#              '#granny': 1,
#              '#thanksgiving': 301,
#              '#ThanksgivingWithBlackFamilies': 5,
#              '#JusticeForLaquan': 4,
#              '#plannedparenthoodshooting': 2,
#              '#coloradosprings': 3,
#              '#PP': 31,
#              '#BlackFriday': 69,
#              '#BlackoutBlackFriday': 8,
#              '#plannedparenthood': 3,
#              '#NRA': 1009,
#              '#womenrights': 6,
#              '#JusticeForLaquanMcDonald': 1,
#              '#BlueLivesMatter': 613,
#              '#ColoradoSprings': 27,
#              '#GunSence': 1,
#              '#PlannedParenthoodShooting': 9,
#              '#bigotry': 5,
#              '#Terrorist': 55,
#              '#Refugees': 114,
#              '#ColoradoSpringsShooting': 11,
#              '#RobertDear': 2,
#              '#PlannedParenthoodshooting': 1,
#              '#IStandWithPP': 7,
#              '#PoliceThePolice': 15,
#              '#RelationshipGoals': 14,
#              '#propaganda': 16,
#              '#JusticeForLaquanMcdonald': 3,
#              '#StudentBlackOut': 2,
#              '#RobertHinton': 1,
#              '#justicefortamirrice': 1,
#              '#fc': 1,
#              '#YouTube': 60,
#              '#abuse': 6,
#              '#mysquad': 1,
#              '#AlonzoSmith': 8,
#              '#4MS': 3,
#              '#Tarantino': 11,
#              '#Louisiana': 78,
#              '#BodyCameras': 5,
#              '#republican': 139,
#              '#terrorist': 38,
#              '#Rancher': 1,
#              '#idaho': 97,
#              '#StLouis': 1819,
#              '#policecrimes': 2,
#              '#StopTheCops': 37,
#              '#Policecrimes': 2,
#              '#RosaParks': 24,
#              '#humanrights': 40,
#              '#Conservatives': 186,
#              '#taleof2cities': 3,
#              '#DanielHoltzclaw': 29,
#              '#Justice4Zo': 2,
#              '#DC': 178,
#              '#GilbertFlores': 1,
#              '#badcopnodonut': 1,
#              '#MathewAjibade': 1,
#              '#incompetence': 1,
#              '#FreddieGrayTrial': 3,
#              '#justice4Freddie': 1,
#              '#JusticeForFreddieG': 2,
#              '#JusticeForFreddieGray': 9,
#              '#VanDyke': 1,
#              '#justiceforjamar': 1,
#              '#justiceforlaquan': 1,
#              '#Numbers': 3,
#              '#policebrautality': 1,
#              '#Justice4Laquan': 2,
#              '#kukluxcops': 1,
#              '#SanBernadino': 139,
#              '#SanBernadinoShooting': 34,
#              '#SandyHook': 43,
#              '#FuckWhitePeople': 1,
#              '#MOASueMeToo': 2,
#              '#hero': 12,
#              '#JusticeForSandraBland': 20,
#              '#BlackXmas2': 15,
#              '#BlackChristmas': 25,
#              '#civilrights': 31,
#              '#SayHerName': 240,
#              '#JeremiahSmith': 1,
#              '#blacklivematter': 2,
#              '#BettieJones': 21,
#              '#QuintonioLegrier': 18,
#              '#murderedbypolice': 1,
#              '#Justice4Tamir': 8,
#              '#resignMcGinty': 6,
#              '#fakeprosecutor': 4,
#              '#justice4TamirRice': 1,
#              '#justice4Tamir': 3,
#              '#Justice4TamirRice': 1,
#              '#sanbernardino': 3,
#              '#copbrutality': 5,
#              '#MarioWoods': 357,
#              '#Justice4MarioWoods': 7,
#              '#NationalCookieDay': 5,
#              '#LEGO': 6,
#              '#OaklandCa': 1,
#              '#Dec05': 1,
#              '#SanBernardino': 290,
#              '#terroristattack': 2,
#              '#RickyBall': 4,
#              '#marlonhorton': 1,
#              '#Cleveland': 6668,
#              '#YouGoodMan': 26,
#              '#blackexcellence': 73,
#              '#Trump': 4528,
#              '#Hitler': 17,
#              '#TrumpIsDisqualifiedParty': 14,
#              '#BlackUnite': 26,
#              '#drugs': 39,
#              '#PhilipColeman': 3,
#              '#JusticeForZo': 1,
#              '#TrumpFacts': 10,
#              '#bigot': 2,
#              '#BlackGirlMagic': 306,
#              '#SpiderManHomecoming': 25,
#              '#Brooklyn': 73,
#              '#HarlemStickTogether': 1,
#              '#Formation': 66,
#              '#Beyonce': 151,
#              '#BlackHistoryMonth': 1275,
#              '#MarshawnMcCarrel': 7,
#              '#amerikkka': 10,
#              '#Birmingham': 23,
#              '#filmthepolice': 3,
#              '#BlackLivesmatter': 70,
#              '#formation': 34,
#              '#whitesupremacy': 32,
#              '#blackhistorymonth': 97,
#              '#Scalia': 58,
#              '#scalia': 2,
#              '#BHM': 149,
#              '#Nestlé': 1,
#              '#BlackPanthers': 39,
#              '#BoycottBeyonce': 4,
#              '#Monday': 90,
#              '#sagawards': 12,
#              '#Blackhistory': 11,
#              '#Obama': 2249,
#              '#WhiteHouse': 137,
#              '#FridayFeeling': 456,
#              '#RIPMauriceWhite': 1,
#              '#EarthWindAndFire': 1,
#              '#2NYPD': 1,
#              '#Bronx': 32,
#              '#Melrose': 1,
#              '#JusticeForMarioWoods': 195,
#              '#SB50': 231,
#              '#TheWailers': 1,
#              '#PeterTosh': 3,
#              '#BlackHistoryMouth': 1,
#              '#SuperBowl': 283,
#              '#Hillary': 1657,
#              '#ThugLife': 4,
#              '#LeprechaunPickupLines': 1,
#              '#StPatricksDay': 56,
#              '#fuckthepolice': 31,
#              '#Unequality': 1,
#              '#BlackmattersUS': 8,
#              '#NotMyHeritage': 5,
#              '#DemocracyIn5Words': 13,
#              '#Jackson': 16,
#              '#ParisAttack': 9,
#              '#BrusselAttack': 1,
#              '#PeopleOfColor': 2,
#              '#SignsYoureABernieSupporter': 13,
#              '#Civilrights': 4,
#              '#BlackOutDay': 18,
#              '#JusticeForFlint': 6,
#              '#BlackMattersUS': 144,
#              '#p2': 2560,
#              '#DylanRoof': 8,
#              '#Sandtown': 3,
#              '#JusticeForIndia': 7,
#              '#PoliticalRevolution': 15,
#              '#JusticeForIndiaCummings': 4,
#              '#LaQuan': 1,
#              '#Eurovision': 4,
#              '#Moors': 5,
#              '#AfricanPresence': 1,
#              '#lemonade': 2,
#              '#AiyanasDreams': 2,
#              '#NationalPoliceWeek': 7,
#              '#MalcolmXDay': 12,
#              '#JoshuaBeebee': 1,
#              '#KrystalLake': 1,
#              '#FarewellFreeman': 1,
#              '#Corley': 1,
#              '#HOLA': 3,
#              '#AndreGreen': 2,
#              '#HASHTAGS': 2,
#              '#ChristianTaylor': 92,
#              '#Yeezus': 3,
#              '#me': 5,
#              '#follow': 521,
#              '#likes': 4,
#              '#immablack': 1,
#              '#chill': 5,
#              '#gethigh': 2,
#              '#RollTide': 11,
#              '#tlot': 699,
#              '#tgdn': 404,
#              '#WhatHappendToSandraBland': 1,
#              '#BlackoutAmerica': 1,
#              '#copsbrutality': 4,
#              '#myniggaz': 1,
#              '#blackpride': 18,
#              '#dancing': 1,
#              '#gethight': 1,
#              '#policelivesnotmatter': 1,
#              '#miami': 13,
#              '#blackproud': 2,
#              '#WhiteLivesMatter': 40,
#              '#blackman': 9,
#              '#twitter': 42,
#              '#FollowIfYouBlack': 3,
#              ...})

# %%
len(tag_to_num)
# Out:
# 85146

# %%
df.isnull().sum()
# Out:
# author                    0
# content                   1
# region                    0
# language                  0
# publish_date              0
# following                 0
# followers                 0
# updates                   0
# post_type           1023675
# account_type              0
# retweet                   0
# account_category          0
# new_june_2018             0
# alt_external_id           0
# tco1_step1           722589
# pb_mdy_info               0
# pb_hm_info                0
# pb_month                  0
# pb_date                   0
# pb_hour                   0
# dtype: int64

# %%
df.post_type.unique()
# Out:
# array(['RETWEET', nan, 'QUOTE_TWEET'], dtype=object)

# %%
# Maybe we don't have to deal with this column yet.

# %%
df.head()
# Out:
#          author                                            content  \
# 424  1D_NICOLE_  #FoodPoisoning is not a joke! #Walmart #KochFa...
# 425  1D_NICOLE_  Thanks God that #turkey i ate few days ago was...
# 426  1D_NICOLE_  I hurt easy, I just don't show it. You can hur...
# 428  1D_NICOLE_  who's got the worst make up ever, don't tell m...
# 429  1D_NICOLE_     jade doesn`t love her! https://t.co/fEOsiKho7C
#
#             region language      publish_date  following  followers  updates  \
# 424  United States  English  11/26/2015 22:20         48         40      394
# 425  United States  English  11/26/2015 22:35         48         40      395
# 426  United States  English   5/25/2015 12:38         59         51      354
# 428  United States  English   5/25/2015 12:38         59         51      352
# 429  United States  English   5/25/2015 12:39         59         51      357
#
#     post_type account_type  retweet account_category  new_june_2018  \
# 424   RETWEET         Koch        1       Fearmonger              0
# 425   RETWEET         Koch        1       Fearmonger              0
# 426       NaN         Koch        0       Fearmonger              0
# 428       NaN         Koch        0       Fearmonger              0
# 429       NaN         Koch        0       Fearmonger              0
#
#     alt_external_id                                         tco1_step1  \
# 424      2535564756  https://twitter.com/Ina_Malone/status/67000248...
# 425      2535564756  https://twitter.com/Willie_BigN/status/6700043...
# 426      2535564756                                                NaN
# 428      2535564756                                                NaN
# 429      2535564756                      https://vine.co/v/OIPJQ21bwg9
#
#     pb_mdy_info pb_hm_info pb_month pb_date pb_hour
# 424  11/26/2015      22:20       11      26      22
# 425  11/26/2015      22:35       11      26      22
# 426   5/25/2015      12:38        5      25      12
# 428   5/25/2015      12:38        5      25      12
# 429   5/25/2015      12:39        5      25      12

# %%
# Some basic descriptive analysis

# %%
df['account_category'].value_counts().plot('bar')

# %%
df['account_type'].value_counts().plot('bar')

# %%
#See the top tag of these tweets
sorted(tag_to_num.items(), key = lambda item: item[1], reverse=True)
#We can find that there're many tags related to politics
# Out:
# [('#news', 126871),
#  ('#sports', 48042),
#  ('#politics', 39519),
#  ('#world', 27518),
#  ('#local', 24789),
#  ('#TopNews', 15135),
#  ('#health', 11479),
#  ('#BlackLivesMatter', 11418),
#  ('#tcot', 11260),
#  ('#business', 10832),
#  ('#MAGA', 10139),
#  ('#PJNET', 9337),
#  ('#tech', 8221),
#  ('#entertainment', 7511),
#  ('#Cleveland', 6668),
#  ('#crime', 6503),
#  ('#TopVideo', 6452),
#  ('#environment', 5777),
#  ('#NowPlaying', 5228),
#  ('#Trump', 4528),
#  ('#breaking', 4508),
#  ('#FAKENEWS', 4332),
#  ('#SanJose', 4150),
#  ('#2A', 4033),
#  ('#WakeUpAmerica', 4032),
#  ('#IslamKills', 3955),
#  ('#life', 3924),
#  ('#GOPDebate', 3864),
#  ('#KochFarms', 3748),
#  ('#DemnDebate', 3566),
#  ('#Miami', 3440),
#  ('#ToDoListBeforeChristmas', 3395),
#  ('#ccot', 3392),
#  ('#Chicago', 3289),
#  ('#TCOT', 3072),
#  ('#amb', 2895),
#  ('#DemDebate', 2837),
#  ('#ThingsYouCantIgnore', 2764),
#  ('#ISIS', 2730),
#  ('#Texas', 2621),
#  ('#TrumpTrain', 2586),
#  ('#p2', 2560),
#  ('#IGetDepressedWhen', 2493),
#  ('#IHatePokemonGoBecause', 2442),
#  ('#SanDiego', 2441),
#  ('#US', 2435),
#  ('#Foke', 2409),
#  ('#Breaking', 2403),
#  ('#2016In4Words', 2382),
#  ('#Trump2016', 2344),
#  ('#VegasGOPDebate', 2320),
#  ('#MustBeBanned', 2318),
#  ('#pjnet', 2291),
#  ('#Obama', 2249),
#  ('#CCOT', 2178),
#  ('#IStartCryingWhen', 2176),
#  ('#Wisconsin', 2160),
#  ('#News', 2157),
#  ('#AlternativeAcronymInterpretations', 2130),
#  ('#GiftIdeasForPoliticians', 2041),
#  ('#BlackTwitter', 2035),
#  ('#ToAvoidWorkI', 2016),
#  ('#RejectedDebateTopics', 2007),
#  ('#NeverHillary', 1981),
#  ('#Brussels', 1973),
#  ('#DontTellAnyoneBut', 1864),
#  ('#TrumpForPresident', 1828),
#  ('#StopTheGOP', 1822),
#  ('#StLouis', 1819),
#  ('#MyOlympicSportWouldBe', 1800),
#  ('#ToFeelBetterI', 1794),
#  ('#OscarHasNoColor', 1771),
#  ('#ObamasWishList', 1751),
#  ('#God', 1720),
#  ('#money', 1693),
#  ('#ChristmasAftermath', 1688),
#  ('#MakeAmericaGreatAgain', 1677),
#  ('#Hillary', 1657),
#  ('#PoliceBrutality', 1646),
#  ('#Prayers4California', 1642),
#  ('#ChildrenThinkThat', 1633),
#  ('#BetterAlternativeToDebates', 1620),
#  ('#USDA', 1597),
#  ('#blacklivesmatter', 1587),
#  ('#StopIslam', 1563),
#  ('#art', 1555),
#  ('#RT', 1550),
#  ('#NoDAPL', 1542),
#  ('#INeedALawyerBecause', 1518),
#  ('#ThingsThatShouldBeCensored', 1512),
#  ('#WhenIWasYoung', 1510),
#  ('#StayWoke', 1508),
#  ('#ObamaNextJob', 1496),
#  ('#BLM', 1478),
#  ('#CruzCrew', 1466),
#  ('#BlackSkinIsNotACrime', 1465),
#  ('#Turkey', 1463),
#  ('#MyEmmyNominationWouldBe', 1457),
#  ('#ProbableTrumpsTweets', 1452),
#  ('#SecondhandGifts', 1443),
#  ('#ThingsMoreTrustedThanHillary', 1440),
#  ('#ValentinesDayIn3Words', 1428),
#  ('#HowToLoseYourJob', 1427),
#  ('#ItsRiskyTo', 1420),
#  ('#TrumpBecause', 1416),
#  ('#RuinADinnerInOnePhrase', 1372),
#  ('#quote', 1368),
#  ('#soundcloud', 1355),
#  ('#IHaveARightToKnow', 1351),
#  ('#music', 1346),
#  ('#SurvivalGuideToThanksgiving', 1318),
#  ('#hiphop', 1310),
#  ('#ReasonsToGetDivorced', 1303),
#  ('#TrumpPence16', 1303),
#  ('#USA', 1286),
#  ('#BlackHistoryMonth', 1275),
#  ('#science', 1265),
#  ('#FeelTheBern', 1244),
#  ('#SextingWentWrongWhen', 1234),
#  ('#WorldNews', 1228),
#  ('#NYC', 1225),
#  ('#PartyWentWrongWhen', 1224),
#  ('#RedNationRising', 1195),
#  ('#IfICouldntLie', 1184),
#  ('#rap', 1181),
#  ('#POTUSLastTweet', 1178),
#  ('#IdRunForPresidentIf', 1176),
#  ('#Milwaukee', 1147),
#  ('#RAPStationRadio', 1140),
#  ('#ReasonsToProtest', 1137),
#  ('#TrumpsFavoriteHeadline', 1129),
#  ('#job', 1122),
#  ('#HillaryClinton', 1118),
#  ('#IHate____Because', 1115),
#  ('#DrainTheSwamp', 1114),
#  ('#TheFirst100DaysToDoList', 1113),
#  ('#ILoveMyFriendsBut', 1113),
#  ('#MakeMeHateYouInOnePhrase', 1108),
#  ('#jobb', 1088),
#  ('#staywoke', 1080),
#  ('#iv', 1073),
#  ('#iva', 1073),
#  ('#nowplaying', 1071),
#  ('#HowToMakeAManGay', 1067),
#  ('#USFA', 1062),
#  ('#PresentsTrumpGot', 1060),
#  ('#AmericaFirst', 1057),
#  ('#GOP', 1054),
#  ('#LA', 1042),
#  ('#FergusonRemembers', 1042),
#  ('#blacktwitter', 1034),
#  ('#Syria', 1023),
#  ('#CrookedHillary', 1020),
#  ('#RealLifeMagicSpells', 1019),
#  ('#dagr8fm', 1017),
#  ('#IfIHadABodyDouble', 1013),
#  ('#ara', 1013),
#  ('#arre', 1013),
#  ('#jan', 1010),
#  ('#NRA', 1009),
#  ('#teaparty', 1009),
#  ('#NewYork', 1005),
#  ('#IAmNotThePresidentBecause', 1004),
#  ('#ThingsEveryBoyWantsToHear', 1004),
#  ('#maga', 1000),
#  ('#IfIWereTedCruz', 997),
#  ('#AddPotInAMovie', 991),
#  ('#UniteBlue', 986),
#  ('#opiceisis', 981),
#  ('#targets', 980),
#  ('#iceisis', 976),
#  ('#MyUselessSuperpower', 974),
#  ('#POTUS', 966),
#  ('#NY', 965),
#  ('#alis', 964),
#  ('#lis', 964),
#  ('#Oscars', 961),
#  ('#Walmart', 960),
#  ('#SoundCloud', 952),
#  ('#kah', 949),
#  ('#ka', 949),
#  ('#Guns4NY', 931),
#  ('#ade', 929),
#  ('#aded', 929),
#  ('#TheResistance', 916),
#  ('#celebs', 915),
#  ('#COSProject', 910),
#  ('#1', 904),
#  ('#ArmyWomenProblems', 901),
#  ('#IfIWereYourMom', 897),
#  ('#baseball', 891),
#  ('#ctl', 887),
#  ('#turkey', 885),
#  ('#America', 877),
#  ('#HipHop', 869),
#  ('#emmss', 867),
#  ('#emms', 866),
#  ('#ThingsDoneByMistake', 856),
#  ('#BTP', 847),
#  ('#WearHoodieForTrayvon', 844),
#  ('#IWouldPreferToForget', 842),
#  ('#SometimesItsOkTo', 841),
#  ('#GrowingUpWithObama', 837),
#  ('#darccy', 836),
#  ('#darcy', 836),
#  ('#ICelebrateTrumpWith', 834),
#  ('#2017SurvivalTips', 821),
#  ('#love', 812),
#  ('#ThingsNotTaughtAtSchool', 810),
#  ('#ThingsIWontBelieve', 789),
#  ('#HillaryPickUpLines', 788),
#  ('#Detroit', 787),
#  ('#ReasonsToLeaveEU', 785),
#  ('#Benghazi', 781),
#  ('#ToSaveMoneyI', 778),
#  ('#SignsYouAreAmerican', 777),
#  ('#FakeNews', 776),
#  ('#racism', 775),
#  ('#gop', 775),
#  ('#IHateItWhen', 774),
#  ('#FoodPoisoning', 772),
#  ('#Russia', 752),
#  ('#Rap', 747),
#  ('#IHaveADreamThat', 739),
#  ('#hockey', 737),
#  ('#MyFarewellWordsWouldBe', 734),
#  ('#ItTurnedAwkwardWhen', 731),
#  ('#MakeAMovieBlack', 723),
#  ('#DonaldTrump', 720),
#  ('#blm', 712),
#  ('#TedCruz', 710),
#  ('#BREAKING', 702),
#  ('#tlot', 699),
#  ('#AlternativeOscarNominations', 697),
#  ('#FollowTheWhiteRabbit', 696),
#  ('#PodernFamily', 690),
#  ('#RejectedStatueOfLibertySigns', 684),
#  ('#OscarsSoWhite', 682),
#  ('#ABCGOPDebate', 677),
#  ('#np', 675),
#  ('#ABCNews', 673),
#  ('#HillaryForPrison2016', 669),
#  ('#ThingsNotToDoAtTheZoo', 667),
#  ('#MyMondayDemotivation', 659),
#  ('#BeingBlackIs', 652),
#  ('#ItsUnacceptableTo', 652),
#  ('#My2017Resolution', 649),
#  ('#FSIS', 647),
#  ('#DogThanking', 646),
#  ('#AllWentWrongWhen', 641),
#  ('#2016ElectionIn3Words', 636),
#  ('#RenewUS', 624),
#  ('#PrayForBrussels', 621),
#  ('#Tcot', 615),
#  ('#BlueLivesMatter', 613),
#  ('#ISISaMovie', 607),
#  ('#TRUMP', 607),
#  ('#ImWithHer', 605),
#  ('#NoCyberCensorship', 605),
#  ('#Blacklivesmatter', 604),
#  ('#TeaParty', 602),
#  ('#EasterIn4Words', 600),
#  ('#ElectionDay', 597),
#  ('#NP', 593),
#  ('#LostIn3Words', 592),
#  ('#LiberalLogic', 588),
#  ('#Election2016', 579),
#  ('#GardenCityShooting', 579),
#  ('#policebrutality', 577),
#  ('#cops', 577),
#  ('#foodpoisoning', 576),
#  ('#mondaymotivation', 570),
#  ('#OneWordOffMovieQuotes', 567),
#  ('#Baltimore', 564),
#  ('#DEMDebate', 560),
#  ('#Listen2', 558),
#  ('#VoteTrump', 548),
#  ('#HowToEscapeADate', 547),
#  ('#ThingsIWontTellMyDad', 545),
#  ('#Jesus', 544),
#  ('#BuildTheWall', 543),
#  ('#MyMondayStartsWith', 543),
#  ('#phosphorusdisaster', 543),
#  ('#ThingsThatDisturbMe', 542),
#  ('#IntelGroup', 540),
#  ('#RejectedLegoMinifigures', 540),
#  ('#BB4SP', 539),
#  ('#Clinton', 537),
#  ('#Obamacare', 537),
#  ('#BeingPatriotic', 537),
#  ('#Rt', 536),
#  ('#NeverTrump', 533),
#  ('#ImTooOldFor', 528),
#  ('#ImThankfulFor', 527),
#  ('#ThursdayThoughts', 525),
#  ('#FreddieGray', 521),
#  ('#follow', 521),
#  ('#ILove__ButIHate__', 518),
#  ('#PRO', 517),
#  ('#debatenight', 516),
#  ('#AltonSterling', 513),
#  ('#WednesdayWisdom', 512),
#  ('#ItsTimeToPanicWhen', 512),
#  ('#Coast2Coast', 511),
#  ('#MikeBrown', 510),
#  ('#PhilandoCastile', 510),
#  ('#sp', 507),
#  ('#MeanGirlsRules', 505),
#  ('#ThingsInventedWhileHigh', 504),
#  ('#IDidMyBestBut', 501),
#  ('#IslamIsTheProblem', 499),
#  ('#Islam', 497),
#  ('#Video', 493),
#  ('#Ferguson', 490),
#  ('#BlackToLive', 490),
#  ('#ILikePeopleWho', 487),
#  ('#MakeTVSexy', 486),
#  ('#Israel', 484),
#  ('#WomensMarch', 484),
#  ('#just', 484),
#  ('#TimeTravelerProblems', 483),
#  ('#MyNewYearStartedWith', 478),
#  ('#AntiPoliceBrutalityDay', 477),
#  ('#quotes', 477),
#  ('#police', 476),
#  ('#Hannity', 475),
#  ('#MuslimBan', 474),
#  ('#ThingsYouShouldntAsk', 474),
#  ('#WorldVideo', 472),
#  ('#HillarysHealth', 470),
#  ('#MakeDCListen', 470),
#  ('#FishTV', 468),
#  ('#UnitedStatesIn3Words', 466),
#  ('#CR4U', 466),
#  ('#YouAreARacistIf', 466),
#  ('#WhatIWouldTellA15YearOldMe', 465),
#  ('#Iran', 463),
#  ('#Atlanta', 462),
#  ('#WasteAMillionIn3Words', 462),
#  ('#trump', 462),
#  ('#Music', 461),
#  ('#AddAMovieRuinAMovie', 459),
#  ('#TamirRice', 458),
#  ('#ItsSoWhiteOutsideThat', 458),
#  ('#FridayFeeling', 456),
#  ('#guncontrol', 455),
#  ('#ReasonIAmNotPresident', 452),
#  ('#IfIWereACop', 450),
#  ('#SingleSurvivalTips', 447),
#  ('#Police', 443),
#  ('#Yemen', 442),
#  ('#My4WordNewYearsResolution', 442),
#  ('#adee', 442),
#  ('#HappyBirthdayHarryTruman', 442),
#  ('#ItsMuchBetterTo', 437),
#  ('#BlackPressDay', 436),
#  ('#abi', 436),
#  ('#ABISS', 436),
#  ('#NoGunsForCriminals', 432),
#  ('#NewsOneNow', 431),
#  ('#IShouldGetAMedalFor', 431),
#  ('#true', 430),
#  ('#HowToSpotASocialist', 430),
#  ('#MyBestFriendIsntAllowed', 429),
#  ('#ACAB', 427),
#  ('#Periscope', 426),
#  ('#LNYHBT', 426),
#  ('#lope', 426),
#  ('#Russian', 425),
#  ('#HillaryForPrison', 424),
#  ('#FakeTaxFacts', 423),
#  ('#IDontNeedACostumeBecause', 422),
#  ('#DemDebateMiami', 422),
#  ('#garry', 422),
#  ('#LastMinuteGifts2016', 421),
#  ('#events', 421),
#  ('#WorstPainEverIn3Words', 419),
#  ('#IfHillaryBecomesPresident', 419),
#  ('#MyDoomsdayPlans', 418),
#  ('#debate', 418),
#  ('#ameliss', 418),
#  ('#amelin', 418),
#  ('#RedneckAMovie', 417),
#  ('#SometimesTwitterMakesMe', 412),
#  ('#TrumpCampaignSlogans', 410),
#  ('#MyBestFriendsInFourWords', 407),
#  ('#aprill', 407),
#  ('#T', 406),
#  ('#WIunion', 406),
#  ('#artyoucanhear', 405),
#  ('#anderr', 405),
#  ('#Florida', 404),
#  ('#tgdn', 404),
#  ('#MakeTVShowsAustralian', 404),
#  ('#showbiz', 404),
#  ('#BanIslam', 403),
#  ('#LockHerUp', 403),
#  ('#AddASongRuinAMovie', 396),
#  ('#TheArtOfWar', 394),
#  ('#Brexit', 394),
#  ('#TheFourHorsemen', 393),
#  ('#conservative', 389),
#  ('#PoliceAMovie', 389),
#  ('#AllLivesMatter', 388),
#  ('#2a', 388),
#  ('#Chelsea', 385),
#  ('#Orlando', 384),
#  ('#PresidentTrump', 384),
#  ('#BlackHistory', 382),
#  ('#EDM', 382),
#  ('#DNC', 381),
#  ('#TheTroubleWithAddiction', 381),
#  ('#Artists', 379),
#  ('#FF', 378),
#  ('#acab', 376),
#  ('#JunkScience', 375),
#  ('#ButIWasTweetingInstead', 374),
#  ('#MSM', 373),
#  ('#AsPresidentIWill', 373),
#  ('#FlintWaterCrisis', 369),
#  ('#HurricaneMatthew', 369),
#  ('#WhatIWantForChristmasIn4Words', 368),
#  ('#VulnerabilityIn5Words', 364),
#  ('#wiunion', 360),
#  ('#IWishItWasIllegalTo', 359),
#  ('#NeverForget', 358),
#  ('#GOPStop', 358),
#  ('#MarioWoods', 357),
#  ('#ThingsPeopleOnTwitterLike', 357),
#  ('#AthleticsTVShows', 351),
#  ('#mixtape', 350),
#  ('#CNN', 349),
#  ('#SCOTUS', 349),
#  ('#QAnon', 349),
#  ('#prayforbrussels', 347),
#  ('#WhenImSotallyTober', 347),
#  ('#resist', 346),
#  ('#DefundPP', 346),
#  ('#Fail', 343),
#  ('#NewMusic', 341),
#  ('#ILikeToCollect', 339),
#  ('#RejectedChristmasDecorations', 339),
#  ('#MakeAMovieHillary', 338),
#  ('#Crime', 336),
#  ('#MakeAMovieEdible', 336),
#  ('#WhenIAmOnMyOwnI', 335),
#  ('#Democrats', 335),
#  ('#ChristmasIn3Words', 335),
#  ('#WCW', 334),
#  ('#BlackExcellence', 334),
#  ('#MondayMotivation', 333),
#  ('#SundayMorning', 333),
#  ('#BernieSanders', 332),
#  ('#SecondHandGifts', 332),
#  ('#IReallyLikeYouBut', 332),
#  ('#WhyImGangsta', 331),
#  ('#FirstLadyRuleBook', 331),
#  ('#streetart', 331),
#  ('#MyBedroomIn3Words', 329),
#  ('#IsQuiteAChallenge', 328),
#  ('#BoycottKeurig', 327),
#  ('#WhatIHateIn5Words', 326),
#  ('#SandraBland', 322),
#  ('#OtherThingsToDoIn6Seconds', 320),
#  ('#1A', 319),
#  ('#ElPaso', 319),
#  ('#HappyBirthdayGeorgeWashington', 318),
#  ('#FlashbackFriday', 317),
#  ('#DrunkBands', 317),
#  ('#FBI', 315),
#  ('#PJNet', 313),
#  ('#UnlikelyThingsHeardAtWalmart', 313),
#  ('#HowToGetMediaAttention', 313),
#  ('#OneWordOffBooks', 312),
#  ('#DealBreakerIn3Words', 312),
#  ('#BasketOfDeplorables', 311),
#  ('#debates', 311),
#  ('#TGDN', 311),
#  ('#guns', 310),
#  ('#TBT', 310),
#  ('#WeThePeople', 310),
#  ('#WithoutTheInternetI', 310),
#  ('#PlannedParenthood', 306),
#  ('#BlackGirlMagic', 306),
#  ('#ListenLIVE', 306),
#  ('#TrumpRussia', 306),
#  ('#ThanksObama', 304),
#  ('#Hillary2016', 304),
#  ('#SearchesGoogleIsAshamedOf', 303),
#  ('#auspol', 303),
#  ('#SexySports', 303),
#  ('#Aleppo', 302),
#  ('#ClimateChange', 302),
#  ('#DamnDebate', 302),
#  ('#RenameMillionWomenMarch', 302),
#  ('#climatechange', 302),
#  ('#thanksgiving', 301),
#  ('#PPCHistory', 301),
#  ('#GOPDebateSC', 301),
#  ('#ElectionFinalThoughts', 300),
#  ('#Resistance', 299),
#  ('#refugees', 298),
#  ('#TrumpenASong', 297),
#  ('#MakeMusicReligious', 297),
#  ('#WeAreAllTrayvon', 295),
#  ('#kochfarms', 293),
#  ('#ReligionOfPeace', 292),
#  ('#mustbebanned', 292),
#  ('#ICantBeUrFriendBecause', 291),
#  ('#AddABandToATVShow', 291),
#  ('#SanBernardino', 290),
#  ('#MyNewCatchPhraseIs', 290),
#  ('#WeedsIllegalBut', 290),
#  ('#RNCinCLE', 288),
#  ('#Mashup', 288),
#  ('#IKnewWeWereDoomed', 286),
#  ('#Black', 285),
#  ('#Christian', 284),
#  ('#MyCampaignSlogan', 284),
#  ('#Iraq', 284),
#  ('#SuperBowl', 283),
#  ('#iHQ', 281),
#  ('#bris', 281),
#  ('#DumbGenieWishes', 280),
#  ('#LaquanMcDonald', 279),
#  ('#StandingRock', 279),
#  ('#ThingsToKnowAboutTwitter', 278),
#  ('#Resist', 277),
#  ('#Veterans', 277),
#  ('#IAmThankfulFor', 277),
#  ('#Inauguration', 277),
#  ('#SomedayIdLikeToSee', 275),
#  ('#TrumpRally', 275),
#  ('#SongContest', 274),
#  ('#IranDeal', 274),
#  ('#AndThatsHowIWentViral', 273),
#  ('#CancelPlansIn5Words', 272),
#  ('#history', 270),
#  ('#FallDepressionReasons', 269),
#  ('#My2017BiggestHope', 269),
#  ('#imho', 268),
#  ('#Night', 268),
#  ('#patriot', 267),
#  ('#instotus', 266),
#  ('#ThingsITryToForgetButCant', 265),
#  ('#SongsHannibalWouldSing', 265),
#  ('#Repost', 265),
#  ('#new', 265),
#  ('#ThingsToDoInAWaitingRoom', 263),
#  ('#China', 263),
#  ('#nra', 263),
#  ('#Christmas', 262),
#  ('#INDIGENOUS', 262),
#  ('#MillennialSportsTeams', 262),
#  ('#birtherism', 262),
#  ('#SanFrancisco', 260),
#  ('#ArticleV', 260),
#  ('#Thanksgiving', 259),
#  ('#Fergusonremembers', 259),
#  ('#wednesdaywisdom', 259),
#  ('#fakenews', 259),
#  ('#fergusonremembers', 257),
#  ('#PushPowerHits', 256),
#  ('#PodestaEmails', 256),
#  ('#NotMyPresident', 255),
#  ('#Muslim', 255),
#  ('#NASDOTCOM', 253),
#  ('#NAS', 253),
#  ('#COMMON', 253),
#  ('#Muslims', 253),
#  ('#California', 252),
#  ('#AmericanHistoryIsBlack', 252),
#  ('#teapartynews', 251),
#  ('#SupremeSacrificeDay', 251),
#  ('#IStandWithHannity', 251),
#  ('#ObservationsAtTheMarathon', 249),
#  ('#Beats', 249),
#  ('#AMJoy', 249),
#  ('#ChelseaNYC', 249),
#  ('#IAmTechnically', 248),
#  ('#3wordsbetterthanIloveyou', 247),
#  ('#GameShowHostPickUpLines', 247),
#  ('#GunControl', 246),
#  ('#InCaseAnyoneAsks', 246),
#  ('#Charlottesville', 246),
#  ('#BuyBlack', 246),
#  ('#BlackGirlsRock', 246),
#  ('#SyrianRefugees', 246),
#  ('#rantfortoday', 246),
#  ('#draintheswamp', 245),
#  ('#patriots', 245),
#  ('#InMemoryOfMalcolmX', 244),
#  ('#DerayForMayor', 244),
#  ('#BillCosby', 244),
#  ('#TAIRP', 244),
#  ('#DogSongs', 244),
#  ('#PokemonGO', 243),
#  ('#Terrorism', 243),
#  ('#InParallelUniverse', 243),
#  ('#SayHerName', 240),
#  ('#FoxNews', 240),
#  ('#SNRTG', 240),
#  ('#InHonorOf', 239),
#  ('#demndebate', 238),
#  ('#black', 237),
#  ('#NYPD', 237),
#  ('#Mixtape', 237),
#  ('#EricGarner', 236),
#  ('#ImpeachTrump', 236),
#  ('#theteaparty', 236),
#  ('#bere', 236),
#  ('#WrongThingsToSayAtAWedding', 235),
#  ('#OhHillNo', 235),
#  ('#Memphis', 234),
#  ('#FattenAMovie', 233),
#  ('#GulfStatesTalks', 233),
#  ('#arte', 232),
#  ('#MentalIllnessIcebreakers', 232),
#  ('#SB50', 231),
#  ('#datpiff', 231),
#  ('#veterans', 231),
#  ('#StarWarsCharactersWishList', 231),
#  ('#Tucker', 230),
#  ('#HateToEatAndRun', 229),
#  ('#usa', 228),
#  ('#2', 228),
#  ('#RulesForEverydayLiving', 227),
#  ('#ImStillLookingFor', 227),
#  ('#HonorForTheBrave', 226),
#  ('#IFWT', 225),
#  ('#CongressIn5Words', 225),
#  ('#truth', 224),
#  ('#TuesdayMotivation', 224),
#  ('#ReasonMyMomIsBetter', 224),
#  ('#TrumpArmy', 224),
#  ('#Cops', 223),
#  ('#KendrickJohnson', 223),
#  ('#DEMNDEBATE', 223),
#  ('#Debate', 222),
#  ('#MyPreWorkOutRoutine', 222),
#  ('#DemExit', 222),
#  ('#TrayvonMartin', 221),
#  ('#CNNDebate', 220),
#  ('#BadSummerCampNames', 219),
#  ('#DemsInPhilly', 219),
#  ('#Sports', 219),
#  ('#FeminismIsAwful', 219),
#  ('#youtube', 217),
#  ('#ComicConIn5Words', 217),
#  ('#Paris', 217),
#  ('#trump2016', 217),
#  ('#Dobbs', 217),
#  ('#3', 216),
#  ('#Syrian', 216),
#  ('#NFL', 215),
#  ('#ImAlwaysOkWith', 215),
#  ('#gunsense', 215),
#  ('#SethRich', 215),
#  ('#2016Election', 214),
#  ('#DickFlicks', 214),
#  ('#2ndAmendmentDay', 214),
#  ('#Dallas', 213),
#  ('#ATCQ', 213),
#  ('#TweepAQuote', 213),
#  ('#1000Network', 212),
#  ('#AndThenIShouldHaveSaid', 212),
#  ('#SOT', 212),
#  ('#Debates2016', 211),
#  ('#ReasonsIAintInARelationship', 210),
#  ('#Saudi', 209),
#  ('#TeamTrump', 207),
#  ('#ClintonFoundation', 206),
#  ('#DJs', 205),
#  ('#Wikileaks', 205),
#  ('#RIP', 204),
#  ('#Philadelphia', 204),
#  ('#SuperheroPresidentialSlogans', 204),
#  ('#SuperOldHeroes', 204),
#  ('#TrumpsArmy', 204),
#  ('#NorthKorea', 203),
#  ('#Constitution', 203),
#  ('#ParisAttacks', 203),
#  ('#InternationalWomensDay', 202),
#  ('#ElectionNight', 202),
#  ('#Audio', 201),
#  ('#WhatILearnedToday', 201),
#  ('#Local', 201),
#  ('#ShouldBeAllowedAtWork', 200),
#  ('#SCPrimary', 199),
#  ('#Military', 198),
#  ('#UK', 197),
#  ('#CaliforniaMovies', 197),
#  ('#ListenLive', 197),
#  ('#IfTheMediaRiggedTheElection', 196),
#  ('#SusanRice', 196),
#  ('#RTifYouAre', 196),
#  ('#JusticeForMarioWoods', 195),
#  ('#HipsterSchoolSuppliesList', 195),
#  ('#Listen', 195),
#  ('#ChristmasAPopSong', 195),
#  ('#WIUNION', 195),
#  ('#KateSteinle', 195),
#  ('#Racism', 194),
#  ('#InsultingMovies', 194),
#  ('#TrumpPence2016', 194),
#  ('#Ukraine', 194),
#  ('#MLK', 193),
#  ('#BlackPickupLines', 193),
#  ('#VoterFraud', 193),
#  ('#fail', 192),
#  ('#SummerAMovie', 191),
#  ('#WriteAPanel', 191),
#  ('#Flint', 189),
#  ('#adsnn', 189),
#  ('#adns', 189),
#  ('#STOPIslam', 189),
#  ('#Patriots', 188),
#  ('#Friday', 187),
#  ('#MyAmazonWishList', 187),
#  ('#Conservatives', 186),
#  ('#obama', 185),
#  ('#spon', 185),
#  ('#TweetsFrom10YearsAgo', 184),
#  ('#StonedComicBooks', 184),
#  ('#Matthew', 183),
#  ('#FightFor15', 183),
#  ('#VoteTrump2016', 183),
#  ('#IfMyFriendsSawMeNow', 183),
#  ('#BadMonsterMovies', 183),
#  ('#SFPD', 182),
#  ('#Putin', 182),
#  ('#bonitaApplebum', 181),
#  ('#Germany', 181),
#  ('#refugeeswelcome', 181),
#  ('#FollowTheMoney', 181),
#  ('#LGBT', 180),
#  ('#LONDON', 180),
#  ('#5WordsForAFriend', 180),
#  ('#WeHonorOurVeteransBy', 180),
#  ('#EU', 179),
#  ('#RejectedWeekends', 179),
#  ('#islam', 179),
#  ('#UnbornLivesMatter', 179),
#  ('#DC', 178),
#  ('#HRC', 178),
#  ('#IowaCaucus', 178),
#  ('#ProLife', 177),
#  ('#PPSellsBabyParts', 177),
#  ('#BernieOrBust', 176),
#  ('#checkitout', 176),
#  ('#BlackPower', 175),
#  ('#thanks', 175),
#  ('#PizzaGate', 175),
#  ('#Vault7', 174),
#  ('#ThingsHillaryGoogles', 174),
#  ('#2ADefenders', 174),
#  ('#uniteblue', 174),
#  ('#KellyFile', 174),
#  ('#Cop', 173),
#  ('#ReasonIAmNotASuperhero', 173),
#  ('#SOULTALK', 173),
#  ('#walmart', 172),
#  ('#AltRight', 172),
#  ('#MLKDay', 171),
#  ('#HillarysEmails', 171),
#  ('#ObamaGate', 171),
#  ('#cop', 170),
#  ('#GiveMadPropsTo', 170),
#  ('#OregonUnderAttack', 169),
#  ('#Ohio', 169),
#  ('#MusingsFromBarbiesDiary', 169),
#  ('#JointAddress', 169),
#  ('#FreeBresha', 168),
#  ('#RahmEmanuelOut', 168),
#  ('#OneLetterOffSports', 168),
#  ('#AllMaleReboots', 168),
#  ('#BatonRouge', 167),
#  ('#GotFiredBecause', 167),
#  ('#policestate', 166),
#  ('#MagicButReal', 166),
#  ('#Seattle', 166),
#  ('#military', 166),
#  ('#TheFive', 166),
#  ('#Cruz', 165),
#  ('#promotion', 165),
#  ('#DNCleak', 165),
#  ('#Sessions', 165),
#  ('#TrusTED', 165),
#  ('#TerribleHashtagIdeas', 165),
#  ('#StopCommonCore', 164),
#  ('#ImAlwaysForgetting', 164),
#  ('#ResignRahm', 163),
#  ('#HighSchoolTaughtMe', 163),
#  ('#WeedTV', 163),
#  ('#GRAMMYs', 161),
#  ('#Libtards', 161),
#  ('#saturdaymorning', 160),
#  ('#TermLimits', 160),
#  ('#Berkeley', 160),
#  ('#Africa', 160),
#  ('#PatriotAct', 160),
#  ('#Justice', 159),
#  ('#Michigan', 159),
#  ('#2016in4words', 159),
#  ('#spinrilla', 159),
#  ('#MemorialDay', 159),
#  ('#WorstWayToSpendTheHolidays', 159),
#  ('#Antifa', 159),
#  ('#beats', 158),
#  ('#DumpTrump', 158),
#  ('#2017', 158),
#  ('#ff', 158),
#  ('#OscarForMuhammad', 158),
#  ('#FriendshipIn5Words', 158),
#  ('#Truth', 157),
#  ('#RAP', 157),
#  ('#4', 157),
#  ('#SummerASong', 157),
#  ('#Datpiff', 157),
#  ('#SanFranciscoshooting', 156),
#  ('#MyAchillesHeel', 156),
#  ('#IAMONFIRE', 156),
#  ('#trndnl', 156),
#  ('#ImVotingBecause', 156),
#  ('#blackhistory', 156),
#  ('#TexasJihad', 156),
#  ('#justice', 155),
#  ('#cdnpoli', 155),
#  ('#ORPUW', 155),
#  ('#TPP', 155),
#  ('#podernfamily', 155),
#  ('#ChicagoBl', 155),
#  ('#MyBestHolidayMemory', 154),
#  ('#power1044fm', 154),
#  ('#London', 154),
#  ('#France', 154),
#  ('#GayLoveMatters', 154),
#  ('#cnn', 153),
#  ('#SaudiArabia', 153),
#  ('#Twitter', 153),
#  ('#blackpeopletwitter', 152),
#  ('#BaltimoreVsRacism', 152),
#  ('#isis', 152),
#  ('#VeteransDay', 152),
#  ('#ReinInDC', 152),
#  ('#Beyonce', 151),
#  ('#IndieAdvancement', 151),
#  ('#Republicans', 151),
#  ('#trumptrain', 151),
#  ('#FTP', 150),
#  ('#notmypresident', 150),
#  ('#ImNotWithHer', 150),
#  ('#AddStarWarsImproveAMovie', 150),
#  ('#ClintonScandals', 150),
#  ('#WarningLabelsForPeople', 150),
#  ('#BHM', 149),
#  ('#Houston', 149),
#  ('#ad', 149),
#  ('#NoBanNoWall', 149),
#  ('#backk', 149),
#  ('#america', 148),
#  ('#PaidGig', 148),
#  ('#JobOpp', 148),
#  ('#MyRashDecision', 148),
#  ('#bianc', 148),
#  ('#WalterScott', 147),
#  ('#SlowJamTV', 147),
#  ('#MistakeAMovie', 146),
#  ('#WaterIsLife', 146),
#  ('#TrusTed', 146),
#  ('#SurveillanceDay', 146),
#  ('#MyBlackRoots', 146),
#  ('#DarriusStewart', 145),
#  ('#IAmOnFire', 145),
#  ('#ScientificTVShows', 145),
#  ('#BlackMattersUS', 144),
#  ('#OffendEveryoneIn4Words', 144),
#  ('#DPK', 144),
#  ('#SongMakesMeTearUp', 144),
#  ('#FukushimaAgain', 144),
#  ('#JapanAMovie', 143),
#  ('#Gospel', 143),
#  ('#lnyhbt', 143),
#  ('#muslim', 143),
#  ('#SOTU', 143),
#  ('#Congress', 142),
#  ('#Republican', 142),
#  ('#IRS', 142),
#  ('#MAGA3X', 142),
#  ('#lov', 142),
#  ('#Bernie2016', 141),
#  ('#BREAKINGNEWS', 141),
#  ('#MakeABookWarm', 141),
#  ('#StrongerTogether', 141),
#  ('#amwriting', 141),
#  ('#Facebook', 141),
#  ('#DylannRoof', 141),
#  ('#podcast', 141),
#  ('#PJnet', 140),
#  ('#Liberals', 140),
#  ('#republican', 139),
#  ('#SanBernadino', 139),
#  ('#ChristmasAHorrorMovie', 139),
#  ('#prolife', 139),
#  ('#immigration', 139),
#  ('#WikiLeaks', 139),
#  ('#SelmaToMontgomery1965', 138),
#  ('#tbt', 138),
#  ('#SochiTalks', 138),
#  ('#greta', 138),
#  ('#IfTwitterWereAMan', 138),
#  ('#WhiteHouse', 137),
#  ('#ElectionDayIn5Words', 137),
#  ('#LubbockTexas', 137),
#  ('#MakeTVShowsCanadian', 136),
#  ('#Haiti', 136),
#  ('#Oakland', 136),
#  ('#feedly', 136),
#  ('#BDS', 136),
#  ('#GoldenGlobes', 136),
#  ('#SNL', 136),
#  ('#GenderSwapAMovie', 136),
#  ('#YouHaveGotTo', 136),
#  ('#shooting', 135),
#  ('#funny', 135),
#  ('#Christians', 135),
#  ('#BLMKidnapping', 135),
#  ('#WalkingDeadTheOlympics', 135),
#  ('#ZombieHillary', 135),
#  ('#Arizona', 134),
#  ('#STAYWOKE', 134),
#  ('#UN', 134),
#  ('#secondhandgifts', 134),
#  ('#Recount2016', 134),
#  ('#TEAPARTY', 134),
#  ('#Hillary4Prison', 134),
#  ('#NSA', 134),
#  ('#NoOffenceBut', 134),
#  ('#CommunityEvent', 133),
#  ('#MGWV', 133),
#  ('#FFRNN', 133),
#  ('#SickHillary', 133),
#  ('#EverythingWentWrongWhen', 133),
#  ('#Tashify', 133),
#  ('#Blacktwitter', 132),
#  ('#BayView', 132),
#  ('#RooseveltFieldMall', 132),
#  ('#WhitePrivilege', 131),
#  ('#Maryland', 131),
#  ('#BanSharia', 131),
#  ('#NetNeutrality', 131),
#  ('#WakeupAmerica', 131),
#  ('#TheGOPHasBecome', 131),
#  ('#trump2020', 131),
#  ('#MSNBC', 130),
#  ('#howtoloseyourjob', 130),
#  ('#ObamaCare', 130),
#  ('#Outnumbered', 130),
#  ('#Maga', 130),
#  ('#WhatIBelieveIn5Words', 130),
#  ('#ObamaFarewell', 129),
#  ('#DebateNight', 129),
#  ('#5', 129),
#  ('#How2016CanRedeemItself', 129),
#  ('#NewHampshireForTrump', 129),
#  ('#realdonaldtrump', 129),
#  ('#ILikelySpendTooMuchTime', 129),
#  ('#Guns', 128),
#  ('#AddCartoonsToHistory', 128),
#  ('#ModernDeadlySins', 128),
#  ('#QueenSugar', 127),
#  ('#LibCrib', 127),
#  ('#StarWars', 127),
#  ('#LosAngeles', 127),
#  ('#probabletrumpstweets', 127),
#  ('#morningjoe', 127),
#  ('#HillarysBodyDouble', 127),
#  ('#JunkieUS', 127),
#  ('#freedom', 126),
#  ('#iTunes', 126),
#  ('#Vegas', 126),
#  ('#MySaturdayNightIn4Words', 126),
#  ('#ThisMaySoundStrangeBut', 126),
#  ('#NYCExplosion', 126),
#  ('#beautiful', 125),
#  ('#msnbc', 125),
#  ('#DescribeBabiesIn3Words', 125),
#  ('#FullRepeal', 125),
#  ('#USArmy', 125),
#  ('#Politics', 124),
#  ('#DumberBroadway', 124),
#  ('#Dems', 124),
#  ('#Soros', 124),
#  ('#SpiritCooking', 124),
#  ('#Islamophobia', 123),
#  ('#ThingsYoucantIgnore', 123),
#  ('#Bernie', 123),
#  ('#Farrakhan', 123),
#  ('#copolitics', 123),
#  ('#Afghanistan', 123),
#  ...]

# %%
#How many unique accounts
df.author.nunique()
# Out:
# 1264

# %%
#Maybe in later analysis we can filter those accounts without any followers bacuse they may not have much impact on citizens
df.groupby('author')['followers'].max().sort_values(ascending = False)
# Out:
# author
# TEN_GOP            145244
# KADIROVRUSSIA       92788
# NOVOSTISPB          82213
# JENN_ABRAMS         71022
# PAMELA_MOORE13      70734
# TODAYNYCITY         62088
# ELEVEN_GOP          59100
# CRYSTAL1JOHNSON     56725
# WOKELUISA           55467
# SOUTHLONESTAR       53782
# COLDWAR20_RU        45088
# USA_GUNSLINGER      43895
# THEFOUNDINGSON      42000
# BLACKNEWSOUTLET     40788
# KANIJJACKSON        32372
# WASHINGTONLINE      32191
# PIGEONTODAY         30486
# BLACKTOLIVE         29469
# NEWORLEANSON        28785
# MARGOSAVAZH         28054
# WARFAREWW           26740
# LUGANSKNOVOSTI      26358
# KANSASDAILYNEWS     25871
# DANAGEEZUS          24663
# ANDYHASHTAGGER      23890
# SANANTOTOPNEWS      22250
# DALLASTOPNEWS       22205
# TPARTYNEWS          22009
# CHRIXMORGAN         21760
# CHICAGODAILYNEW     21712
#                     ...
# WHATSUPPPADAMS          0
# DNT_SHOOT               0
# CDAVISA20               0
# CHAYKA_CHELSEY          0
# VESTNIKPSKOV            0
# CTHUNO                  0
# KIRILLANDY              0
# AMBBERTHTT              0
# SYLVIE1FREEMAN          0
# AHMADYUSUFF03           0
# LAMARMUTANT             0
# LAUREL_LORENS           0
# LAURENBURTONS           0
# CARREDTRT               0
# ARIELLE_BROWNIN         0
# APRIILDTRUT             0
# MAYERS_STEFANY          0
# MUPU26                  0
# AMYYTHOSSMA             0
# RAJAMANICKAMDA2         0
# RAYMAN_ANDY             0
# AMBERDAVV               0
# HARRYLEVVIS             0
# HABDARRAHMAN4           0
# GREGFRANKLIN030         0
# GREENMONIKA6            0
# FREEJEROMESMITH         0
# BLACKJACKWEINER         0
# SPARKSDANS              0
# CAMILLITIXTOPS          0
# Name: followers, Length: 1264, dtype: int64

# %%
top_following = list(df.groupby('author')['followers'].max().sort_values(ascending = False)[:100].index)

# %%
#Tweets trend in months
df.pb_month.value_counts().plot('bar')

# %%
#Tweets trend in days
# These accounts tend to tweets during the middle of months
df.pb_date.value_counts().plot('bar')

# %%
df.post_type.value_counts()
# Out:
# RETWEET        792911
# QUOTE_TWEET     27865
# Name: post_type, dtype: int64

# %%
#About half of the handles follow more than 500 accounts
df.groupby('author')['following'].max().sort_values(ascending = False).loc[lambda x: x > 500].count()
# Out:
# 535

# %% [markdown]
# ### Wordcloud

# %%
from wordcloud import WordCloud
wordcloud = WordCloud(background_color="white",width=1000, height=860, margin=2).generate(' '.join(hash_tags))

# %%
import matplotlib.pyplot as plt
plt.imshow(wordcloud)
plt.axis("off")
plt.show()

# %%
wordcloud.to_file('hash_tag_wordcloud.png')

# %% [markdown]
# #### content cloud, remove url/hashtag/@

# %%
content = list(df['content'])
content[918986] = ''

# %%
content_str = ' '.join(content)

# %%
import re
def remove_url(content):
    for i in range(len(content)):
        text = re.sub(r'https?:\/\/.*[\r\n]*', '', content[i], flags=re.MULTILINE)
        content[i] = text
    return content

# %%
def remove_hashtags(content):
    for i in range(len(content)):
        text = re.sub(r'#\w+', '', content[i], flags=re.MULTILINE)
        content[i] = text
    return content

# %%
def remove_at(content):
    for i in range(len(content)):
        text = re.sub(r'@\w+', '', content[i], flags=re.MULTILINE)
        content[i] = text
    return content

# %%
test_remove_at = ['Tell me about equality!   @deray ',
 "'@markaddisonjr @deray Is a kid at pool more dangerous than 150 armed thugs in federal building?  ",
 "'@markaddisonjr @deray is a 12 yo black kid with a toy gun more dangerous than 150 armed bigots?'",
 'Is this accurate?      ']
remove_at(test_remove_at) # test function
# Out:
# ['Tell me about equality!    ',
#  "'  Is a kid at pool more dangerous than 150 armed thugs in federal building?  ",
#  "'  is a 12 yo black kid with a toy gun more dangerous than 150 armed bigots?'",
#  'Is this accurate?      ']

# %%
remove_url(content[:3]) # test function
# Out:
# ['#FoodPoisoning is not a joke! #Walmart #KochFarms ',
#  'Thanks God that #turkey i ate few days ago was good. #KochFarms ',
#  "I hurt easy, I just don't show it. You can hurt someone and not even know it."]

# %%
remove_hashtags(content[:3]) # test function
# Out:
# [' is not a joke!   ',
#  'Thanks God that  i ate few days ago was good.  ',
#  "I hurt easy, I just don't show it. You can hurt someone and not even know it."]

# %%
content = remove_url(content)

# %%
content
# Out:
# ['#FoodPoisoning is not a joke! #Walmart #KochFarms ',
#  'Thanks God that #turkey i ate few days ago was good. #KochFarms ',
#  "I hurt easy, I just don't show it. You can hurt someone and not even know it.",
#  "who's got the worst make up ever, don't tell me, mirror",
#  'jade doesn`t love her! ',
#  'Unreal friendship may turn to real. But real friendship, once ended, cannot be mended.',
#  '« The young are permanently in a state resembling intoxication. » Aristotle',
#  'The best thing you can do in your life is to please God. The worst thing you can do in your life is to please everyone.',
#  "Honey, I'll learn! ",
#  'cats giving high fives!!!!! ',
#  'Home is where my bed is',
#  'When the beat drops just keep swinging it',
#  "She gets on you under your skin like a tattoo, she'll always be there, she holds on stuck in your head, like an old song. #JasonAldean",
#  'As usual, there is a great woman behind every idiot',
#  'Music plays a mind trick, watch me forget about missing you',
#  'do u ever look at ur friends like "im so glad these weird losers are mine"',
#  'I consider hitting a girl the most pussy thing a guy could ever possibly do',
#  'When we first met, I had no idea you’d become this important to me.',
#  'what happiness is? Free Wi-Fi!',
#  'Even if my intentions are good, the result is still awful :(',
#  'incredible!!!!! ',
#  'Booty ',
#  'girls winning',
#  'Why did we give a monopoly of creating money out of thin air to a private [Federal Reserve] corporation? – Franklin Saunders',
#  'Despite all the junk food someone still complimented me on my skin',
#  "Love like you'll never be hurt",
#  'so easy I can do them myself! ',
#  "RT if you're ripping that Hustle gang",
#  'queen and anti-queen ',
#  "When love is real, it doesn't lie, cheat, pretend, or hurt you. It cures you of all your worries and makes you truly happy.",
#  'The harder you work, the harder it is to surrender.',
#  '',
#  'you should never care what other people say about you',
#  "Unless you change how you are, you will always have what you've got.",
#  "I'm an instant star. Just add water and stir.",
#  'don`t wear it if #hungry!! ',
#  "Took 50 pictures... Don't like a single one. Even IG filters don't help me!",
#  "'@DrGregoryWest gave me shivers...'",
#  'I want my little parrot to speak at last!!! #DumbGenieWishes',
#  'An everyday changing funny church sign #DumbGenieWishes',
#  'I wish look like #YoLandi #DumbGenieWishes',
#  "Why is someone even against the #petition? I'll watch you bleeding when some thug shoots your ass off #NoGunsForCriminals",
#  'It’s reasonable to ban firearms sales in #black areas #NoGunsForCriminals ',
#  "'@HalfOnionInABag Follow the other half an onion! Mage America Great Again1'",
#  "'@HalfOnionInABag Follow another half of the onion. Reveal it's dark side!'",
#  "'@cmath_72 @HalfOnionInABag Follow the other side of the onion to Make America Great Again!'",
#  '#Raiders defense playing hungry .. Bending and not breaking �',
#  "Let's go offense !!!! Start Up the #Carr !!!! #RaiderNation ... We need to turn up the tempo �� #Raiders",
#  "I was shocked and heartbroken when @CBS canceled #MikeAndMolly. I would have shot this show for 50 more years. I'll miss my 2nd family.",
#  "I used to call Eden Hazard 'overrated' as a joke. Nobody's laughing now.  He's dreadful.",
#  'The Holidays are in full swing.  Need gift ideas? Check out my Holiday Gift guide!  ',
#  "My mum had no electricity at here's so she has moved in w/ me. I dressed her up as a � & we are… ",
#  'VOTE for @Grandfathered at @peopleschoice awards. Click here to VOTE: ',
#  "Who’s ready for tWitch & Allison's Dance Challenge? If you know a super talented kid dancer, send in a video! ",
#  "#CaitlynJenner: if trans people 'look like a man in a dress, it makes people uncomfortable' ",
#  "'@robdelaney just tell the horse it won who gives a shit'",
#  '.[2] @meed429 #ConversationWithAlanis ...can share my humanity without shame i see it as an invitation for others to do the same.',
#  'Cleveland Golf + Technology = #HOLYPOOPICANPUTT!!!  Check it: ',
#  'Who wears the pants in #WillSmith’s family?! ',
#  "'@wizkhalifa put in so much work on Cabin Fever 3.'",
#  'Tina Fey on The Tonight Show Starring Jimmy Fallon ',
#  '.@iTunesPodcasts @thisamerlife and @duncantrussell and @CherylStrayed’s #DearSugarRadio #ConversationWithAlanis',
#  "U don't like Carson - u r racist, U don't like Trump - u r loser. That is what tonight's #GOPDebate is about  #VegasGOPDebate",
#  'Some idiotic show on MTV would be more informative than #GOPDebate #VegasGOPDebate',
#  'God is not a franchise of the Republican Party #VegasGOPDebate',
#  '#Cruz is the worst candidate for our country #VegasGOPDebate',
#  'Whatever happened to #Bush? Where’s he hiding? #GOPDebate #VegasGOPDebate',
#  "'@SenTedCruz Why do GOP candidates whine to avoid answering questions?  #VegasGOPDebate'",
#  'Trump is an magnate and he doesn’t care about US economy. He cares only about his own money #GOPDebate #VegasGOPDebate',
#  '#CNNDebate #VegasGOPDebate All these speeches are empty #GOPDebate',
#  '#CNNDebate Do we really need another #GOPDebate? Every new is worse than the previous one #VegasGOPDebate',
#  'Is there a drinking game for the #GOPDebate? #VegasGOPDebate',
#  "'@JohnKasich What are your thoughts on Drake and Meek Mill? #VegasGOPDebate'",
#  '#CNNDebate #VegasGOPDebate Today we’ll hear a lot of empty promises.  Are you ready? #GOPDebate',
#  'Will corrupted politicians talk about corruption? #GOPDebate #VegasGOPDebate',
#  '#CNNDebate #GOPDebate If Jeb loses his wife will lose her last hope to get thr green card #VegasGOPDebate',
#  'It’s just a baby talk #GOPDebate #VegasGOPDebate',
#  "'@CarlyFiorina What is your favorite color... colored person? #VegasGOPDebate'",
#  'Common sense isn’t the best friend of the GOP candidates #VegasGOPDebate',
#  "#VegasGOPDebate #GOPDebate If Carson doesn't stab Trump it will be waste of time",
#  'Donald Trump at the #GOPDebate #VegasGOPDebate',
#  '"Carter Banned Iranians From Coming To U.S. During Hostage Crisis" ',
#  'Today Only! Save 25% on all 1982 Collection items, and save 40% when you bundle together! ',
#  'What an amazing room today filled with so many strong and inspiring women.. ❤️ #Power100 ',
#  'You asked. We did it....."Bre 4 Sports Toilet Bowl" !!! Join at ',
#  '�Today\'s the day! My limited edition @maccosmetics lipstick "Von Teese" is now on sale:… ',
#  'Love these wise words from one of the most elegant women ever! #WCW: Audrey Hepburn. #wordsofwisdom #quoteoftheday ',
#  'but that dont say none of syrian refugees are terrorists #IslamKills',
#  '#IslamKills #tousensemble #prayforbrussels #Brussels',
#  '#IslamKills Thoughts and prayers are with all in Brussels.#prayforBrussels',
#  'Refugees are not welcome, that my view! #IslamKills #StopIslam',
#  '#Brussels We may not be at war with Islam, but it sure seems Islam is at war w/us! #tcot #IslamKills',
#  '#IslamKills These people need to stay out of America. They are animals. Disgusting animals #StopIslam',
#  'That\'s it!Not complicated at all. #IslamKills"',
#  '#Brussels #IslamKills Keep Canada White',
#  "#IslamKills Why do we destroy ourselves I don't get it, we're destroying our own planet with things like these I'm skdjsiis #PrayForBrussels",
#  '#IslamKills This is actually terrifying, love and thoughts go out to everyone ❤️ #PrayForBrussels #Brussels',
#  "#IslamKills Why isn't Europe keeping its promise to resettle #refugees?",
#  '#Brussels Obama wants to help refugees? Why doesn’t he want to help fellow Americans first? #IslamKills',
#  "If you don't think all Syrian refugees are terrorists you are part of the problem. #IslamKills",
#  '#Brussels #IslamKills "Immigration without integration is an invasion" prolly smartest thing Bobby Jindals ever said',
#  '#IslamKills the ‘refugees’ don’t look like those in need, absolutely #StopIslam',
#  '#IslamKills "not all refugees are terrorists" not all bears are gonna kill you but do you want bears living in your house',
#  '#IslamKills @jnevandcourtney All is ok here in Spain. Thank you. #PrayforBrussels #Brussels',
#  "#IslamKills My thoughts and prayers to all the family's who involved in the terror accents in Brussels #PrayForBrussels #StopIslam",
#  '#StopIslam #IslamKills RT @DooM_Tasty: #PrayForBrussels',
#  '#Brussels #IslamKills IS wants to polarize Europe. They seek to create chaos and a religious war between Muslims and non-Muslims',
#  '#Brussels but that dont say none of syrian refugees are terrorists #IslamKills',
#  '#blacklivesmatter #blm #equality #equalrights ',
#  "'@big_gun_in_utah so? If you pay more taxes you have more rights? This how it works?'",
#  "'@big_gun_in_utah some of you?'",
#  'Black Students force the university to divest $25 Million in private prisons  ',
#  "Racist Maine Gov. on 'drug problem'  ",
#  '‘I Can’t Breathe’: Video of  Police Dragging Barbara Dawson from the Hospital   ',
#  'Cop Sentenced To Five Years For Pointing Gun In Man’s Face  ',
#  'Case re-opened. Cop Shoot Man 3 Times as He Was Face Down in Handcuffs  ',
#  "At last! NYPD cop In Eric Garner's Death Faces Departmental Charges #blacklivesmatter #policestate #policebrutality ",
#  'That feel when you find this new great song and listen to it on repeat ',
#  'What the f*ck?  ',
#  'Same old story rich and white your alright. End of story #equality #equalrights ',
#  'Obama delivers his final State of the Union address but said nothing about #BLM Why? @ShaunKing ',
#  'Did they count slavery as incarceration? #policestate #policebrutality #incarceration ',
#  'On this day in 1966,  Johnson appoints first African-American cabinet member - Robert C. Weaver #blacktwitter ',
#  'Cop turns a simple situation into aggressive confrontation  ',
#  "Cop's Passion For Arresting Activists Nah! NYPD does NOT make me feel safe  ",
#  'Chilly #black ',
#  'Cop Shot 12yo Girl While Evicting Her Family From Their Home  ',
#  'Idiot Cop Accuses Asian man of Being “an ISIS” and Beats Him  ',
#  'White America Does The Crime, Black America Gets The Time. WTF? #BlackLivesMatter #racism ',
#  'what? #blaclivesmatter #blacktivist #blactwitter ',
#  'Numbers #Justice is kinda selective. #equality #racism #policestate #incarceration #prison  #BlackLivesMatter ',
#  "'@Plantflowes what kind of information do you need?'",
#  'A mom and her baby. Some people lose diamonds in search of stones #black #art ',
#  'A mom and her baby. Some people lose diamonds in search of stones #black #art #blackgirlmagic ',
#  'Video of Cedrick Chatman’s Killing by Police will be released #CedrickChatman  #blacklivesmatter #blackToLive ',
#  'Look to @chrisrock  to make jokes about him being the only Black on stage #OscarsStillSoWhite #OscarsSoWhite ',
#  'Video of cops shooting #CedrickChatman released  ',
#  'Somebody #AskPOTUS why he completely ignores black issues in final state of the Union Address #BlackLivesMatter ',
#  'Settlement to Freddie Gray’s Family delayed  ',
#  "'@deray worst day of the week'",
#  'Looking for a common sense during #GOPDebate   #blahblahblah #BS ',
#  'Cop drags man out of car and brutally beats him  ',
#  'Black students not getting the mental health help they need Research: ',
#  'Every one of us, whether a child or a grown up, should pursue the dreams ',
#  'Seriously? wants Arizona to ban shooting cops without their permission  ',
#  "Cops just don't need a real reason #acab #policestate #racism ",
#  'Took a YEAR! Three Baltimore cops charged with assaulting a man at Sinai Hospital.  ',
#  'Cop faces NO charges after  fatally strangling innocent man  ',
#  "Ferguson's History of Racism #blacklivesmatter #equality Video: ",
#  'Seems like #GOPDebate is about blaming Obama and Clintons on literally everything ',
#  "Only one question about police and back to immigrants. #BlackLivesMatter doesn't matter in the #GOPDebate #BLM ",
#  'Luv it! Cops report that a man drove a tractor over eight police vehicles after marijuana arrest  #acab ',
#  '#ImProtestingBecause cops kill unarmed Blacks and never get punished #NoJusticeNoPeace #BlackLivesMatters ',
#  'Jada Pinkett-Smith have criticised Oscar committee! She is so right! #Blacklivesmatter #blm #equality ',
#  '16yo Gynnya McMillen died in police custody last week. Read and RT this  ',
#  "What? Cop: Buy these tickets or I take your car Ain't that illegal AF?  ",
#  '#ReclaimMLK #SayTheirNames  Find an action near you  ',
#  '#ReclaimMLK: "This is a time for vigorous and positive action."  Action! #BlackLivesMatter ',
#  'Thy shalt not take Tylenol but after  Cop beats ya in the head ya gonna need that Tylenol  ',
#  "Bet he'd say he feared for his life, the judge will believe him, then walks free #acab #BLM  ",
#  'Just perfect ',
#  'Sounds like a victory!  ',
#  'Study shows 45 percent increase in death by cops. Mostly among non-whites.  ',
#  'This is a day to honor one man who took initiative and stood up for the minority. #MLKDay ',
#  '51 years later and the things Martin Luther King said are still relevant #MLKDay ',
#  'So @realDonaldTrump walks in the bar and...  #BibleTrumping #TwoCorinthians ',
#  "'@deray finally. GOPdebate aint touched that'",
#  'So we need a police reform. ASAP! #DemDebate ',
#  "'@FoxNews @HillaryClinton proud to be traitor?'",
#  "Henry Bennett was shot by PBSO deputy on Saturday Cop's name not released. No video of shooting. Nothing #BLM ",
#  'People arrested in LA while protesting the killing of #MichaelBrown  ',
#  '‘You’re Lucky I Didn’t Shoot You In The Head’!  ',
#  'Shot over 10 Times by cops: the CJay Pettit story  ',
#  'What? Mysterious malfunction?  ',
#  'Black means Beautiful ',
#  'Sick! Alabama hit with KKK flyers, wishing the civil rights icon a “Happy Birthday” just before #MLKDay  #MLKNOW ',
#  "'@deray republicans just enjoy doin that'",
#  'Johannes Mehserle, the cop who murdered #OscarGrant, did 1 year in jail and is currently still a COP!  Justice? No ',
#  'This proves that police violence doesn\'t happen because of "black on black crime"   ',
#  'Numbers #PoliceBrutality  #policestate #acab ',
#  "'@realDonaldTrump come on! Beat the establishment!'",
#  'Cop “Accidentally” Fires 27 Rounds at Own Mom.  "Accidentally" means no need for charges.  ',
#  'White Privilege and its results for all others in USA ',
#  'This cop assaulted 13 black women. Now #danielholtzclaw is sentenced to 263 years in prison  #BlackLivesMatter ',
#  'Will Smith joins wife in not attending the Oscars #OscarsSoWhite #OscarsBoycott ',
#  'Oscars have consistently cinematically robbed Black America #OscarsSoWhite #OscarsBoycott   ',
#  "'@ShaunKing justice should be served!'",
#  'DA to have press conference at 7:30PM #GrandJuryWatch #AnthonyHill #MentalIllnessIsNotACrime ',
#  '“It destroyed a whole family " This cop raped a 15yo girl since 15 #policebrutality #acab   ',
#  "'@gloed_up @genericpanic bet those who decided are white AF'",
#  'The #AnthonyHill decision would probably be handed down in minutes #GrandJuryWatch ',
#  'DeKalb officer Olsen indicted on all 6 counts in death of Anthony Hill. Arrest warrant issued #AnthonyHill ',
#  "Black students speak out on Wheaton's Larycia Hawkins 'problem' Read this   ",
#  'All SIX COUNTS! This is HUGE VICTORY! #GrandJuryWatch #AnthonyHill  #allsixcounts @deray #BlackLivesMatter ',
#  '“It destroyed a whole family " This cop raped a 15yo girl since 15 #policebrutality #acab   ',
#  "What? Cops who killed Michael Marshall won't be prosecuted  ",
#  'Wow! Homeless Black man saves family from fire. Says "I\'m not a hero\'  ',
#  'Tonight, we celebrate. Tonight, we won! All this would be impossible without @bridgie_xoxo  #AnthonyHill',
#  'Tonight, we celebrate. Tonight, we won! All this would be impossible without @bridgie_xoxo  #AnthonyHill ',
#  "'@thewritelady @RebelMouse ty!'",
#  "Sandra Bland's Arrest Was Cop's Fault. Justice would be served! #BlackLivesMatter   ",
#  'Just imagine #OscarsSoWhite  #OscarsBoycott  #Black #Friends #FriendsReunion ',
#  'Being black be like #BlackLivesMatter  #equality  #discrimination ',
#  'when I think I got a handle on shit in my life ',
#  "Being white 'protester' be like: warm food, Wi-Fi and no violence from cops  ",
#  'Missed this #BlackLivesMatter protester interrupts @usmayors event #ResignRahm #Blacktwitter ',
#  'Simple #Roe43 #prolifemarch ',
#  "'@msgdi8511 @usmayors some people recognize threat in literally EVERY black person'",
#  '#BlackLivesMatter #BlackTwitter ',
#  '#BlackLivesMatter Is coming to Netflix  ',
#  'Walsh and March are off the streets cuz their reports contradict what is seen on video. Oh really? #LaquanMcDonald ',
#  'No parole for #KKK leader who killed Black teen with a crossbow  ',
#  '13 Honest books about #slavery young people should read #BlackLivesMatter ',
#  '#BlackLivesMatter St. Paul wants to charge  cop who posted  “Run them over” in advance of protest they held ',
#  'Redmond, Wash. Black store owners find #KKK robe, rope left for them  ',
#  '#Justice? NO Kwame Kilpatrick vs Rick Snyder #FlintWaterCrisis  #BlackTwitter ',
#  "#danielholtzclaw's victims: Our lives changed forever! #BlackLivesMatter #Blacktwitter  ",
#  'Academypresident Cheryl Isaacs  promised to bring  diversity to future shows #OscarsSoWhite #BlackTwitter #equality ',
#  'The story of Akai Gurley who was shot by cop in Brooklyn   ',
#  'HBO Ordered a #BlackLivesMatter documentary after #OscarsSoWhite   ',
#  "America's prosecutors: 95% white and 79% male  Equality? Justice? Diversity? NO NO and NO #BlackLivesMatter ",
#  'Never forget. Never give up #BlackLivesMatter #BlackTwitter ',
#  'How about being Black woman in Hollywood?  ',
#  "A boy gets kicked outta school for saying 'ISIS' but this is perfectly acceptable?  ",
#  'Won a lottery, spent money on gifts 4 ppl in need Killed 2 months later in home invasion  ',
#  'Voting? Nah Cleveland grand jury never voted to indict the cop who shot #TamirRice  ',
#  'Flint’s water system should be fixed asap  ',
#  'Tennessee cops profiting off drug trade?  ',
#  '#Cops shot this man in the head Now he is suing the dept for $6mil  ',
#  'On January 24, 1956, Emmett Till murderers made magazine confession #BlackLivesMatter  #Blacktwitter ',
#  "'@ShaunKing @MichaelsStores cant say N word? Write it'",
#  'History repeats. Cops hide behind the badges just like men hid under white hoods #TamirRice #BlackLivesMatter ',
#  "'@vickijee well tbh I actually support a citizen's right to own a firearm. Not an issue'",
#  'Great job standing your ground! Black man schools cops on his rights  ',
#  'So you got poisoned. Now pay for it! This is what rebellions are made of.  ',
#  'The #BlackLivesMatter murals in a school ',
#  "Just a sacrificial lamb. When ALL cops are held accountable, I'll be happy.  ",
#  "In the coming months, we'll know if those to blame were criminals or merely incompetent jackasses #FlintWaterCrisis ",
#  'The fuck? Cops be like: lets hire some murderers.  ',
#  "I'll just leave it here #CopsBeLike #Policestate #Policebrutality #ACAB ",
#  'Half of young black men in Chicago out of work, out of school  ',
#  '#FlintWaterCrisis sum up  ',
#  "'@RemyKyd the worst part'",
#  'Tf? Man tried to save his dogs from burning house. Got beaten and arrested by #cops!  ',
#  'Reality of #reparations  ',
#  ".@_KrisJStewart on #OscarsSoWhite: 'Instead of complaining, do Something' Ok. Like dis? #Oscar2016 ",
#  'Must read. Understanding white supremacy  ',
#  'Being black is not a crime!  #BlackLivesMatter #Blacktwitter ',
#  "'@BJSolomonCarson my bad.  ",
#  'Reality we are facing every day #BlackLivesMatter #Policebrutality #SandraBland #TamirRice #LaquanMcDonald ',
#  'Not the way it should be #Black and #White #Ferguson and #Oregon  #racism #hypocrisy #BlackLivesMatter ',
#  'More #Black babies aborted than born alive in NY  ',
#  '#Black is beautiful and always will be! #BlackLivesMatter  #blackbeauty ',
#  'So powerful! #FlintWaterCrisis made the @TIME cover #FlintWater #Blacklivesmatter ',
#  "Cops be like 'I swear to #protect and #serve'  BS! #AkaiGurley  #BlackLivesMatter  #Policebrutality #BlackTwitter ",
#  'Anyone else wondering about this? Help spreading this #DonateWater2Flint #FlintWaterCrisis  #BlackLivesMatter ',
#  'Must-read  ',
#  'Powerful historical photos: Black Americans even had to fight for the right to use the ocean #BlackLivesMatter ',
#  "Today's #BlackLivesMatter protest at Albany City Hall #BLM #JusticeForDontay #DontayIvy ",
#  "'@No1TopHatFanboy feeling of absolute weakness'",
#  '#QuintonioLeGrier called 911 on the day he was shot by #cops  ',
#  'Some truth #blizzard2016 #BlackLivesMatter ',
#  'Happy birthday Dr. Angela Davis! #AngelaDavis  #BlackLivesMatter ',
#  'We stand with you! Militia will take up arms to defend flint If necessary  ',
#  'New excuse! My muscles feared for my life Cop blames ‘muscle memory’ after  shooting unarmed driver #Policestate ',
#  'Obama bans solitary confinement of juveniles! #KaliefBrowder  #BlackLivesMatter   ',
#  '"R" girl from N-word T-shirts photo apologizes, says she is not #racist   ',
#  'They blind?? NYPD #cops zapped wrong man. Victim will file $5M lawsuit  ',
#  "TF? Man ACCIDENTALLY thrown in the steaming shower? Dat's BS  ",
#  'But we will. We will talk and act! #AngelaDavis  #BlackLivesMatter  #Blacktwitter ',
#  "Don't let em mind fuck u #Racism #BlackLivesMatter ",
#  "'@dijoni @No1TopHatFanboy @RemyKyd Never forget. And never stop fighting'",
#  'White ppl be like "I have black friends crowd, I\'m not racist cuz my bf is black". Dont be deceived by fake smiles ',
#  'Acquiescence - agreement or consent by silence or without objection #WakeUp #BlackLivesMatter  #FlintWaterCrisis ',
#  "Tell me how #whiteprivilage doesn't exist #Blacklivesmatter #RacismMustFall  #equality ",
#  'Sick! What next? Braiding salon hiring only white women #Black   ',
#  'Rest in power #sandrabland #blacklivesmatter #rip ',
#  'Different shades of #black! ',
#  'Dont be afraid to #Blackpower #Blacklivesmatter #BlackTwitter ',
#  'How #Flint, #Ferguson and #Baltimore are all connected  ',
#  'Dozens seeking challenge of remaking #Ferguson police force   ',
#  '4 years later They just be in jail.  #137shots  #PoliceBrutality ',
#  'A Minnesota cop on #MLKDay used his FB acc to instruct ppl how to kill black protesters and go unpunished #BLM ',
#  'Feds are forcing policing reforms on #Ferguson. ',
#  'Cop used chokehold on #BlackLivesMatter Protester  ',
#  "#EricGarner's daughter endorses @BernieSanders   ",
#  '#FlashbackFriday be like ',
#  'To see young black women coming together in the face of these ignorant girls is a beautiful thing #BlackLivesMatter ',
#  "'@BlakeDontCrack tryna set new record'",
#  'Flint organizer advising #BlackLivesMatter On #FlintWaterCrisis   ',
#  "#LaquanMcDonald's murderer had broken his dashcam on purpose  ",
#  "'@politicalseason @Maat_Justice ",
#  'Injustice in Louisiana: 16-year-old got life without parole for throwing one punch @nytimes ',
#  'Black school kids in US are beaten  disproportionately  ',
#  "Nah! Never met those 'all cops' ",
#  'Chicago cops hid mics to block audio. Every video is silent  ',
#  'Do conservatives give a fuck about #policebrutality?  ',
#  'Black woman was chased by 6 #KKK Members but cops did nothing!  ',
#  'Cops caught on camera beating  an unarmed man  ',
#  "'@deray Carson forgot to take his pills?'",
#  'Bravo! Love this! Totally lost it at mayonnaise monster lmfao  ',
#  '“Due to the corrupt system, I have a dead child" - Samaria Rice  ',
#  'In case you missed it. #OregonUnderAttack ',
#  'Tell me about equality! #OregonUnderAttack #BlackLivesMatter @deray ',
#  "'@markaddisonjr @deray Is a kid at pool more dangerous than 150 armed thugs in federal building? #OregonUnderAttack ",
#  "'@markaddisonjr @deray is a 12 yo black kid with a toy gun more dangerous than 150 armed bigots?'",
#  'Is this accurate? #OregonUnderAttack  #BlackLivesMatter  #equality ',
#  "You can't separate peace from freedom because no one can be at peace unless he has his freedom. ",
#  'Since Xmas, cops in US have killed 14 people. Twice as many people as the British police have killed since 2011! ',
#  'Anyone? #OregonUnderAttack  #BlackLivesMatter  #TamirRice  #JusticeForTamir  @deray @LeftSentThis ',
#  "'@deray yeah right. What about their guns? They seem less threatening than Tamir's?'",
#  'Or maybe a 12 year old black kid with a fake gun. Or a guy with a clock #OregonUnderAttack  #BlackLivesMatter ',
#  "'@Billysmithjr33 should i remind you it was open carry state?'",
#  "'@Billysmithjr33 he didn't point point a gun at anyone. Watch the video'",
#  "'@Billysmithjr33 that was like minute before cops arrived'",
#  "'@Billysmithjr33 All they had to say was put the gun down. They dont train cops like that to pull up and basically do a drive by shooting.'",
#  'Cop killed teen, crashed patrol car while high on crack. Still a cop  ',
#  'More black parents to consider homeschooling due to #racism  ',
#  'Can anyone explain this shit? #Black ',
#  '#DoJ cracks down on #Ferguson cops —  record everything  ',
#  "Didn't know this @SenSanders  #MLK #MLKDay #BlackLivesMatter ",
#  "'@AshaBurwell Be strong!  Tell us how we can support you!'",
#  'Dear white ppl! Please stop trying to make yourself oppressed #BlackLivesMatter #Equality ',
#  'Another example of cops  escalating an incident  ',
#  'Join Us!!! We need All Of #NewYorkCity ! #BlackLivesMatter #RamarleyGraham ',
#  'WTF???? @Migov currently has a $575M budget SURPLUS  ',
#  'Sexual violence by #cops deserves the same attention as the Catholic Church scandal   ',
#  '#Holtzclaw went to jail monday, but he’s since vanished  ',
#  "America's need for more black male educators  ",
#  'Detroit teachers sue district over horrible conditions  ',
#  'They don’t want us to protect ourselves  #BlackLivesMatters  #BlackPanther  #BLM ',
#  "There's always an excuse to justify white people. #BLM #BlackLivesMatters ",
#  "'@BlakeDontCrack we should be able to protect ourselves!'",
#  "'@ShaunKing justice in America...'",
#  'White Supremacy Has always Been a War of Power Against Blacks in America  ',
#  '#StopKillingOurKids: A Mother’s Response to the #TamirRice Decision  ',
#  'Govt Pays Millions in Reparations to 57 Victims of this cop. He Still Receives a Pension  ',
#  'Only 5 years? U fuckin kidding? Cop Gave Under Age Girl Ambien to Drug Her, Then Raped Her  ',
#  'Back in the sixties cops organized the mobs to attack black protesters. Cops were always racist. Nothing changed ',
#  '1,200 people killed by police in 2015. 0 cops in jail today 0 convictions Justice? Definitely NO #BlackLivesMatter ',
#  'Chicago cops tried to intimidate Laquan McDonald witnesses  ',
#  "'Raise your kids not to play with fake guns stupid b*tch'  Cop to Tamir's mother Gets paid vacation after that. WTF ",
#  'NYPD Cops act like the Mafia extorting $1k per week from the  pizza shop owner  ',
#  'Off-duty cop sends Maryland State Troopers on a high-speed chase. Gets paid vacation instead of being arrested!  ',
#  '18 cops were arrested for unjustified shootings in 2015. Not a single cop convicted  ',
#  'How to get a paid vacation as a cop 1 Break the law 2 Get vacation  Da phuck? ',
#  'This cop beats and rapes pregnant women. Still not fired  ',
#  'Just think about it #policestate #policebrutality  #acab ',
#  'The Deadly Consequences When #Police Lack Proper Training to Handle #MentalIllness Calls ',
#  '#Blackwomen are made out of brown sugar, cocoa, honey and gold…  And the strength of ten thousand moons ',
#  '#Sheriff that Laughed about Flash Banging a Toddler, Was Just #Shot By Murderous Rogue #Cop ',
#  'Cop Shoots Mentally Ill Woman in the Chest. Officer Was Justified ',
#  '#Cops #Police #PoliceBrutality #US ',
#  '#Cops #Police #PoliceBrutality #Shooting #StayWoke #JusticeOrElse ',
#  'Nobody has the right to take away someone’s freedom  #cops #PoliceBrutality #policeabuse #BlackLivesMatter ',
#  '4 those who r out there in #Ferguson RN  I love U  U can make me happy by posting pic of u w/ a #4mysquad sign  #IOIOIS #MillionManMarch',
#  '#ClevelandDA refuses 2 file charges against cop, who shot #TamirRice. unlikely the grand jury own will file charges. ',
#  'ATTENTION! remember this motherfucker? you can help get this DANGEROUS #Cop off the streets   ',
#  '',
#  '"Are they for real?" #PoliceBrutality #PoliceAbuse #CopBlock #JusticeOrElse ',
#  'So now they say #TamirRice shooting was reasonable! seriously? 12 y/o boy with a pellet gun... smell it? I DO ',
#  'You never become a howling success by just howling.',
#  '2k15 makes me feel the same way... ',
#  '#MillionManMarch crowds in #Washington under the banner of “#JusticeOrElse” for 20th anniversary rally. ',
#  'Same shit But now in color today #BlackLivesMatter #StayWoke #PoliceBrutality #PoliceRacism ',
#  'Look at this bullshit!��� SO topical! everybody be talking about #PoliceBravery RN. Not #PoliceBrutality no no no ',
#  '#JusticeOrElse  We Got The Power ',
#  "#OpenCarry legal in Ohio, but #TamirRice, shot'n'killed for open carrying TOYS Fake Gun - Real Tragedy #StayWoke ",
#  'Utter bullshit! Anyone can be brave with a badge, a gun & a back-up unit round the corner. #Police #Cowards #Psychos ',
#  "#OpenCarry legal in Ohio, but #TamirRice, shot'n'killed for open carrying a TOY Fake Gun  Real Tragedy #StayWoke ",
#  'ISSUE: #RacialJustice SOLUTION: #BernieSanders ',
#  '#TX high school #cop grabs 14 y/o by throat, slams teen to ground (VIDEO) #GyasiHughes ',
#  "'@richboyric @SweetAs_Kai Probably the same stuff as Ludacris ",
#  'The patron saint of the internet is Isidore of Seville, who tried to record everything ever known ',
#  "I'm about to get my Deray on @deraysvest ",
#  '“If #TamirRice Was White In a Cardigan and Nikes Would that #cop have thought twice and Stopped and Gave Advice” ',
#  'Photo taken by the  at the #MillionMamMarch #BlackLivesMatter #BlackTwitter #POWER ',
#  'Two leaders of the future generation at the #MillionManMarch in Washington DC #BlackLivesMatter #Cute #BlackTwitter ',
#  "#Aerosmith lead singer Steven Tyler told #DonaldTrump 2 stop using 'Dream On'. Because Fuck you, thats why ",
#  'This is precisious! Young feminist warrior on the Million Man March. #MillionManMarch #feminist #feminism ',
#  'This is precisious! Young feminist warrior on the Million Man March today. #MillionManMarch #feminist #feminism ',
#  'Go down in history, baby #BlackLivesMatter ',
#  'Remember #KaldrickDonald killed by Police in 2014 #blacklivesmatter  #justiceorelse #millionmanmarch ',
#  'Dark times. ',
#  'stay to myself cuz these niggas is corny ',
#  'This is what i call a real struggle in America  people have to eat,too ',
#  '#Police Withhold videos despite vows of transparency  So there is a fair question if #bodycameras are really working? ',
#  'We need #Justice! So…Release the tapes. ',
#  '#DarkTimes: #Cop accused of #Raping a girl at the gunpoint was justified ',
#  'When she asks if your finger game is strong... ',
#  'The reason 50 cent declared bankruptcy #BlackTwitter #50Cent #Bankruptcy ',
#  '#FTP ',
#  "#Iaintnever ran from nothin' but the #Police ",
#  'Cole at the #JusticeOrElse #MillionManMarch in Washington DC ',
#  'Fired Kalamazoo prosecutor gets jail, probation for drunken driving crash ',
#  'fuck you miley ',
#  'WHY THE HELL THEY WERE NOT PUNISHED? are u fucking serious???  #BlackLivesMatter #BlackTwitter #blackpeopletwitter ',
#  '#policebrutality covered w/ the most stupid reason to kill an unarmed man #acab #cops #BlackLivesMatter #blackpeople ',
#  'white VS black people  lol ',
#  "stop being mad ppl we won't stop it at all ",
#  "'@nettaaaaaaaa was arrested filming a direct action of civil disobedience #cops #PoliceBrutality ",
#  '#WhiteSupremacy is more afraid of black unity than #black rage. —  #DerayMcKesson #WhitePrivilege #blackpower #BlackLivesMatter',
#  'It’s hard out here for a troll ',
#  'Selma 50 event today. See Congressman John Lewis’ feed, of course deray and the #Selma50 tag ',
#  'IMPORTANT UPDATE! SPREAD IT! TWEET IT! BE THERE! ',
#  "'@marclamonthill @carolsonlyboy yes bro  should we speak 'bout justice or else?'",
#  '#RIP #TamirRice #PoliceBrutality #cops #policeViolence ',
#  "#SandraBland we won't forget ",
#  '#Ferguson #policeAbuse #PoliceBrutality #cops #BlackLivesMatter #BlackTwitter ',
#  '“If I didn’t define myself for myself, I would be crunched into other people’s fantasies for me and eaten alive.” - Audre Lorde',
#  'wow thanks for support bae  ',
#  "'@GoddessKerriLyn @AnasuyaIam equality is the only way to stay alive'",
#  '#BlackLivesMatter #blackpeopletwitter #BlackTwitter ',
#  "there's no reason to turn in white ",
#  'perfect bro ',
#  'last year perfect twitt ',
#  "'@AnasuyaIam @GoddessKerriLyn oh yes honey  I agree so'",
#  'wise thoughts ',
#  "'@4mysquad No need for cancerous tanning. Bc of Melanin we do not age as quickly as non-Blacks. #BeautifullyBkack'",
#  'We’re using Baltimore’s economic assets for job creation at all skill levels. ',
#  "'@MayorSRB some people are using Baltimore victims for their benefit'",
#  "'@CulpritEnter @amandvbynes their wet lips you know lol'",
#  'I love yours and mine and ours. If reincarnated, i wanna come back Black. ',
#  '#Unarmed #Black Woman beaten and tackled by Florida #cops 4 #FilmingArrest of her husband. ',
#  "parents: so what'd yall do when we were out of town   me and friends: um... just chilled.. *has flashback* ",
#  'We have nothing to lose but our chains  #BlackLivesMatter #JusticeOfElse #BlackTwitter ',
#  '"Why\'d u cheat on me" ',
#  '#MillionManMarch drew crowds to National Mall in Washington under the banner of #JusticeOrElse ',
#  'Calls for change at 20th anniversary of Million Man March ',
#  "#Police accused of Inflation nightclub cover-up: 'We are the police and we decide what to do' #cops #BlackTwitter ",
#  'Chief Defends “Good #Cop” Who Pepper-Sprayed Man For No Reason as He Walked Down the Street #cops #acab #police #race ',
#  '#PoliceBrutality VIDEO Cindy Hahn sues City of Carlsbad #Police Assault caught on tape #California #cops #acab #BLM ',
#  'Round Rock High police incident caught on camera #cops #PoliceBrutality #BlackLivesMatter #BlackTwitter #racism #acab ',
#  '#Jailhouse Video Released In The Death Of 21-year-old #MatthewAjibade #cops #acab #PoliceBrutality #BLM #BlackTwitter ',
#  "2 Reports Say #Officer's #Shooting of #TamarRice Justified #cops #policeBrutality #acab #policeViolence #BlackTwitter ",
#  '#Texas Councilman Tazed While Defending Friends Being Questioned By The Same Officers Who Arrested #SandraBland #BLM ',
#  'such tactless mudslinging #BlackLivesMatter #acab #PoliceBrutality #BlackTwitter #BlackPeopleRules #cop #badcop ',
#  '#BlackLivesMatter holds up the mirror of truth to #racists  #racism #BlackTwitter #blackpeopletwitter #cops #blackout ',
#  '#BLM is fucking up so #hard. #BlackTwitter #BlackLivesMatter #BlackPeopleRules #blackpeopletwitter #PoliceBrutality ',
#  'While On Desk Duty for Kicking a Cuffed Man in the Face, Cop Manages to Beat an Innocent Teen  ',
#  '#BlackLivesMatter and their tense closed-doors meeting with #HillaryClinton  #BlackTwitter #blackpeopletwitter #acab ',
#  'Being #white in #America vs being #Black in America #blackpeopletwitter #BlackTwitter #BlackPower #BlackLivesMatter ',
#  'These are the people who police the #police #BlackLivesMatter #BlackTwitter #blackpeopletwitter #BlackPower #acab ',
#  'Black and unarmed! #wherewasthethreat #blm #JeremyMcDole #checkthetag ',
#  'When you are not trying to hear #alllivesmatter #BlackLivesMatter #BlackTwitter #blackpeopletwitter #BlackPower ',
#  'society makes these assaults happen,not the perpetrator.Or skewed investigation.Or anything but actual responsibility ',
#  'The same shit  #BlackLivesMatter #blackpeopletwitter #BlackTwitter #acab #PoliceBrutality ',
#  'Taxpayer Money Could Be Used To Defend Daniel Holtzclaw In Civil Suit #BlackLivesMatter #cops #acab #PoliceBrutality ',
#  'No matter what they say #blackpeople have less opportunities in life than white in #America ',
#  'This is what i call a real struggle in #usa ',
#  'This is important. #BlackLivesMatter #blackpeopletwitter #BlackTwitter #BlackPower #cops #PoliceBrutality ',
#  'one in a million wanted #justice and would have to pay for it #BlackLivesMatter #BlackTwitter #PoliceBrutality #Black ',
#  '1% of the police officers are convicted in crimes  compared to 94% of the citizens #BlackLivesMatter #blackpeople ',
#  'wow ',
#  'Colin Kaepernick to start this Sunday for the San Francisco 49ers ',
#  "CRAZY! A 14 yr old child who can't pay a small fine to a court can end up in an adult prison instead. #FinesAndFees ",
#  "Me when it's time to code-switch for an interview:   #AtlantaFX ",
#  's/o to this literal icon ',
#  "[RECORD SCRATCH] [FREEZE FRAME]  AMERICA: Yep, that's me. You're probably wondering how I got myself into this. ",
#  "'Mommy,am I gonna die':Mom of 5year-old Ohio girl accidently shot by cop trying to subdue dog says officer left scene ",
#  '#AvaEllis was accidentally shot by a Columbus police officer who was trying to subdue a charging dog #PoliceBrutality ',
#  'Video Clears Man (M. Jeter) and Cops are Charged!  WATCH ',
#  'LMAO  ',
#  'lol ',
#  'damn straight ',
#  '#Cops beat up and seem to break black teens arm for getting money out of his ATM ',
#  'yes. absolutely right bro ',
#  "Don't take NO for an answer. Agitate against white supremacy. #BlackLivesMatter ",
#  'bastards ',
#  'Video shows #police tasing a bloody, restrained #MatthewAjibade in the testicles before his death. #PoliceBrutality ',
#  '#Cop Runs Down Suspect with Truck,Beats & Tasers him in the Head, Dept Says it was an Accident #PoliceBrutality #acab ',
#  'Palestinian Child Bleeds to Death while Israeli Police&Civilians Watch, Shouting Insults #acab #cops #PoliceBrutality ',
#  'Cleveland #police officer charged with abduction appears in court #PoliceBrutality #policeViolence #BlackLivesMatter ',
#  '2 deputies fired after fellow deputy shot in sting #BlackLivesMatter #acab #BlackTwitter #PoliceBrutality ',
#  'NY Police Say Viral Video Showing #Cop Choking Man Was Actually Life Saving Attempt there was no f*ckin reason ',
#  'Former Cleveland #police chief awarded his service #gun #PoliceBrutality #acab #BlackLivesMatter #BlackPeopleProblems ',
#  "'@87_cjohnson totally bro. fat pigs'",
#  'lil black girl is runnin from police officcer ',
#  '3 charts that show police forces still have a #race problem #PoliceBrutality #cops #policeviolence #BlackLivesMatter ',
#  "'@_JujuBean12 @No_Biggy_ awful gif image dudes'",
#  'Smart kid! ',
#  "'@Kilameri1 Since the childhood she has to fear'",
#  "'@87_cjohnson yes. black children to grow up in fear. why the f*ck can't it stop'",
#  "'@4mysquad She's learning early to run away, from a Brutal Murderer!'",
#  "'@4mysquad Our Government, Supreme Court, Congress, and the DOJ are intertwined in Bigotry and Racism, the DOJ commands Brutal police force!'",
#  "'@Briizayy__ @Simone101xo awful scene'",
#  'Photo: Badge privilege\xa0 #Cops #Police #Abuse #CorruptedCops \xa0\xa0 ',
#  'Nicholas Kristof:Gun deaths more numerous for preschoolers than police #BlackLivesMatter #cops #acab #PoliceBrutality ',
#  'Border Patrol agent indicted in 2012 fatal shooting #PoliceBrutality #cops #policeviolence ',
#  '#Cops Taser kneeling #black councilman in #Texas town where #SandraBland was arrested #PoliceBrutality #Black ',
#  'Fairfax tickets cars for needing inspection — while they wait for inspections #BlackLivesMatter #cops #acab ',
#  'Cleveland #Police Justified in Killing 12-Year-Old #TamirRice, Reports State #JusticeOrElse #racism #BlackLivesMatter ',
#  'Councilman Tasered in #Texas over Crime of—Actually There Wasn’t Even a #Crime #SandraBland #BlackLivesMatter #acab ',
#  'Me lol ',
#  "when I'm extremely high ",
#  'Me asking for #justice  #BlackLivesMatter #acab #racism #BlackTwitter #Blackpeoplebelike ',
#  "When I hear people say there's no racism in #America #BlackLivesMatter #Blackpeoplebelike #BlackTwitter #acab #BLM ",
#  '#BlackBeauty #BlackPower #BlackWomen #blackgirls #BlackLivesMatter #BlackTwitter #Blackpeoplebelike ',
#  'Dank Pineapple Express Nugs � ',
#  'who is the most pretty girls #blackgirls #blackbeauty #BlackWomenAreGorgeous #BlackTwitter #Blackpeoplebelike ',
#  '#Drunk #dance #beyonce #Blackgirls #BlackWomenAreGorgeous ',
#  '#drake #asaprocky #Blackpeoplebelike #rappers #blacktwitter #nigga ',
#  'Miss Fantasy #blackBeauty #blackgirls #BlackWomenAreGorgeous #BlackLivesMatter #BlackTwitter #Blackpeoplebelike ',
#  'smoke it #weed #nigga #Blackpeoplebelike #BlackTwitter ',
#  '#BlackWomen #blackgirls #Blackpeoplebelike #BlackBeauty #BlackLivesMatter ',
#  'I know when that hotline bling That can only mean one thing � #drake #music #everyday',
#  "'@Imaumbn hey c'mon I think snickers isn't the worst desicion'",
#  'Mix ',
#  '#hello #motherfuckers #boy #nigga #BlackTwitter #Blackpeoplebelike #blackpower ',
#  'lol i cant �� #Blackpeoplebelike #BlackPeopleTwitter #BlackLivesMatter #BlackTwitter ',
#  'True #BlackPeopleProblems #Blackpeoplebelike #black #blacktwitter ',
#  'for real ',
#  'for real tho ���dudes I love you all  ������ ',
#  'who can relate to this? ���� #morning #happyday #BlackTwitter #Blackpeoplebelike ',
#  '#Justice is what we seek #Blackpeoplebelike #BlackTwitter #BlackLivesMatter #JusticeOrElse #racism #america ',
#  '#BlackPeopleBeLike “ White People Be Like”... #BlackLivesMatter #BlackTwitter #racism #stopracism ',
#  "When you get the cops called because a 'Hispanic-looking woman & black man with a suspicious white truck & camera' are near a school � ",
#  'Colin Kaepernick wore pig socks, took a knee in protest, picked out his fro, did NOT back down, spoke his mind and then got his job back: ',
#  '⚡ Report: Actor Tommy Ford has died at 52   ',
#  'Yes, they are. Yes, they are. Yes, they do. ',
#  'Institutionalize racism at its best ',
#  'Transgender woman found dead in Cleveland with plastic bag around head ',
#  'R.I.P. ',
#  "LMAOOOOO @R3troSp3ctro ON #ATLANTAFX I'M DEADASS CRYING RIGHT NOW ",
#  "Why isn't this all over twitter? #MaryHawkes  #Boost #PoliceLies  #PoliceBrutality #StayWoke  ",
#  'Daughter calls 911 to help suicidal mother, #Cops #Shoot her by mistake, then #kill her mom ',
#  "'@deray @ShaunKing @ReverantRevan @christwords199 @foolishchicka @Kilameri1 @ElleLamar @ZaRdOz420WPN @BWorthingtonIII ",
#  'so yall niggas ain’t fuckin with this cake i baked ',
#  '17 y/o  #DevenGuilford was killed by a #Cop after flashing his brights. This is depressing  ',
#  "'@elise_flowers fucking bangbangers smh'",
#  'This Man survived a #PoliceShooting and became an activist #BlackLivesMatter #usa  ',
#  '#Police has created a corrosion in the justice system of our country We got to fix it ',
#  '#Philly #police officer clearly stalking man by reason of intimidation tactics. rediculous!  ',
#  '✊�✊�✊� ',
#  'HE SAID #BLACKLIVESMATTER AND I APPROVE THIS MESSAGE! #BlackLivesMatter #Bernie2016   ',
#  'It is NOW  #BlackLivesMatter #StayWoke #BlackTwitter ',
#  '#Bernie2016  He has got my vote ',
#  "'@4mysquad Then I suppose this will have to do until then. ✊⚖☮☯✏ United we stand. ",
#  '‘CUZ THERE’S NO “BUT” IN DIS, BITCH  #BlackLivesMatter ',
#  'California starts new Law that says #police must get a #warrant 2 use #stingray #StayWoke It Works #BlackLivesMatter ',
#  "'@IAmKenyaGrace oh boy U looooove to hear compliments! Good thing I love 2 say em. Youre DOPE! ������'",
#  "'@imindigomoon oh boy U looooove to hear compliments! Good thing I love 2 say em. Youre DOPE! ������'",
#  'Our people are dying...We must unite',
#  '#MMIW Missing/Murdered 235 cases of #Indigenous Girls! ',
#  'Every time something Bad happens all people want is the #Truth Today it is a rarity #BlackLivesMatter #PoliceLies ',
#  'Police STILL stonewalling about the killing of #ZacharyHammond. October 14, 2015 #StayStrong  ',
#  'no way dude ',
#  "'@KeeganNYC @ReverantRevan THE POLICE IS RUNNING OUT OF FUCKS TO GIVE ABOUT CITIZEN'S LIVES!'",
#  "How search interest in #BlackLivesMatter spiked during last night's debate: ",
#  'During the "talking" period and you realize she might be the other half you been missing: ',
#  "'@imindigomoon this is usually triggered by music, related to those memories'",
#  "Where do all those 'fired' #cops go? #Colorado Police welcomes them with open arms  ",
#  'Son of a bitch ',
#  '#black teens age 15-19 are 21 times more likely to be shot by police than whites are. #BlackLivesMatter ',
#  'Help Iowa #FeelTheBern as a campaign organizer!  Apply here: ',
#  "'@meechonmars @cuntxmuffin_ Bae, Its not you, Its me.....'",
#  '"According to the FBI’s Uniform Crime Report, white Americans are responsible for 69.3 percent of crime." ',
#  '69 � ',
#  "We're not talking about a murder mystery here ",
#  'Oh shit. I totally forgot about this. Watch: Michelle Obama Slams Hillary  ',
#  'Woman accused of open container but bodycam shows cop saying "you have an attitude, you\'re under arrest too then" #CopsLie ',
#  'So... my cousin is trying to teach his cat to use the toilet "to save on kitty litter"  My dude, WTF is this shit?!?  I gotta get my own apt ',
#  '90% rapes go unreported Of those reported, only 30% go to trial Of those who faced trial, only 1/3 were jailed #WhyWomenDontReport #notokay ',
#  "Come on y'all, spread the word. ",
#  "'@SARAH2TURNNT I always tell people about their screwed hoods and unzipped bags, just reserving a table in heaven for myself ☺️'",
#  'Ima spray some on you ',
#  'mmmmOh my God � ',
#  'this truth tea is scalding ',
#  'Bae #BlackTwitter #Nudes #Bae #BlackGirl #Cute #Tattoo ',
#  'Sixth Tucson police employee terminated in prostitution probe ',
#  'Resisting charge dropped against woman in heated traffic stop w/ deputy  #StayWoke It works ',
#  '#Racism:  Ignore it… and it won’t go away! #blacklivesmatter ',
#  'and N.W.A. Playing #NWA #FuckThePolice #ACAB ',
#  'when your mom comes home and there’s a fork in the sink and you ain’t take that damn chicken out the freezer ',
#  'She’s beauty, she’s grace   She puts panties on her face ',
#  'oh shi.... #ACAB #FuckTheCops #BlackLivesMatter ',
#  'Bae:  ',
#  'YOU: ',
#  "#Cops band together, use #BluePrivilege 2 help convicted CHILDMOLESTOR Cop get lighter sentence 'serve and protect' ",
#  '#QueenslandPolice Officer violently arrests, injures cyclist 4 not wearing a helmet video: ',
#  'Alabama man shuts down cops who questioned him for jogging #WhileBlack — and it’s perfect ����  ',
#  'No justice. No peace.  ',
#  'How #DonaldTrump comes up with his ideas  ',
#  'current mood: irritatingly sad ',
#  '& every time u hear a black person speaking as loud as possible,sb is going 2 say:‘Look at those niggers over there’ ',
#  "'@christwords199 Trump is always on the wrong side of the argument smh'",
#  'I present this w/ no comments ',
#  'IS THIS FOR REAL? #PoliceBrutality #PoliceIncompetence #DontCall911 #ACAB #FuckThePolice ',
#  'This shit is NOT OK, Officer! Tackling 14 y/o non-violent #GyasiHughes w/ a chokehold? Bad move, Officer! ',
#  '#BlackLivesMatter  ',
#  'All of them ',
#  'LIT #The6ix #PrayingHads #Drake #JustALittleStoner ',
#  '#Police officer slamming 15 y/o #TylerDeburgo at William Tolman High School in Pawtucket #RhodeIsland ',
#  '#NYPD Destroyed birth certificates, medication, IDs in #EastHarlem homeless raid more here: ',
#  'State makes it legal to #ShootCops in self-defense if they violate your rights.  is That the solution? watcha think? ',
#  "'@4mysquad Flag down Flagrant Unsportsmanlike Conduct Lifetime Ejection From the Team Additional Sanctions To Follow ",
#  'But thats gay  (ƃuᴉʞoɾ ɯ,I) ',
#  "'@christwords199 covering murder with homicide... thats not math where two  negatives make positive'",
#  "'@christwords199 but fuck yeah, I'll shoot a cop, who is trying to take me down 4 nothin'",
#  "Jus' want to be clear: #BlackLivesMatter simply means that the lives of African-Americans matter. That’s all. ",
#  'When I meet her vs. When I meet her parents ',
#  '#BU Stands With MU #BlackLivesMatter #BlackAndProud ',
#  '#MLK won the #NobelPeacePrize in 1964. This Wednesday (14th) is a day of commemoration of his achievement. ',
#  'That. Was. Awesome. #FuckThaPolice #PoliceAbuse #BlackLivesMatter #RemainSilent  ',
#  'That. Was. Awesome. #FuckThaPolice #PoliceAbuse #BlackLivesMatter #RemainSilent ',
#  "'@4mysquad  Trump never has stated, which side of the Black lives Matter debate he is on. ",
#  'still the most crusial issue above all in the United States #StopBlackGenocide #BlackLivesMatter ',
#  'If I die in police custody, I didn’t commit suicide.',
#  "#Police officers' names still secret 3 years after #shooting ",
#  '#FuckHer ',
#  '�� ',
#  '"Bye Roberta" is the new "Bye Felicia" ✌�#QueenSugar ',
#  'We need more good cops to step up and do the right thing. ',
# ...
#  'lmao ',
#  'When they talk bout banning guns they bring #Oregon shooting But what bout #Police terror on Black Ppl We NEED #Guns 2 protect our lives',
#  'Today I’m so sick of thinking about race, but it’s the first thing on my mind ‘cause it’s the first thing on my face ',
#  'Lit artwork via   ',
#  'Palm Beach Officer Who Killed #CoreyJones Wearing Plain Clothes And Driving Unmarked Car ',
#  "'@LanceBass @MTV Woke AF'",
#  "'@NBCTheVoice @KorinBukowski @ChaseKerby @respektor ",
#  'I give a fuck about MY LIFE do you? ',
#  "'@ChachiBobinks @AndrastesTits @blogdiva @deray  I don't usually political art but here (could be better I admit) ",
#  "'@dxnitrv whats wrong about it?'",
#  "'@ShaunKing Clear themselves... ugh... theyre never gonna be clean'",
#  "Will there ever be any #Justice 4 #POC in this country?!  I'm losing faith...  ",
#  "'@ShaunKing come and get these blue pigs. I'll do it myself for all of us #BlackLivesMatter'",
#  "Detective Can't Shake Hidden Camera Claims #PoliceBrutality #acab #BlackTwitter #BlackPower #BlackFamily ",
#  'Maryland police officer accused of biting testicles has left department #PoliceBrutality #acab #BlackTwitter #Black ',
#  "'@SugarBeats Thank you 2!'",
#  "Mass. town giving 'tickets' for good behavior #PoliceBrutality #cops #acab #blackpeopletwitter #BlackTwitter #BLM ",
#  'Homan Square revealed:How Chicago police ‘disappeared’ 7,000 ppl #blackpeopletwitter #BlackTwitter #PoliceBrutality ',
#  'Florida #cops kill #black man who pulled over with car trouble-and then refuse to tell family why #BlackPeople #BLM ',
#  'The #NYPD Is Using Mobile X-Ray Vans to Spy on Unknown Target #PoliceBrutality #BlackLivesMatter #BlackTwitter #BLM ',
#  'Police Kill Man Who Took Officer’s Gun During Struggle In Downtown #SanFrancisco #PoliceBrutality #BlackTwitter #BLM ',
#  'hey right  ',
#  '#Chicago #Cops Have Disappeared More than 7,000 Ppl at Secret Interrogation Warehouse #PoliceBrutality #BlackTwitter ',
#  "#Nigga was dancin' on the roof while it was a fire  #Cops are takin' him on a gurney Respect bro! #BlackLivesMatter ",
#  'Nina Simone to the South African rap game when their biggest supporters are under siege. #FeesMustFall ',
#  'Never compromise for anything less than you deserve.',
#  'lmao God  ',
#  'LOL so  ',
#  'oh boo I want you to know yall not alone bae  not alone  w/love ',
#  "'@wordoffar8 #PrayForJustice  #BlackLivesMatter #BlackPeople #BlackPower'",
#  'Police arrest 23 as students protest tuition fee-hike plan  #PoliceBrutality #cops #acab #BlackTwitter #BlackPeople ',
#  'This is straight up #realtalk #FeesMustFall ',
#  '“The white man’s happiness cannot be purchased by the #black man’s misery.” -Frederick Douglass #PoliceBrutality ',
#  'Words can be weapons by Hidden Foo #art #PoliceBrutality #BlackTwitter ',
#  'Truth about slavery ',
#  'I have a dream my little children will 1 day live in a nation where they wont be judged by the color of their skin, but by their character',
#  '#BlackTransWoman Shot In The Head.For the second time this month a black transgender woman has been killed #BLM #blc ',
#  'Statistics speak for themselves #PoliceBrutality #racismInAmerica #BlackLivesMatter #BlackTwitter #BlackPeople #acab ',
#  "'@OGJudy_ common sense is great but each of your fam w/common sense is boring no?'",
#  "'@OGJudy_ hey boopsy i want you to be more polite ugh  #tyke'",
#  'How I feel about starting my work on a Monday #sleeponit ',
#  'LMAO ',
#  "'@Oprah LOE'",
#  "'@Oprah LOVE'",
#  "'@SethMacFarlane SO TRUE'",
#  'FRESH AF ',
#  "'@Drake YASSS'",
#  'Chicago Mayor blames viral #PoliceBrutality videos for rising murder numbers ...wait what? ',
#  'You know where it is going ',
#  "'@deray #StayWoke it works'",
#  "Thats the shit I don't like #FTP #BLM #ACAB #BlackLivesMatter ",
#  "I'm dead  #BlacklivesMatter #System #POC #StayWoke ",
#  '#Chicago #Cops have “Disappeared” more than 7k people at secret interrogation warehouse ',
#  "'@JanelleMonae @starwars a black guy!'",
#  'JOE ARPAIO USES FAKE RECALL TO FUNDRAISE ',
#  'Star Wars: #TheForceAwakens: Watch the new trailer ',
#  'Police Officer totally provoking a black man he pulled over, escalating situation but gets no response. #PoliceAbuse  ',
#  'Drake is on FLEEEEEK w/ his new video 4 HotlineBling watch here: ',
#  'Video:"Police officer" in SUV hits cyclist, threatens to arrest.   ',
#  'NYPD officer indicted for allegedly stealing home ownership from dead woman’s family #PoliceBrutality #acab #BlackTw ',
#  'After his car broke down, Florida church drummer shot and killed by plainclothes officer #PoliceBrutality #BlackFolk ',
#  'Florida Cop Literally Just Shot Unarmed #Black W/His Hands Up, Begging Not To Be Shot #PoliceBrutality #blackTwitter ',
#  'Cop Runs Down Suspect with Truck, Beats Him, Tasers Him, Then Says It Was All An ‘Accident’ #BlackTwitter #acab #BLM ',
#  'Garner chief #AntiPolice graffiti cowardly a hate crime #PoliceBrutality #BlackTwitter #BlackPower #BlackPeople #BLM ',
#  'Pastor: I held my son while Sacramento deputy shot him to death #PoliceBrutality #BlackLivesMatter #BlackTwitter ',
#  '#Chicago Mayor blames viral #police brutality videos for rising murder numbers #BlackTwitter #blackpeopletwitter ',
#  "Homan Square revealed: how Chicago #police 'disappeared' 7,000 people #PoliceBrutality #cops #BlackLivesMatter #BLM ",
#  'A Turkish police officer pointed a gun at the head of a journalist #PoliceBrutality is all around #acab #BLM #blc ',
#  'Racial Profiling is Real and So Are Its Lingering Effects ',
#  "'@zellieimani share it! #BlackLivesMatter'",
#  '7 ways #police break the law, use threats, or lie to get what they want #BlackPeople #BlackTwitter #blackpower #acab ',
#  '7 ways #police break the law, use threats, or lie to get what they want #BlackPeople #BlackTwitter #blackpower #acab ',
#  'BOOST ',
#  'Just lemme know why the fuck  ',
#  'Important AF!!! ',
#  "Video: Metro transit police detained and arrested a teenager after she wouldn't throw away her bag of chips. ",
#  'The U.S. constitution has clearly been violated by these MFs. ',
#  'It’s sad and unpleasant times we live in when people have to ride around with messages painted on their cars.. #blacklivesmatter #philly ',
#  'SATELLITE FEED CUT AS SOON AS CONGRESSMAN MENTIONS WIKILEAKS ON CNN  ',
#  'People: if we just be kind and loving to those who want us dead they will eventually affirm our humanity  History: ',
#  "I always feel blindsided and personally attacked when I'm trying to carry out convos via text and they suddenly call me. ",
#  'I had an ancestor who stole the "settler\'s" hearts so they stole her from her family. GENEALOGY = a decidedly white hobby #BlackLivesMatter',
#  "I won't say who it is.But I'm very thankful  #BlackLivesMatter #BlackTwitter #racism #blackpeopletwitter ",
#  "'@AFRICAisMankind he was harmful to all peace. you know all the troubles inflicted by cops'",
#  "'@4mysquad Cop shot 7 year old #Aiyana n the head as she slept he also killed the dog. No jail. Did he harm ppl 2? Was Animal cruelty called?'",
#  'Former H.S. #FootballStar Shot and Killed in Virginia After Allegedly Jumping Into Off-Duty #Police Officer’s Car ',
#  'Federal court tells the DEA to stop harassing medical marijuana providers #BlackTwitter #BlackLivesMatter #BlackPpl ',
#  "#Michigan teen's family files federal lawsuit over fatal traffic-stop shooting #BlackLivesMatter #blackpeopletwitter ",
#  '$2.25 million settlement reached in Painesville police Taser incident #blackpeopletwitter #BlackTwitter ',
#  'Is that guy carrying a gun? #BlackLivesMatter #BlackTwitter #BlackPower #BlackPeopleTwitter ',
#  "#Cop fired after failing lie detector test as he was questioned over the disappearance of his brother's girlfriend ",
#  'Tenn. lawmakers urged to keep asset forfeiture law intact #BlackLivesMatter #blackpeopletwitter #BlackPower ',
#  'DEMON POSSESSED ARGENTINIAN COP FAKE CAR ACCIDENT AND INJURY: THERE IS NO SUCH THING AS A GOOD COP ',
#  '#JCole at the #MillionManMarch  #BlackTwitter #BlackLivesMatter #blackpeopletwitter #BlackProblems ',
#  '#October 17, 1968: Olympic protestors stripped of their medals ',
#  'fists in the air   #BlackLivesMatter #BlackTwitter #blackpeopletwitter ',
#  '“Hold your head up little man you’re a king!”-Nas #BlackLivesMatter #blackpeopletwitter #BlackTwitter #Black ',
#  "For out Gov't ",
#  '',
#  'in #America it is #usa #BlackLivesMatter #BlackTwitter ',
#  'This is the society that I live in. No humanity…no #justice ',
#  "'@ShaunKing lemme know how can we call him officer? It's total shame. Who to call when police murders'",
#  '#whiteprivilege  ',
#  '#BlackLivesMatter ',
#  'RIP #EricGarner ',
#  'more than 920 people were killed by police in 2015 …just in LA',
#  '. @deray everytime you post this I realy proud of us #BlackLivesMatter',
#  '. @deray I dream of #BlackLivesMatter  I dream of race would be nothing',
#  'nice bro   ',
#  '. @HendersonKaya Just thank you are with us.  #BlackLivesMatter movement is perfect. Happy to be in',
#  "'@ReverantRevan @deray yes man.it is we must be strong'",
#  '. @ShaunKing they hurt us every time they are near by. cops must be more polite to every citizen independently of race and skin colour',
#  '. @ShaunKing @vicenews say if I can help Shaun',
#  "'@hbg1x48 thanx bro! you're welcome 2'",
#  '. @ReverantRevan @deray I just want America to let justice in. That is decision',
#  "'@ReverantRevan @deray I see your point.and I'm agree. Totally'",
#  'cute ',
#  "'@AFRICAisMankind @4mysquad @BlackjediNow @foolishchicka @NewNatTurner @conscious_black @Briizayy__ @MeJoycex Life isn't about what you earn.'",
#  'Ain’t nothin wrong with a lil bit of chocolat ',
#  'Is Cleveland In a State of Ignorance? #BlackLivesMatter #TamirRice #BlackTwitter #blackpeopletwitter ',
#  '#BlackLivesMatter Protesters Attack Trump Supporters ➠ Trump Supporters Blamed For Violence ',
#  'Queen ',
#  'Do you prefer miracle whip ? ',
#  'LMAOOO RT @angelayee: Wale says Meek bought a pencil to a gunfight, a piece of paper and tried to paper cut him to death #breakfastclub',
#  'Agawam woman accidentally shot in face by police files $1.5 million suit in federal court ',
#  'Dog shot by Florida City police officer Animal rescue volunteer says dog shot 3 times in head ',
#  'Animal purposely run over, shot in Collingwood; resident believes animal his dog ',
#  'Owner of dog shot, killed by police files lawsuit for $2 million #BlackLivesMatter ',
#  'NBAer in 1Oak club brawl suing cops and city for $50M ',
#  'Soldier Finds His Former Hero Service Dog Being Abused by a Deputy who Won’t Give Him Back #PoliceBrutality #acab ',
#  'Drug war is a scam, #racism is a problem and it’s time to stand up: ‘Unfiltered’ GA $cop tells it like it is #BLM ',
#  'Florida #Cop Murders Pet Dog 3 Feet From Terrified Homeowners in Incident Caught on Video  #PoliceBrutality #acab ',
#  'Florida deputies arrest 9 y.o. boy and post mugshot online, prompting criticism and cheers #BlackLivesMatter #acab ',
#  '#NYPD #cop stole 4-story townhouse, DA says #acab #PoliceBrutality #cops #BlackTwitter #cops #acab #BlackLivesMatter ',
#  'mah fam ',
#  'love that #PoliceBrutality #cops #BlackTwitter #BlackLivesMatter #BlackPower #BlackDream ',
#  'lemme be #nigga  #BlackLivesMatter #BlackTwitter ',
#  'staff ',
#  'Yes #BlackLivesMatter #BlackTwitter #BlackandWhite #BlackPower ',
#  'nice art ',
#  'True bro ',
#  'Failed #BlackLivesMatter ',
#  "RIP #NYPD Officer Randolph Holder  we never forget the other cops' #Brutality ",
#  '"4 police officers murdered in the last 11 months that\'s about as bad as it gets."   Worse than 956 killed by police #NYPD',
#  'perfect one ',
#  'CURRY REALLY WILDIN ON THESE NIGGAS ',
#  "Rudy Giuliani looks like he hasn't laughed at a joke since the 1920s so I get why he didn't find that one funny. #AlSmithDinner ",
#  '',
#  'Artist Sean Hassett created this piece titled “I Am You”, and thought it was so powerful I had to share. Deep. #blacklivesmatter ',
#  'ʷʰʸ\xa0 \xa0 \xa0 \xa0 ʷʰʸ \xa0 \xa0 \xa0 ʷʰʸ\xa0 \xa0\xa0 \xa0 ʷʰʸ \xa0 \xa0 ʷʰʸ \xa0 \xa0 ʷʰʸ \xa0 \xa0 ʷʰʸ \xa0 ʷʰʸ \xa0 why am i an asshole\xa0\xa0 ʷʰʸ \xa0\xa0 \xa0 \xa0 \xa0 \xa0 \xa0 ʷʰʸ\xa0 \xa0 \xa0 \xa0 \xa0 \xa0 ʷʰʸ',
#  'Reporter confronts white man who calls him the n-word, slave A Virginia man verbally harassed Steve Crump near Mother Emanuel Church. ',
#  'I wish I had teachers like that✊� 2,000 Seattle teachers showed up for work in #BlackLivesMatter shirts. ',
#  "It's official, at 18 years old I co-own B & B's Ice Cream with my parents. Located at 8236 s Racine. COME SUPPORT A BLACK OWNED BUSINESS ",
#  '"Please hold your applause until all of the graduates names have been called"  Black parents: ',
#  'Anthem singer at Heat-76ers game kneels during performance   ',
#  'shit ',
#  'Young Morgan Freeman look like old Morgan Freeman dressed up like young Morgan Freeman ',
#  'Donald Trump has said he wants to bans Muslims, but Hillary Clinton has already bombed Muslims. #tytlive',
#  'If he didn’t say he was “live on facebook”, he would have been arrested and assaulted ',
#  'She is gorgeous ',
#  'lmao ',
#  'Little Did He Know ',
#  'The fuck wrong with them? ',
#  'Hey #Blacktivist!  ',
#  "'@Virtuous_Queen_ @SweetAs_Kai @watchlar66 @Dontstopnow5 @kidnoble @akacharleswade @SARAH2TURNNT @Russian_Starr @BlackLaughs'",
#  'Hey #Blacktivist!  ',
#  'Hey #Blacktivist!  ',
#  'Me: damn I have to much to do  Me for 57 minutes: ',
#  'We have to stand up for black children and be prepared to protect them. ',
#  'NAACP demands federal probe after noose allegedly put on black student ',
#  'SOLANGE pro-black and her music has a clear, unapologetic message ',
#  "Students from Steinert High School � this how y'all act? Someone find some  @'s ",
#  'I NEED this! ',
#  "How y'all look at teenage girls when they have an abortion vs how y'all look at her if she keeps the baby ",
#  'Lynching of Thomas Shipp and Abram Smith and a mural dedicated to the white Lynch mob in an urban community hidden in plain sight. ',
#  'Nah, we gotta get this camera off the market. � ',
#  'When your mom show you something "funny" on facebook that you saw on twitter 2 years ago ',
#  'First black, female comic book store owner on the East Coast to appear on variant cover of "Invincible Iron Man #1." ',
#  'I don’t think white supremacists have to hide very much in the police. ',
#  'Gucci Mane, ladies and gentlemen. This might be the greatest thing that has ever happened to me. ',
#  'Black high school football player in Mississippi says white students put noose around his neck during practice. ',
#  'How fucking in a motherfucker business to notice four fucking flakes on a dude dashboard. These cops ain’t prioritizing at all ',
#  '� ',
#  'Niya was arrested for challenging police abuse in school. Her story is an important part of our struggle. ',
#  "Then: Me: I want McDonald's  Mom: Do you have McDonald's money?  Now: Mom: I want grandkids  Me: Do you have grandkids money??",
#  'Why Pop Culture Just Can’t Deal With Black Male Sexuality ',
#  'It\'s hard to believe that there are "teachers" like this one  White Teacher Told Blck Students That White People Are More Superior Than Them ',
#  'An affirmative action bake sale from white students at the University of Texas. They actually think they have it harder b/c they are white. ',
#  'Seattle police officer caught lying in the performance of her duties keeps job, raise and PROMOTION thanks to police union ‘agreement’ ',
#  'I respect black women for putting up with daily disrespect. I can’t even imagine that shit',
#  'GTA San Andreas is 12 years old today. Is this the best GTA game or no � ',
#  'But who cares about facts, right? The cops FEEL there is a war being waged against them. ',
#  'Wake yo ass up before you be late to school��� ',
#  'Nigga is that Anne Hathaway? RT @woahaydrian: Dominicans are out of control lmaoo ',
#  '"HARASSED BY POLICE FOR MY HAIR!!"  ',
#  'She was supposed to sing the national anthem – but then they saw her shirt. ',
#  'Haiti President Calls Clinton Thieve Who Should Be In Jail ',
#  'Oh really? So how are the falsely convicted prisoners and their families going to be compensated? ',
#  'A #collage of Sandra Bland using #portraits of black woman or feminine presenting people. ',
#  ...]

# %%
wordcloud = WordCloud(background_color="white",width=1000, height=860, margin=2).generate(' '.join(content))
plt.imshow(wordcloud)
plt.axis("off")
plt.show()

# %%
wordcloud.to_file('content_wordcloud.png')

# %%
content = remove_hashtags(content)
content
# Out:
# [' is not a joke!   ',
#  'Thanks God that  i ate few days ago was good.  ',
#  "I hurt easy, I just don't show it. You can hurt someone and not even know it.",
#  "who's got the worst make up ever, don't tell me, mirror",
#  'jade doesn`t love her! ',
#  'Unreal friendship may turn to real. But real friendship, once ended, cannot be mended.',
#  '« The young are permanently in a state resembling intoxication. » Aristotle',
#  'The best thing you can do in your life is to please God. The worst thing you can do in your life is to please everyone.',
#  "Honey, I'll learn! ",
#  'cats giving high fives!!!!! ',
#  'Home is where my bed is',
#  'When the beat drops just keep swinging it',
#  "She gets on you under your skin like a tattoo, she'll always be there, she holds on stuck in your head, like an old song. ",
#  'As usual, there is a great woman behind every idiot',
#  'Music plays a mind trick, watch me forget about missing you',
#  'do u ever look at ur friends like "im so glad these weird losers are mine"',
#  'I consider hitting a girl the most pussy thing a guy could ever possibly do',
#  'When we first met, I had no idea you’d become this important to me.',
#  'what happiness is? Free Wi-Fi!',
#  'Even if my intentions are good, the result is still awful :(',
#  'incredible!!!!! ',
#  'Booty ',
#  'girls winning',
#  'Why did we give a monopoly of creating money out of thin air to a private [Federal Reserve] corporation? – Franklin Saunders',
#  'Despite all the junk food someone still complimented me on my skin',
#  "Love like you'll never be hurt",
#  'so easy I can do them myself! ',
#  "RT if you're ripping that Hustle gang",
#  'queen and anti-queen ',
#  "When love is real, it doesn't lie, cheat, pretend, or hurt you. It cures you of all your worries and makes you truly happy.",
#  'The harder you work, the harder it is to surrender.',
#  '',
#  'you should never care what other people say about you',
#  "Unless you change how you are, you will always have what you've got.",
#  "I'm an instant star. Just add water and stir.",
#  'don`t wear it if !! ',
#  "Took 50 pictures... Don't like a single one. Even IG filters don't help me!",
#  "'@DrGregoryWest gave me shivers...'",
#  'I want my little parrot to speak at last!!! ',
#  'An everyday changing funny church sign ',
#  'I wish look like  ',
#  "Why is someone even against the ? I'll watch you bleeding when some thug shoots your ass off ",
#  'It’s reasonable to ban firearms sales in  areas  ',
#  "'@HalfOnionInABag Follow the other half an onion! Mage America Great Again1'",
#  "'@HalfOnionInABag Follow another half of the onion. Reveal it's dark side!'",
#  "'@cmath_72 @HalfOnionInABag Follow the other side of the onion to Make America Great Again!'",
#  ' defense playing hungry .. Bending and not breaking �',
#  "Let's go offense !!!! Start Up the  !!!!  ... We need to turn up the tempo �� ",
#  "I was shocked and heartbroken when @CBS canceled . I would have shot this show for 50 more years. I'll miss my 2nd family.",
#  "I used to call Eden Hazard 'overrated' as a joke. Nobody's laughing now.  He's dreadful.",
#  'The Holidays are in full swing.  Need gift ideas? Check out my Holiday Gift guide!  ',
#  "My mum had no electricity at here's so she has moved in w/ me. I dressed her up as a � & we are… ",
#  'VOTE for @Grandfathered at @peopleschoice awards. Click here to VOTE: ',
#  "Who’s ready for tWitch & Allison's Dance Challenge? If you know a super talented kid dancer, send in a video! ",
#  ": if trans people 'look like a man in a dress, it makes people uncomfortable' ",
#  "'@robdelaney just tell the horse it won who gives a shit'",
#  '.[2] @meed429  ...can share my humanity without shame i see it as an invitation for others to do the same.',
#  'Cleveland Golf + Technology = !!!  Check it: ',
#  'Who wears the pants in ’s family?! ',
#  "'@wizkhalifa put in so much work on Cabin Fever 3.'",
#  'Tina Fey on The Tonight Show Starring Jimmy Fallon ',
#  '.@iTunesPodcasts @thisamerlife and @duncantrussell and @CherylStrayed’s  ',
#  "U don't like Carson - u r racist, U don't like Trump - u r loser. That is what tonight's  is about  ",
#  'Some idiotic show on MTV would be more informative than  ',
#  'God is not a franchise of the Republican Party ',
#  ' is the worst candidate for our country ',
#  'Whatever happened to ? Where’s he hiding?  ',
#  "'@SenTedCruz Why do GOP candidates whine to avoid answering questions?  '",
#  'Trump is an magnate and he doesn’t care about US economy. He cares only about his own money  ',
#  '  All these speeches are empty ',
#  ' Do we really need another ? Every new is worse than the previous one ',
#  'Is there a drinking game for the ? ',
#  "'@JohnKasich What are your thoughts on Drake and Meek Mill? '",
#  '  Today we’ll hear a lot of empty promises.  Are you ready? ',
#  'Will corrupted politicians talk about corruption?  ',
#  '  If Jeb loses his wife will lose her last hope to get thr green card ',
#  'It’s just a baby talk  ',
#  "'@CarlyFiorina What is your favorite color... colored person? '",
#  'Common sense isn’t the best friend of the GOP candidates ',
#  "  If Carson doesn't stab Trump it will be waste of time",
#  'Donald Trump at the  ',
#  '"Carter Banned Iranians From Coming To U.S. During Hostage Crisis" ',
#  'Today Only! Save 25% on all 1982 Collection items, and save 40% when you bundle together! ',
#  'What an amazing room today filled with so many strong and inspiring women.. ❤️  ',
#  'You asked. We did it....."Bre 4 Sports Toilet Bowl" !!! Join at ',
#  '�Today\'s the day! My limited edition @maccosmetics lipstick "Von Teese" is now on sale:… ',
#  'Love these wise words from one of the most elegant women ever! : Audrey Hepburn.   ',
#  'but that dont say none of syrian refugees are terrorists ',
#  '   ',
#  ' Thoughts and prayers are with all in Brussels.',
#  'Refugees are not welcome, that my view!  ',
#  ' We may not be at war with Islam, but it sure seems Islam is at war w/us!  ',
#  ' These people need to stay out of America. They are animals. Disgusting animals ',
#  'That\'s it!Not complicated at all. "',
#  '  Keep Canada White',
#  " Why do we destroy ourselves I don't get it, we're destroying our own planet with things like these I'm skdjsiis ",
#  ' This is actually terrifying, love and thoughts go out to everyone ❤️  ',
#  " Why isn't Europe keeping its promise to resettle ?",
#  ' Obama wants to help refugees? Why doesn’t he want to help fellow Americans first? ',
#  "If you don't think all Syrian refugees are terrorists you are part of the problem. ",
#  '  "Immigration without integration is an invasion" prolly smartest thing Bobby Jindals ever said',
#  ' the ‘refugees’ don’t look like those in need, absolutely ',
#  ' "not all refugees are terrorists" not all bears are gonna kill you but do you want bears living in your house',
#  ' @jnevandcourtney All is ok here in Spain. Thank you.  ',
#  " My thoughts and prayers to all the family's who involved in the terror accents in Brussels  ",
#  '  RT @DooM_Tasty: ',
#  '  IS wants to polarize Europe. They seek to create chaos and a religious war between Muslims and non-Muslims',
#  ' but that dont say none of syrian refugees are terrorists ',
#  '    ',
#  "'@big_gun_in_utah so? If you pay more taxes you have more rights? This how it works?'",
#  "'@big_gun_in_utah some of you?'",
#  'Black Students force the university to divest $25 Million in private prisons  ',
#  "Racist Maine Gov. on 'drug problem'  ",
#  '‘I Can’t Breathe’: Video of  Police Dragging Barbara Dawson from the Hospital   ',
#  'Cop Sentenced To Five Years For Pointing Gun In Man’s Face  ',
#  'Case re-opened. Cop Shoot Man 3 Times as He Was Face Down in Handcuffs  ',
#  "At last! NYPD cop In Eric Garner's Death Faces Departmental Charges    ",
#  'That feel when you find this new great song and listen to it on repeat ',
#  'What the f*ck?  ',
#  'Same old story rich and white your alright. End of story   ',
#  'Obama delivers his final State of the Union address but said nothing about  Why? @ShaunKing ',
#  'Did they count slavery as incarceration?    ',
#  'On this day in 1966,  Johnson appoints first African-American cabinet member - Robert C. Weaver  ',
#  'Cop turns a simple situation into aggressive confrontation  ',
#  "Cop's Passion For Arresting Activists Nah! NYPD does NOT make me feel safe  ",
#  'Chilly  ',
#  'Cop Shot 12yo Girl While Evicting Her Family From Their Home  ',
#  'Idiot Cop Accuses Asian man of Being “an ISIS” and Beats Him  ',
#  'White America Does The Crime, Black America Gets The Time. WTF?   ',
#  'what?    ',
#  'Numbers  is kinda selective.        ',
#  "'@Plantflowes what kind of information do you need?'",
#  'A mom and her baby. Some people lose diamonds in search of stones   ',
#  'A mom and her baby. Some people lose diamonds in search of stones    ',
#  'Video of Cedrick Chatman’s Killing by Police will be released     ',
#  'Look to @chrisrock  to make jokes about him being the only Black on stage   ',
#  'Video of cops shooting  released  ',
#  'Somebody  why he completely ignores black issues in final state of the Union Address  ',
#  'Settlement to Freddie Gray’s Family delayed  ',
#  "'@deray worst day of the week'",
#  'Looking for a common sense during      ',
#  'Cop drags man out of car and brutally beats him  ',
#  'Black students not getting the mental health help they need Research: ',
#  'Every one of us, whether a child or a grown up, should pursue the dreams ',
#  'Seriously? wants Arizona to ban shooting cops without their permission  ',
#  "Cops just don't need a real reason    ",
#  'Took a YEAR! Three Baltimore cops charged with assaulting a man at Sinai Hospital.  ',
#  'Cop faces NO charges after  fatally strangling innocent man  ',
#  "Ferguson's History of Racism   Video: ",
#  'Seems like  is about blaming Obama and Clintons on literally everything ',
#  "Only one question about police and back to immigrants.  doesn't matter in the   ",
#  'Luv it! Cops report that a man drove a tractor over eight police vehicles after marijuana arrest   ',
#  ' cops kill unarmed Blacks and never get punished   ',
#  'Jada Pinkett-Smith have criticised Oscar committee! She is so right!    ',
#  '16yo Gynnya McMillen died in police custody last week. Read and RT this  ',
#  "What? Cop: Buy these tickets or I take your car Ain't that illegal AF?  ",
#  '   Find an action near you  ',
#  ': "This is a time for vigorous and positive action."  Action!  ',
#  'Thy shalt not take Tylenol but after  Cop beats ya in the head ya gonna need that Tylenol  ',
#  "Bet he'd say he feared for his life, the judge will believe him, then walks free    ",
#  'Just perfect ',
#  'Sounds like a victory!  ',
#  'Study shows 45 percent increase in death by cops. Mostly among non-whites.  ',
#  'This is a day to honor one man who took initiative and stood up for the minority.  ',
#  '51 years later and the things Martin Luther King said are still relevant  ',
#  'So @realDonaldTrump walks in the bar and...    ',
#  "'@deray finally. GOPdebate aint touched that'",
#  'So we need a police reform. ASAP!  ',
#  "'@FoxNews @HillaryClinton proud to be traitor?'",
#  "Henry Bennett was shot by PBSO deputy on Saturday Cop's name not released. No video of shooting. Nothing  ",
#  'People arrested in LA while protesting the killing of   ',
#  '‘You’re Lucky I Didn’t Shoot You In The Head’!  ',
#  'Shot over 10 Times by cops: the CJay Pettit story  ',
#  'What? Mysterious malfunction?  ',
#  'Black means Beautiful ',
#  'Sick! Alabama hit with KKK flyers, wishing the civil rights icon a “Happy Birthday” just before    ',
#  "'@deray republicans just enjoy doin that'",
#  'Johannes Mehserle, the cop who murdered , did 1 year in jail and is currently still a COP!  Justice? No ',
#  'This proves that police violence doesn\'t happen because of "black on black crime"   ',
#  'Numbers     ',
#  "'@realDonaldTrump come on! Beat the establishment!'",
#  'Cop “Accidentally” Fires 27 Rounds at Own Mom.  "Accidentally" means no need for charges.  ',
#  'White Privilege and its results for all others in USA ',
#  'This cop assaulted 13 black women. Now  is sentenced to 263 years in prison   ',
#  'Will Smith joins wife in not attending the Oscars   ',
#  'Oscars have consistently cinematically robbed Black America     ',
#  "'@ShaunKing justice should be served!'",
#  'DA to have press conference at 7:30PM    ',
#  '“It destroyed a whole family " This cop raped a 15yo girl since 15     ',
#  "'@gloed_up @genericpanic bet those who decided are white AF'",
#  'The  decision would probably be handed down in minutes  ',
#  'DeKalb officer Olsen indicted on all 6 counts in death of Anthony Hill. Arrest warrant issued  ',
#  "Black students speak out on Wheaton's Larycia Hawkins 'problem' Read this   ",
#  'All SIX COUNTS! This is HUGE VICTORY!     @deray  ',
#  '“It destroyed a whole family " This cop raped a 15yo girl since 15     ',
#  "What? Cops who killed Michael Marshall won't be prosecuted  ",
#  'Wow! Homeless Black man saves family from fire. Says "I\'m not a hero\'  ',
#  'Tonight, we celebrate. Tonight, we won! All this would be impossible without @bridgie_xoxo  ',
#  'Tonight, we celebrate. Tonight, we won! All this would be impossible without @bridgie_xoxo   ',
#  "'@thewritelady @RebelMouse ty!'",
#  "Sandra Bland's Arrest Was Cop's Fault. Justice would be served!    ",
#  'Just imagine        ',
#  'Being black be like      ',
#  'when I think I got a handle on shit in my life ',
#  "Being white 'protester' be like: warm food, Wi-Fi and no violence from cops  ",
#  'Missed this  protester interrupts @usmayors event   ',
#  'Simple   ',
#  "'@msgdi8511 @usmayors some people recognize threat in literally EVERY black person'",
#  '  ',
#  ' Is coming to Netflix  ',
#  'Walsh and March are off the streets cuz their reports contradict what is seen on video. Oh really?  ',
#  'No parole for  leader who killed Black teen with a crossbow  ',
#  '13 Honest books about  young people should read  ',
#  ' St. Paul wants to charge  cop who posted  “Run them over” in advance of protest they held ',
#  'Redmond, Wash. Black store owners find  robe, rope left for them  ',
#  '? NO Kwame Kilpatrick vs Rick Snyder    ',
#  "'s victims: Our lives changed forever!    ",
#  'Academypresident Cheryl Isaacs  promised to bring  diversity to future shows    ',
#  'The story of Akai Gurley who was shot by cop in Brooklyn   ',
#  'HBO Ordered a  documentary after    ',
#  "America's prosecutors: 95% white and 79% male  Equality? Justice? Diversity? NO NO and NO  ",
#  'Never forget. Never give up   ',
#  'How about being Black woman in Hollywood?  ',
#  "A boy gets kicked outta school for saying 'ISIS' but this is perfectly acceptable?  ",
#  'Won a lottery, spent money on gifts 4 ppl in need Killed 2 months later in home invasion  ',
#  'Voting? Nah Cleveland grand jury never voted to indict the cop who shot   ',
#  'Flint’s water system should be fixed asap  ',
#  'Tennessee cops profiting off drug trade?  ',
#  ' shot this man in the head Now he is suing the dept for $6mil  ',
#  'On January 24, 1956, Emmett Till murderers made magazine confession    ',
#  "'@ShaunKing @MichaelsStores cant say N word? Write it'",
#  'History repeats. Cops hide behind the badges just like men hid under white hoods   ',
#  "'@vickijee well tbh I actually support a citizen's right to own a firearm. Not an issue'",
#  'Great job standing your ground! Black man schools cops on his rights  ',
#  'So you got poisoned. Now pay for it! This is what rebellions are made of.  ',
#  'The  murals in a school ',
#  "Just a sacrificial lamb. When ALL cops are held accountable, I'll be happy.  ",
#  "In the coming months, we'll know if those to blame were criminals or merely incompetent jackasses  ",
#  'The fuck? Cops be like: lets hire some murderers.  ',
#  "I'll just leave it here     ",
#  'Half of young black men in Chicago out of work, out of school  ',
#  ' sum up  ',
#  "'@RemyKyd the worst part'",
#  'Tf? Man tried to save his dogs from burning house. Got beaten and arrested by !  ',
#  'Reality of   ',
#  ".@_KrisJStewart on : 'Instead of complaining, do Something' Ok. Like dis?  ",
#  'Must read. Understanding white supremacy  ',
#  'Being black is not a crime!    ',
#  "'@BJSolomonCarson my bad.  ",
#  'Reality we are facing every day      ',
#  'Not the way it should be  and   and      ',
#  'More  babies aborted than born alive in NY  ',
#  ' is beautiful and always will be!    ',
#  'So powerful!  made the @TIME cover   ',
#  "Cops be like 'I swear to  and '  BS!       ",
#  'Anyone else wondering about this? Help spreading this     ',
#  'Must-read  ',
#  'Powerful historical photos: Black Americans even had to fight for the right to use the ocean  ',
#  "Today's  protest at Albany City Hall    ",
#  "'@No1TopHatFanboy feeling of absolute weakness'",
#  ' called 911 on the day he was shot by   ',
#  'Some truth   ',
#  'Happy birthday Dr. Angela Davis!    ',
#  'We stand with you! Militia will take up arms to defend flint If necessary  ',
#  'New excuse! My muscles feared for my life Cop blames ‘muscle memory’ after  shooting unarmed driver  ',
#  'Obama bans solitary confinement of juveniles!      ',
#  '"R" girl from N-word T-shirts photo apologizes, says she is not    ',
#  'They blind?? NYPD  zapped wrong man. Victim will file $5M lawsuit  ',
#  "TF? Man ACCIDENTALLY thrown in the steaming shower? Dat's BS  ",
#  'But we will. We will talk and act!      ',
#  "Don't let em mind fuck u   ",
#  "'@dijoni @No1TopHatFanboy @RemyKyd Never forget. And never stop fighting'",
#  'White ppl be like "I have black friends crowd, I\'m not racist cuz my bf is black". Dont be deceived by fake smiles ',
#  'Acquiescence - agreement or consent by silence or without objection     ',
#  "Tell me how  doesn't exist     ",
#  'Sick! What next? Braiding salon hiring only white women    ',
#  'Rest in power    ',
#  'Different shades of ! ',
#  'Dont be afraid to    ',
#  'How ,  and  are all connected  ',
#  'Dozens seeking challenge of remaking  police force   ',
#  '4 years later They just be in jail.     ',
#  'A Minnesota cop on  used his FB acc to instruct ppl how to kill black protesters and go unpunished  ',
#  'Feds are forcing policing reforms on . ',
#  'Cop used chokehold on  Protester  ',
#  "'s daughter endorses @BernieSanders   ",
#  ' be like ',
#  'To see young black women coming together in the face of these ignorant girls is a beautiful thing  ',
#  "'@BlakeDontCrack tryna set new record'",
#  'Flint organizer advising  On    ',
#  "'s murderer had broken his dashcam on purpose  ",
#  "'@politicalseason @Maat_Justice ",
#  'Injustice in Louisiana: 16-year-old got life without parole for throwing one punch @nytimes ',
#  'Black school kids in US are beaten  disproportionately  ',
#  "Nah! Never met those 'all cops' ",
#  'Chicago cops hid mics to block audio. Every video is silent  ',
#  'Do conservatives give a fuck about ?  ',
#  'Black woman was chased by 6  Members but cops did nothing!  ',
#  'Cops caught on camera beating  an unarmed man  ',
#  "'@deray Carson forgot to take his pills?'",
#  'Bravo! Love this! Totally lost it at mayonnaise monster lmfao  ',
#  '“Due to the corrupt system, I have a dead child" - Samaria Rice  ',
#  'In case you missed it.  ',
#  'Tell me about equality!   @deray ',
#  "'@markaddisonjr @deray Is a kid at pool more dangerous than 150 armed thugs in federal building?  ",
#  "'@markaddisonjr @deray is a 12 yo black kid with a toy gun more dangerous than 150 armed bigots?'",
#  'Is this accurate?      ',
#  "You can't separate peace from freedom because no one can be at peace unless he has his freedom. ",
#  'Since Xmas, cops in US have killed 14 people. Twice as many people as the British police have killed since 2011! ',
#  'Anyone?         @deray @LeftSentThis ',
#  "'@deray yeah right. What about their guns? They seem less threatening than Tamir's?'",
#  'Or maybe a 12 year old black kid with a fake gun. Or a guy with a clock    ',
#  "'@Billysmithjr33 should i remind you it was open carry state?'",
#  "'@Billysmithjr33 he didn't point point a gun at anyone. Watch the video'",
#  "'@Billysmithjr33 that was like minute before cops arrived'",
#  "'@Billysmithjr33 All they had to say was put the gun down. They dont train cops like that to pull up and basically do a drive by shooting.'",
#  'Cop killed teen, crashed patrol car while high on crack. Still a cop  ',
#  'More black parents to consider homeschooling due to   ',
#  'Can anyone explain this shit?  ',
#  ' cracks down on  cops —  record everything  ',
#  "Didn't know this @SenSanders     ",
#  "'@AshaBurwell Be strong!  Tell us how we can support you!'",
#  'Dear white ppl! Please stop trying to make yourself oppressed   ',
#  'Another example of cops  escalating an incident  ',
#  'Join Us!!! We need All Of  !   ',
#  'WTF???? @Migov currently has a $575M budget SURPLUS  ',
#  'Sexual violence by  deserves the same attention as the Catholic Church scandal   ',
#  ' went to jail monday, but he’s since vanished  ',
#  "America's need for more black male educators  ",
#  'Detroit teachers sue district over horrible conditions  ',
#  'They don’t want us to protect ourselves       ',
#  "There's always an excuse to justify white people.   ",
#  "'@BlakeDontCrack we should be able to protect ourselves!'",
#  "'@ShaunKing justice in America...'",
#  'White Supremacy Has always Been a War of Power Against Blacks in America  ',
#  ': A Mother’s Response to the  Decision  ',
#  'Govt Pays Millions in Reparations to 57 Victims of this cop. He Still Receives a Pension  ',
#  'Only 5 years? U fuckin kidding? Cop Gave Under Age Girl Ambien to Drug Her, Then Raped Her  ',
#  'Back in the sixties cops organized the mobs to attack black protesters. Cops were always racist. Nothing changed ',
#  '1,200 people killed by police in 2015. 0 cops in jail today 0 convictions Justice? Definitely NO  ',
#  'Chicago cops tried to intimidate Laquan McDonald witnesses  ',
#  "'Raise your kids not to play with fake guns stupid b*tch'  Cop to Tamir's mother Gets paid vacation after that. WTF ",
#  'NYPD Cops act like the Mafia extorting $1k per week from the  pizza shop owner  ',
#  'Off-duty cop sends Maryland State Troopers on a high-speed chase. Gets paid vacation instead of being arrested!  ',
#  '18 cops were arrested for unjustified shootings in 2015. Not a single cop convicted  ',
#  'How to get a paid vacation as a cop 1 Break the law 2 Get vacation  Da phuck? ',
#  'This cop beats and rapes pregnant women. Still not fired  ',
#  'Just think about it     ',
#  'The Deadly Consequences When  Lack Proper Training to Handle  Calls ',
#  ' are made out of brown sugar, cocoa, honey and gold…  And the strength of ten thousand moons ',
#  ' that Laughed about Flash Banging a Toddler, Was Just  By Murderous Rogue  ',
#  'Cop Shoots Mentally Ill Woman in the Chest. Officer Was Justified ',
#  '    ',
#  '      ',
#  'Nobody has the right to take away someone’s freedom      ',
#  '4 those who r out there in  RN  I love U  U can make me happy by posting pic of u w/ a  sign   ',
#  ' refuses 2 file charges against cop, who shot . unlikely the grand jury own will file charges. ',
#  'ATTENTION! remember this motherfucker? you can help get this DANGEROUS  off the streets   ',
#  '',
#  '"Are they for real?"     ',
#  'So now they say  shooting was reasonable! seriously? 12 y/o boy with a pellet gun... smell it? I DO ',
#  'You never become a howling success by just howling.',
#  '2k15 makes me feel the same way... ',
#  ' crowds in  under the banner of “” for 20th anniversary rally. ',
#  'Same shit But now in color today     ',
#  'Look at this bullshit!��� SO topical! everybody be talking about  RN. Not  no no no ',
#  '  We Got The Power ',
#  " legal in Ohio, but , shot'n'killed for open carrying TOYS Fake Gun - Real Tragedy  ",
#  'Utter bullshit! Anyone can be brave with a badge, a gun & a back-up unit round the corner.    ',
#  " legal in Ohio, but , shot'n'killed for open carrying a TOY Fake Gun  Real Tragedy  ",
#  'ISSUE:  SOLUTION:  ',
#  ' high school  grabs 14 y/o by throat, slams teen to ground (VIDEO)  ',
#  "'@richboyric @SweetAs_Kai Probably the same stuff as Ludacris ",
#  'The patron saint of the internet is Isidore of Seville, who tried to record everything ever known ',
#  "I'm about to get my Deray on @deraysvest ",
#  '“If  Was White In a Cardigan and Nikes Would that  have thought twice and Stopped and Gave Advice” ',
#  'Photo taken by the  at the     ',
#  'Two leaders of the future generation at the  in Washington DC    ',
#  " lead singer Steven Tyler told  2 stop using 'Dream On'. Because Fuck you, thats why ",
#  'This is precisious! Young feminist warrior on the Million Man March.    ',
#  'This is precisious! Young feminist warrior on the Million Man March today.    ',
#  'Go down in history, baby  ',
#  'Remember  killed by Police in 2014     ',
#  'Dark times. ',
#  'stay to myself cuz these niggas is corny ',
#  'This is what i call a real struggle in America  people have to eat,too ',
#  ' Withhold videos despite vows of transparency  So there is a fair question if  are really working? ',
#  'We need ! So…Release the tapes. ',
#  ':  accused of  a girl at the gunpoint was justified ',
#  'When she asks if your finger game is strong... ',
#  'The reason 50 cent declared bankruptcy    ',
#  ' ',
#  " ran from nothin' but the  ",
#  'Cole at the   in Washington DC ',
#  'Fired Kalamazoo prosecutor gets jail, probation for drunken driving crash ',
#  'fuck you miley ',
#  'WHY THE HELL THEY WERE NOT PUNISHED? are u fucking serious???     ',
#  ' covered w/ the most stupid reason to kill an unarmed man     ',
#  'white VS black people  lol ',
#  "stop being mad ppl we won't stop it at all ",
#  "'@nettaaaaaaaa was arrested filming a direct action of civil disobedience   ",
#  ' is more afraid of black unity than  rage. —     ',
#  'It’s hard out here for a troll ',
#  'Selma 50 event today. See Congressman John Lewis’ feed, of course deray and the  tag ',
#  'IMPORTANT UPDATE! SPREAD IT! TWEET IT! BE THERE! ',
#  "'@marclamonthill @carolsonlyboy yes bro  should we speak 'bout justice or else?'",
#  '     ',
#  " we won't forget ",
#  '      ',
#  '“If I didn’t define myself for myself, I would be crunched into other people’s fantasies for me and eaten alive.” - Audre Lorde',
#  'wow thanks for support bae  ',
#  "'@GoddessKerriLyn @AnasuyaIam equality is the only way to stay alive'",
#  '   ',
#  "there's no reason to turn in white ",
#  'perfect bro ',
#  'last year perfect twitt ',
#  "'@AnasuyaIam @GoddessKerriLyn oh yes honey  I agree so'",
#  'wise thoughts ',
#  "'@4mysquad No need for cancerous tanning. Bc of Melanin we do not age as quickly as non-Blacks. '",
#  'We’re using Baltimore’s economic assets for job creation at all skill levels. ',
#  "'@MayorSRB some people are using Baltimore victims for their benefit'",
#  "'@CulpritEnter @amandvbynes their wet lips you know lol'",
#  'I love yours and mine and ours. If reincarnated, i wanna come back Black. ',
#  '  Woman beaten and tackled by Florida  4  of her husband. ',
#  "parents: so what'd yall do when we were out of town   me and friends: um... just chilled.. *has flashback* ",
#  'We have nothing to lose but our chains     ',
#  '"Why\'d u cheat on me" ',
#  ' drew crowds to National Mall in Washington under the banner of  ',
#  'Calls for change at 20th anniversary of Million Man March ',
#  " accused of Inflation nightclub cover-up: 'We are the police and we decide what to do'   ",
#  'Chief Defends “Good ” Who Pepper-Sprayed Man For No Reason as He Walked Down the Street     ',
#  ' VIDEO Cindy Hahn sues City of Carlsbad  Assault caught on tape     ',
#  'Round Rock High police incident caught on camera       ',
#  ' Video Released In The Death Of 21-year-old       ',
#  "2 Reports Say 's  of  Justified      ",
#  ' Councilman Tazed While Defending Friends Being Questioned By The Same Officers Who Arrested   ',
#  'such tactless mudslinging        ',
#  ' holds up the mirror of truth to        ',
#  ' is fucking up so .      ',
#  'While On Desk Duty for Kicking a Cuffed Man in the Face, Cop Manages to Beat an Innocent Teen  ',
#  ' and their tense closed-doors meeting with      ',
#  'Being  in  vs being  in America     ',
#  'These are the people who police the       ',
#  'Black and unarmed!     ',
#  'When you are not trying to hear      ',
#  'society makes these assaults happen,not the perpetrator.Or skewed investigation.Or anything but actual responsibility ',
#  'The same shit       ',
#  'Taxpayer Money Could Be Used To Defend Daniel Holtzclaw In Civil Suit     ',
#  'No matter what they say  have less opportunities in life than white in  ',
#  'This is what i call a real struggle in  ',
#  'This is important.       ',
#  'one in a million wanted  and would have to pay for it     ',
#  '1% of the police officers are convicted in crimes  compared to 94% of the citizens   ',
#  'wow ',
#  'Colin Kaepernick to start this Sunday for the San Francisco 49ers ',
#  "CRAZY! A 14 yr old child who can't pay a small fine to a court can end up in an adult prison instead.  ",
#  "Me when it's time to code-switch for an interview:    ",
#  's/o to this literal icon ',
#  "[RECORD SCRATCH] [FREEZE FRAME]  AMERICA: Yep, that's me. You're probably wondering how I got myself into this. ",
#  "'Mommy,am I gonna die':Mom of 5year-old Ohio girl accidently shot by cop trying to subdue dog says officer left scene ",
#  ' was accidentally shot by a Columbus police officer who was trying to subdue a charging dog  ',
#  'Video Clears Man (M. Jeter) and Cops are Charged!  WATCH ',
#  'LMAO  ',
#  'lol ',
#  'damn straight ',
#  ' beat up and seem to break black teens arm for getting money out of his ATM ',
#  'yes. absolutely right bro ',
#  "Don't take NO for an answer. Agitate against white supremacy.  ",
#  'bastards ',
#  'Video shows  tasing a bloody, restrained  in the testicles before his death.  ',
#  ' Runs Down Suspect with Truck,Beats & Tasers him in the Head, Dept Says it was an Accident   ',
#  'Palestinian Child Bleeds to Death while Israeli Police&Civilians Watch, Shouting Insults    ',
#  'Cleveland  officer charged with abduction appears in court    ',
#  '2 deputies fired after fellow deputy shot in sting     ',
#  'NY Police Say Viral Video Showing  Choking Man Was Actually Life Saving Attempt there was no f*ckin reason ',
#  'Former Cleveland  chief awarded his service      ',
#  "'@87_cjohnson totally bro. fat pigs'",
#  'lil black girl is runnin from police officcer ',
#  '3 charts that show police forces still have a  problem     ',
#  "'@_JujuBean12 @No_Biggy_ awful gif image dudes'",
#  'Smart kid! ',
#  "'@Kilameri1 Since the childhood she has to fear'",
#  "'@87_cjohnson yes. black children to grow up in fear. why the f*ck can't it stop'",
#  "'@4mysquad She's learning early to run away, from a Brutal Murderer!'",
#  "'@4mysquad Our Government, Supreme Court, Congress, and the DOJ are intertwined in Bigotry and Racism, the DOJ commands Brutal police force!'",
#  "'@Briizayy__ @Simone101xo awful scene'",
#  'Photo: Badge privilege\xa0     \xa0\xa0 ',
#  'Nicholas Kristof:Gun deaths more numerous for preschoolers than police     ',
#  'Border Patrol agent indicted in 2012 fatal shooting    ',
#  ' Taser kneeling  councilman in  town where  was arrested   ',
#  'Fairfax tickets cars for needing inspection — while they wait for inspections    ',
#  'Cleveland  Justified in Killing 12-Year-Old , Reports State    ',
#  'Councilman Tasered in  over Crime of—Actually There Wasn’t Even a     ',
#  'Me lol ',
#  "when I'm extremely high ",
#  'Me asking for        ',
#  "When I hear people say there's no racism in       ",
#  '       ',
#  'Dank Pineapple Express Nugs � ',
#  'who is the most pretty girls      ',
#  '     ',
#  '      ',
#  'Miss Fantasy       ',
#  'smoke it     ',
#  '     ',
#  'I know when that hotline bling That can only mean one thing �   ',
#  "'@Imaumbn hey c'mon I think snickers isn't the worst desicion'",
#  'Mix ',
#  '       ',
#  'lol i cant ��     ',
#  'True     ',
#  'for real ',
#  'for real tho ���dudes I love you all  ������ ',
#  'who can relate to this? ����     ',
#  ' is what we seek       ',
#  ' “ White People Be Like”...     ',
#  "When you get the cops called because a 'Hispanic-looking woman & black man with a suspicious white truck & camera' are near a school � ",
#  'Colin Kaepernick wore pig socks, took a knee in protest, picked out his fro, did NOT back down, spoke his mind and then got his job back: ',
#  '⚡ Report: Actor Tommy Ford has died at 52   ',
#  'Yes, they are. Yes, they are. Yes, they do. ',
#  'Institutionalize racism at its best ',
#  'Transgender woman found dead in Cleveland with plastic bag around head ',
#  'R.I.P. ',
#  "LMAOOOOO @R3troSp3ctro ON  I'M DEADASS CRYING RIGHT NOW ",
#  "Why isn't this all over twitter?         ",
#  'Daughter calls 911 to help suicidal mother,   her by mistake, then  her mom ',
#  "'@deray @ShaunKing @ReverantRevan @christwords199 @foolishchicka @Kilameri1 @ElleLamar @ZaRdOz420WPN @BWorthingtonIII ",
#  'so yall niggas ain’t fuckin with this cake i baked ',
#  '17 y/o   was killed by a  after flashing his brights. This is depressing  ',
#  "'@elise_flowers fucking bangbangers smh'",
#  'This Man survived a  and became an activist    ',
#  ' has created a corrosion in the justice system of our country We got to fix it ',
#  '  officer clearly stalking man by reason of intimidation tactics. rediculous!  ',
#  '✊�✊�✊� ',
#  'HE SAID  AND I APPROVE THIS MESSAGE!     ',
#  'It is NOW     ',
#  '  He has got my vote ',
#  "'@4mysquad Then I suppose this will have to do until then. ✊⚖☮☯✏ United we stand. ",
#  '‘CUZ THERE’S NO “BUT” IN DIS, BITCH   ',
#  'California starts new Law that says  must get a  2 use   It Works  ',
#  "'@IAmKenyaGrace oh boy U looooove to hear compliments! Good thing I love 2 say em. Youre DOPE! ������'",
#  "'@imindigomoon oh boy U looooove to hear compliments! Good thing I love 2 say em. Youre DOPE! ������'",
#  'Our people are dying...We must unite',
#  ' Missing/Murdered 235 cases of  Girls! ',
#  'Every time something Bad happens all people want is the  Today it is a rarity   ',
#  'Police STILL stonewalling about the killing of . October 14, 2015   ',
#  'no way dude ',
#  "'@KeeganNYC @ReverantRevan THE POLICE IS RUNNING OUT OF FUCKS TO GIVE ABOUT CITIZEN'S LIVES!'",
#  "How search interest in  spiked during last night's debate: ",
#  'During the "talking" period and you realize she might be the other half you been missing: ',
#  "'@imindigomoon this is usually triggered by music, related to those memories'",
#  "Where do all those 'fired'  go?  Police welcomes them with open arms  ",
#  'Son of a bitch ',
#  ' teens age 15-19 are 21 times more likely to be shot by police than whites are.  ',
#  'Help Iowa  as a campaign organizer!  Apply here: ',
#  "'@meechonmars @cuntxmuffin_ Bae, Its not you, Its me.....'",
#  '"According to the FBI’s Uniform Crime Report, white Americans are responsible for 69.3 percent of crime." ',
#  '69 � ',
#  "We're not talking about a murder mystery here ",
#  'Oh shit. I totally forgot about this. Watch: Michelle Obama Slams Hillary  ',
#  'Woman accused of open container but bodycam shows cop saying "you have an attitude, you\'re under arrest too then"  ',
#  'So... my cousin is trying to teach his cat to use the toilet "to save on kitty litter"  My dude, WTF is this shit?!?  I gotta get my own apt ',
#  '90% rapes go unreported Of those reported, only 30% go to trial Of those who faced trial, only 1/3 were jailed   ',
#  "Come on y'all, spread the word. ",
#  "'@SARAH2TURNNT I always tell people about their screwed hoods and unzipped bags, just reserving a table in heaven for myself ☺️'",
#  'Ima spray some on you ',
#  'mmmmOh my God � ',
#  'this truth tea is scalding ',
#  'Bae       ',
#  'Sixth Tucson police employee terminated in prostitution probe ',
#  'Resisting charge dropped against woman in heated traffic stop w/ deputy   It works ',
#  ':  Ignore it… and it won’t go away!  ',
#  'and N.W.A. Playing    ',
#  'when your mom comes home and there’s a fork in the sink and you ain’t take that damn chicken out the freezer ',
#  'She’s beauty, she’s grace   She puts panties on her face ',
#  'oh shi....    ',
#  'Bae:  ',
#  'YOU: ',
#  " band together, use  2 help convicted CHILDMOLESTOR Cop get lighter sentence 'serve and protect' ",
#  ' Officer violently arrests, injures cyclist 4 not wearing a helmet video: ',
#  'Alabama man shuts down cops who questioned him for jogging  — and it’s perfect ����  ',
#  'No justice. No peace.  ',
#  'How  comes up with his ideas  ',
#  'current mood: irritatingly sad ',
#  '& every time u hear a black person speaking as loud as possible,sb is going 2 say:‘Look at those niggers over there’ ',
#  "'@christwords199 Trump is always on the wrong side of the argument smh'",
#  'I present this w/ no comments ',
#  'IS THIS FOR REAL?      ',
#  'This shit is NOT OK, Officer! Tackling 14 y/o non-violent  w/ a chokehold? Bad move, Officer! ',
#  '  ',
#  'All of them ',
#  'LIT     ',
#  ' officer slamming 15 y/o  at William Tolman High School in Pawtucket  ',
#  ' Destroyed birth certificates, medication, IDs in  homeless raid more here: ',
#  'State makes it legal to  in self-defense if they violate your rights.  is That the solution? watcha think? ',
#  "'@4mysquad Flag down Flagrant Unsportsmanlike Conduct Lifetime Ejection From the Team Additional Sanctions To Follow ",
#  'But thats gay  (ƃuᴉʞoɾ ɯ,I) ',
#  "'@christwords199 covering murder with homicide... thats not math where two  negatives make positive'",
#  "'@christwords199 but fuck yeah, I'll shoot a cop, who is trying to take me down 4 nothin'",
#  "Jus' want to be clear:  simply means that the lives of African-Americans matter. That’s all. ",
#  'When I meet her vs. When I meet her parents ',
#  ' Stands With MU   ',
#  ' won the  in 1964. This Wednesday (14th) is a day of commemoration of his achievement. ',
#  'That. Was. Awesome.      ',
#  'That. Was. Awesome.     ',
#  "'@4mysquad  Trump never has stated, which side of the Black lives Matter debate he is on. ",
#  'still the most crusial issue above all in the United States   ',
#  'If I die in police custody, I didn’t commit suicide.',
#  " officers' names still secret 3 years after  ",
#  ' ',
#  '�� ',
#  '"Bye Roberta" is the new "Bye Felicia" ✌� ',
#  'We need more good cops to step up and do the right thing. ',
#  'Here’s       ',
#  "'@4mysquad  This we cover each other asses crap must end & not just police  Dr.'s/Dr.'s Lawyers/Lawyers Christians/Christians Priests/Priests'",
#  ' Officer guilty of felony 4 lying about arrest of  photographer ',
#  'ALL  are scum bags and get exactly what they deserve! everyone HATES cops EVERYONE… ever wonder why?  ',
#  "You  have a power which is backed by societal trust.And you're constantly losing that trust!  ",
#  "Stealing this pic.  Thanks! RT @kidnoble: Almost tweeted something really filthy, but it's 6:58 am. ",
#  'We Need Cops With People Skills! ',
#  '  ',
#  " that's my dream ",
#  'Start a segway gang.   won’t be able to infiltrate it ',
#  "'@ShaunKing  that's my dream'",
#  "'@ShaunKing  that's my dream ",
#  '    ',
#  ' ',
#  'If ever you needed proof that police are there for revenue collection ONLY, here it is.   ',
#  'I wonder how  found the strength to think about other people rather than yourself, I’m not sure if I would ',
#  'Man files civil rights suit against DPD officers. This is LOUD! Read the story: ',
#  ' police will always understate their problems and violence if reporting it is optional ',
#  "'@4mysquad  Man 1 Depraved indifference to human life  8 & 1/2 to Life Because it was a 911 dispatcher on duty. NO Parole. AAARRRRRRRRRGGGGGG'",
#  'Because  is still alive       ',
#  'LMAO no humor ',
#  'I’m just going to leave this right here. ',
#  'SMH ���� ',
#  'So gorgeous.     ',
#  '       ',
#  '    ',
#  'We are the one.We all are power      ',
#  'So Jesus just gonna leave His slides?   ',
#  '         ',
#  'oh no  ',
#  "'@christwords199 ya think his feet have to be dirty than? LMAO'",
#  'Courtesy of ',
#  'In case u fail to see how ridiculous u sound saying unarmed people somehow caused their own murder w/their questions ',
#  'I’m dying! Haha     ',
#  "White people can argue reverse racism day in and day out. And I'ma keep shooting back ",
#  "'@menchithekid I'm just copyin their behavior'",
#  "'@menchithekid or you think I'ma rasist bae???'",
#  "'@menchithekid let me know the thing bae.don't be silent'",
#  'Keep up the important work MUST SEEEE:   ',
#  "'@menchithekid so now i'm confused'",
#  "'@menchithekid ok bae  keep calm'",
#  'Bruh lolol     ',
#  "'@4mysquad My brother locked his door, ONCE The next day all bedroom doors were gone Dad: I sold them Buy your own damn doors Doorless a week'",
#  '17 Powerful Quotes About  In     ',
#  'Behind every color skin is a human just like you and me. Please be respectful.  @jesuisalbinos ',
#  'Join us on the albino campaign JE SUIS ALBINOS Please say stop killing albinos on your profile now @jesuisalbinos ',
#  ' underreported serious assaults, skewing  for 8 years (!!!) whooooooops ',
#  "'@4mysquad found you from tumblr, MY GOD�. If you don't get em which yo baddazz✊� ",
#  'Man Freed 25 Years After Police tortured him Into a false confession whooops, a broken life ',
#  'Two Brooklyn  arrested a man sitting in the passenger seat of the vehicle, accusing him of damaging their car ',
#  'Pay $250 Fine or Patrol Car Gets Towed, Illegally Parked  Gets a Taste of  Extortion  ',
#  ' Band Together, Use Blue Privilege to Help Convicted Child Molester Cop Get Lighter Sentence  ',
#  'Officer Previously Arrested For Attempted Murder, Arrested Again For Choking Girlfriend ',
#  'Man Freed 25Years After Police Tortured Him Into A False Confession    ',
#  ' and  among those missing from FBI record of  killings    ',
#  "'@4mysquad   Time to start kicking these donkeys in deep depressions OUT of the police forces across this country. ",
#  ' Officer Guilty Of Felony For Lying About Arrest Of NY Times Photographer     ',
#  ' underreported serious assaults, skewing crime stats for 8 years     ',
#  'Virginia cops try to bully family farm over  sign but ignite furious backlash instead  ',
#  'Remember innocent child sufferings ',
#  'thank you! ',
#  'We hear about  on the radio every day. It is like news about show business   ',
#  'This is what happened when  was asked if  or  during the debate ',
#  '2 Chicago  under investigation for sex trafficking 14y.o. girl     ',
#  'JOE ARPAIO "FAILED IN HIS RESPONSIBILITY,"SAYS PRIVATE INVESTIGATOR    ',
#  'Police union head calls for boycott of pumpkin patch over  sign   ',
#  'Michael Wood, ex- officer, tweets about alleged      ',
#  'Settlement Reached After Witnesses Say Cop Broke Mans Jaw With Kick      ',
#  'Resisting charge dropped against woman in heated traffic stop with deputy     ',
#  'war on cops is the best way to solve the problem      ',
#  "'@4mysquad  Mandatory sentencing. ANY Law Enforcement Officer found guilty of a crime gets double normal jail time. ",
#  "'@4mysquad  Mr Carruthers Sir. Time to retire.   As G'ma would say You stepped in it You don't get to come back inside till the stink is gone'",
#  "'@4mysquad  Of all people, Law Enforcment should know better Call  Congress Insist! Remind them.... I VOTE.... ALL MY FRIENDS VOTE. Thank you'",
#  "'@1017nelle plug in baby'",
#  '“F*** your breath!” - Cops curse unarmed man as he dies after they shot him ',
#  'A man says he was left with broken bones and bruising from an encounter with the police    ',
#  '2 deputies charged with killing a college student in a jail cell have been acquitted   ',
#  'why the police still exists in America if It carries more damage than all criminals gather together? ',
#  "'@meganbrice89 so we must fight 'em'",
#  'we will never forget ',
#  "'@CherriLain I don't wanna sleep honey'",
#  "'@CherriLain I don't wanna sleap honey'",
#  "If you're looking for a Netlix documentary to watch tonight, make it this one about sloths ",
#  "'@ShaunKing I still remember when his cousin reached out to us so long ago. It's thankfully getting good coverage now.'",
#  "I'm told that at least 8 Tolman High School students in Pawtucket have been arrested for protesting the police brutality at their school.",
#  '40% of homes with police in them have reported domestic violence.  The national average is 10%  NFL average is 6%.   ',
#  "Just give me the one in the red dress and I'll be happy.  ",
#  'Mood ��  ',
#  'Deputies Acquitted In Killing Of Inmate      ',
#  'Florida SWAT team halts stand-off to allow white couple to finish having sex    ',
#  'Hidden Camera Gets   Sentenced to Prison for Beating & Terrorizing Innocent People  ',
#  'Why Did A  Shoot Robert Chambers In The Head? Disarm the Police!     ',
#  "California deputy caught on live TV First there're two cops  beating unarmed   than one more monster ",
#  'hey ya all girls wanna be w/us  lmao  ',
#  'Yup. ',
#  'My friend said you got to get a bitch with a big ol meaty booty. They keep you warm',
#  'From Chocolate City to Latte City: Being  in the new D.C.     ',
#  ' sheriff furious Obama took his military tank away: People will die because of this decision ',
#  "Cyclist Bangs On  Officer's SUV in Bike Lane Dispute, Gets Handcuffed    ",
#  'Palm Beach Sheriff’s Office Loses Cellphone, Laptop of Cop Who Shot and Killed Seth Adams    ',
#  'Texas Man Plays “Fuck the ” for Cops Who Pulled Him Over for Retaliatory Purposes While Remaining Silent ',
#  'one more case of   &       ',
#  ' on a high school student      ',
#  'Incident between Round Rock, PD & High School Student Caught on Camera    ',
#  "'@4mysquad Strangely Hispanics r counted twice. Included n White census & a Hispanic category. Y count 1 group twice? Atlanta is still Black.'",
#  "'@4mysquad Ur on it tonight! He's an idiot. That's not his tank. He is a replaceable employee. Our tax $'s paid 4 that tank. Citizens own it.'",
#  'Want to see if a police officer has a history of misconduct?These states make it hard   ',
#  ' who shot  used ‘excessive ’ before, lawsuit says   ',
#  'CORRUPT COP GETS MAD WHEN COPWATCH TRIES TO FILE A COMPLAINT AGAINST A COP     ',
#  'Woman Shot in Face by Police Gets $20K     ',
#  'How many people have been killed by police officers in America?     ',
#  'HELP US TRACK IMMIGRANTS KILLED BY       ',
#  "'@xxoCHRISTIANA ",
#  "'@BlazinBrownSkin @deray @yungthugrat @ShaunKing may be its just a guy in Halloween costume?'",
#  "'@brownblaze @Virtuous_Queen_ She was nice btw'",
#  "and they blame THE TRAFFIC SYSTEM. which they say 'allow suspects to move at greater speeds and make wild turns '��� ",
#  "Im not feeling it today. Kinda sick of it today.  All whats left 4 me 's  2 pray. 'Dont let em take me away' ",
#  "'@city_z3n_0wl @MastaOfMp3s Poison!'",
#  "'@HighOffLyfe__ @shezumi @luvgoodspliff thats what you said to your parents?'",
#  "My daddy say i'm geekin' My momma say I'm geekin & when I come around I'm barely fucking speaking ",
#  "'@HighOffLyfe__ @shezumi @luvgoodspliff wow youre a whore! (ƃuᴉʞoɾ)'",
#  "'@deray Doubts? DOUBTS? he is a MAD MAN. I have a permanent confidence that this man is EVIL'",
#  "'@deray she lost it a long time ago.'",
#  'Video shows Officer treating a homeless person 4 NO reason. Now the homeless guy is in jail!  ',
#  'SLAP THAT BITCH ',
#  "'@wizkhalifa Spit on it'",
#  "'@wizkhalifa We just feeling it'",
#  ' this shit ',
#  'I NEED TO HAVE A RIGHT TO DEFEND MYSELF FROM POLICE  2k15 Edition ',
#  'MUST READ ',
#  'Rasheed Wallace is furious about Flint.  And he wants you to know the truth. ',
#  'Google it. Its true. ',
#  ' though ',
#  'Oh Shit  ',
#  'They learned it  ',
#  "I'll never tell anyone to not vote, but I will ask you what's the point of it. ",
#  "'@Itsraddyhoe stop shaming sex workers— especially if you're a beneficiary of their labor'",
#  'Clinton takes money from big oil bundlers.  ',
#  'Chicago probably needs it the most   ',
#  '7 dirty tricks  Officers will use to get what they want from u.   ',
#  'If your posting smoking pics or vids you better have one rolled when I see you.',
#  'beautiful ',
#  'sure, bae      ',
#  'Queen!        ',
#  "I don't wanna HAVE to have that TALK w/ my kids. ",
#  'Why dafuq he smiling? sick bastard      ',
#  "'@deray ",
#  'spread it  ',
#  "'@RE_invent_ED no doubt'",
#  "'- That phrase on the side of your vehicle, sir?  - Oh, Just a PR slogan. ",
#  "'@shezumi 50 shades of gay huh?'",
#  "'@deray swim good?'",
#  'Some letters wore off  To Protect and Serve... Wealthy White People ',
#  "'@wizkhalifa uoeno'",
#  'Think №police can’t use illegally bbtained  against u? Think again. ',
#  "'@ShaunKing @NYDailyNews @RahmEmanuel Youre doing a great job, Shaun. Massive support from StLouis!  luv ya!'",
#  "We're living in a 21st century,    ",
#  'Anyone in the Joliet IL area, be wary of racist Officer Michael Pauly. Record your encounter.  ',
#  'Its really that simple ',
#  "'@wizkhalifa ",
#  'fuck that older brother is in trooooooouble ',
#  "They are also mostly white, so this doesn't impress me at all. ",
#  'What we desperately need is a right 2 defend ourslves from    is tryna do a complete opposite  ',
#  'Ever since I left the city ',
#  ' is now coming 4 our guns Whatever she tryna do - we need THE OPPOSITE.  ',
#  '    Rest in power. ',
#  " Mayor:  backlash makes officers 'fetal' @RahmEmanuel ",
#  "'@deray Bubba the Racist'",
#  ' freaks out and assaults woman 4 taking a tylenol  This is ridiculouis  ',
#  'Woke Af   ',
#  'Shots fired! incompetency is outrageous. Amazing footage WATCH:  ',
#  'Oh Hell no !!! ',
#  'Momma always said to never start a fight, but always be the one to finish it. Thats why im in the movement ',
#  '*Drops mic*   ��� ',
#  'Black City councilman tasered by .officer was also involved in ’s arrest ',
#  'I APPROVE THIS MESSAGE     ',
#  '4 the 2nd time in 6 years, the   constable has found himself under arrest ',
#  'one in a million wanted justice and would have to pay for it ',
#  "Can't say no s**t when I bring that bible quotes!  I love all of these people   ",
#  'Now Facebook lets you order food from restaurants � or buy movie tickets � directly from its pages. ',
#  'I want to experience this ',
#  'Possibly the saddest, most heart breaking "This exhibit is currently out of order" sign ever!! ',
#  'Honestly thought someone was just super excited about the drinks machine ',
#  '"fuck niggers" This is America In 2016. ',
#  'The 2016 news photo of the year contest has closed ',
#  'El Chapo judge gunned down in front of his house in Mexico\xa0 ',
#  'They really not as smart as they try to come off. ',
#  'its that time of year ',
#  'lmao ',
#  'When they talk bout banning guns they bring  shooting But what bout  terror on Black Ppl We NEED  2 protect our lives',
#  'Today I’m so sick of thinking about race, but it’s the first thing on my mind ‘cause it’s the first thing on my face ',
#  'Lit artwork via   ',
#  'Palm Beach Officer Who Killed  Wearing Plain Clothes And Driving Unmarked Car ',
#  "'@LanceBass @MTV Woke AF'",
#  "'@NBCTheVoice @KorinBukowski @ChaseKerby @respektor ",
#  'I give a fuck about MY LIFE do you? ',
#  "'@ChachiBobinks @AndrastesTits @blogdiva @deray  I don't usually political art but here (could be better I admit) ",
#  "'@dxnitrv whats wrong about it?'",
#  "'@ShaunKing Clear themselves... ugh... theyre never gonna be clean'",
#  "Will there ever be any  4  in this country?!  I'm losing faith...  ",
#  "'@ShaunKing come and get these blue pigs. I'll do it myself for all of us '",
#  "Detective Can't Shake Hidden Camera Claims      ",
#  'Maryland police officer accused of biting testicles has left department     ',
#  "'@SugarBeats Thank you 2!'",
#  "Mass. town giving 'tickets' for good behavior       ",
#  'Homan Square revealed:How Chicago police ‘disappeared’ 7,000 ppl    ',
#  'Florida  kill  man who pulled over with car trouble-and then refuse to tell family why   ',
#  'The  Is Using Mobile X-Ray Vans to Spy on Unknown Target     ',
#  'Police Kill Man Who Took Officer’s Gun During Struggle In Downtown     ',
#  'hey right  ',
#  '  Have Disappeared More than 7,000 Ppl at Secret Interrogation Warehouse   ',
#  " was dancin' on the roof while it was a fire   are takin' him on a gurney Respect bro!  ",
#  'Nina Simone to the South African rap game when their biggest supporters are under siege.  ',
#  'Never compromise for anything less than you deserve.',
#  'lmao God  ',
#  'LOL so  ',
#  'oh boo I want you to know yall not alone bae  not alone  w/love ',
#  "'@wordoffar8     '",
#  'Police arrest 23 as students protest tuition fee-hike plan       ',
#  'This is straight up   ',
#  '“The white man’s happiness cannot be purchased by the  man’s misery.” -Frederick Douglass  ',
#  'Words can be weapons by Hidden Foo    ',
#  'Truth about slavery ',
#  'I have a dream my little children will 1 day live in a nation where they wont be judged by the color of their skin, but by their character',
#  ' Shot In The Head.For the second time this month a black transgender woman has been killed   ',
#  'Statistics speak for themselves       ',
#  "'@OGJudy_ common sense is great but each of your fam w/common sense is boring no?'",
#  "'@OGJudy_ hey boopsy i want you to be more polite ugh  '",
#  'How I feel about starting my work on a Monday  ',
#  'LMAO ',
#  "'@Oprah LOE'",
#  "'@Oprah LOVE'",
#  "'@SethMacFarlane SO TRUE'",
#  'FRESH AF ',
#  "'@Drake YASSS'",
#  'Chicago Mayor blames viral  videos for rising murder numbers ...wait what? ',
#  'You know where it is going ',
#  "'@deray  it works'",
#  "Thats the shit I don't like     ",
#  "I'm dead      ",
#  '  have “Disappeared” more than 7k people at secret interrogation warehouse ',
#  "'@JanelleMonae @starwars a black guy!'",
#  'JOE ARPAIO USES FAKE RECALL TO FUNDRAISE ',
#  'Star Wars: : Watch the new trailer ',
#  'Police Officer totally provoking a black man he pulled over, escalating situation but gets no response.   ',
#  'Drake is on FLEEEEEK w/ his new video 4 HotlineBling watch here: ',
#  'Video:"Police officer" in SUV hits cyclist, threatens to arrest.   ',
#  'NYPD officer indicted for allegedly stealing home ownership from dead woman’s family    ',
#  'After his car broke down, Florida church drummer shot and killed by plainclothes officer   ',
#  'Florida Cop Literally Just Shot Unarmed  W/His Hands Up, Begging Not To Be Shot   ',
#  'Cop Runs Down Suspect with Truck, Beats Him, Tasers Him, Then Says It Was All An ‘Accident’    ',
#  'Garner chief  graffiti cowardly a hate crime      ',
#  'Pastor: I held my son while Sacramento deputy shot him to death    ',
#  ' Mayor blames viral  brutality videos for rising murder numbers   ',
#  "Homan Square revealed: how Chicago  'disappeared' 7,000 people     ",
#  'A Turkish police officer pointed a gun at the head of a journalist  is all around    ',
#  'Racial Profiling is Real and So Are Its Lingering Effects ',
#  "'@zellieimani share it! '",
#  '7 ways  break the law, use threats, or lie to get what they want     ',
#  '7 ways  break the law, use threats, or lie to get what they want     ',
#  'BOOST ',
#  'Just lemme know why the fuck  ',
#  'Important AF!!! ',
#  "Video: Metro transit police detained and arrested a teenager after she wouldn't throw away her bag of chips. ",
#  'The U.S. constitution has clearly been violated by these MFs. ',
#  'It’s sad and unpleasant times we live in when people have to ride around with messages painted on their cars..   ',
#  'SATELLITE FEED CUT AS SOON AS CONGRESSMAN MENTIONS WIKILEAKS ON CNN  ',
#  'People: if we just be kind and loving to those who want us dead they will eventually affirm our humanity  History: ',
#  "I always feel blindsided and personally attacked when I'm trying to carry out convos via text and they suddenly call me. ",
#  'I had an ancestor who stole the "settler\'s" hearts so they stole her from her family. GENEALOGY = a decidedly white hobby ',
#  "I won't say who it is.But I'm very thankful      ",
#  "'@AFRICAisMankind he was harmful to all peace. you know all the troubles inflicted by cops'",
#  "'@4mysquad Cop shot 7 year old  n the head as she slept he also killed the dog. No jail. Did he harm ppl 2? Was Animal cruelty called?'",
#  'Former H.S.  Shot and Killed in Virginia After Allegedly Jumping Into Off-Duty  Officer’s Car ',
#  'Federal court tells the DEA to stop harassing medical marijuana providers    ',
#  " teen's family files federal lawsuit over fatal traffic-stop shooting   ",
#  '$2.25 million settlement reached in Painesville police Taser incident   ',
#  'Is that guy carrying a gun?     ',
#  " fired after failing lie detector test as he was questioned over the disappearance of his brother's girlfriend ",
#  'Tenn. lawmakers urged to keep asset forfeiture law intact    ',
#  'DEMON POSSESSED ARGENTINIAN COP FAKE CAR ACCIDENT AND INJURY: THERE IS NO SUCH THING AS A GOOD COP ',
#  ' at the       ',
#  ' 17, 1968: Olympic protestors stripped of their medals ',
#  'fists in the air      ',
#  '“Hold your head up little man you’re a king!”-Nas     ',
#  "For out Gov't ",
#  '',
#  'in  it is    ',
#  'This is the society that I live in. No humanity…no  ',
#  "'@ShaunKing lemme know how can we call him officer? It's total shame. Who to call when police murders'",
#  '  ',
#  ' ',
#  'RIP  ',
#  'more than 920 people were killed by police in 2015 …just in LA',
#  '. @deray everytime you post this I realy proud of us ',
#  '. @deray I dream of   I dream of race would be nothing',
#  'nice bro   ',
#  '. @HendersonKaya Just thank you are with us.   movement is perfect. Happy to be in',
#  "'@ReverantRevan @deray yes man.it is we must be strong'",
#  '. @ShaunKing they hurt us every time they are near by. cops must be more polite to every citizen independently of race and skin colour',
#  '. @ShaunKing @vicenews say if I can help Shaun',
#  "'@hbg1x48 thanx bro! you're welcome 2'",
#  '. @ReverantRevan @deray I just want America to let justice in. That is decision',
#  "'@ReverantRevan @deray I see your point.and I'm agree. Totally'",
#  'cute ',
#  "'@AFRICAisMankind @4mysquad @BlackjediNow @foolishchicka @NewNatTurner @conscious_black @Briizayy__ @MeJoycex Life isn't about what you earn.'",
#  'Ain’t nothin wrong with a lil bit of chocolat ',
#  'Is Cleveland In a State of Ignorance?     ',
#  ' Protesters Attack Trump Supporters ➠ Trump Supporters Blamed For Violence ',
#  'Queen ',
#  'Do you prefer miracle whip ? ',
#  'LMAOOO RT @angelayee: Wale says Meek bought a pencil to a gunfight, a piece of paper and tried to paper cut him to death ',
#  'Agawam woman accidentally shot in face by police files $1.5 million suit in federal court ',
#  'Dog shot by Florida City police officer Animal rescue volunteer says dog shot 3 times in head ',
#  'Animal purposely run over, shot in Collingwood; resident believes animal his dog ',
#  'Owner of dog shot, killed by police files lawsuit for $2 million  ',
#  'NBAer in 1Oak club brawl suing cops and city for $50M ',
#  'Soldier Finds His Former Hero Service Dog Being Abused by a Deputy who Won’t Give Him Back   ',
#  'Drug war is a scam,  is a problem and it’s time to stand up: ‘Unfiltered’ GA $cop tells it like it is  ',
#  'Florida  Murders Pet Dog 3 Feet From Terrified Homeowners in Incident Caught on Video    ',
#  'Florida deputies arrest 9 y.o. boy and post mugshot online, prompting criticism and cheers   ',
#  '  stole 4-story townhouse, DA says        ',
#  'mah fam ',
#  'love that       ',
#  'lemme be     ',
#  'staff ',
#  'Yes     ',
#  'nice art ',
#  'True bro ',
#  'Failed  ',
#  "RIP  Officer Randolph Holder  we never forget the other cops'  ",
#  '"4 police officers murdered in the last 11 months that\'s about as bad as it gets."   Worse than 956 killed by police ',
#  'perfect one ',
#  'CURRY REALLY WILDIN ON THESE NIGGAS ',
#  "Rudy Giuliani looks like he hasn't laughed at a joke since the 1920s so I get why he didn't find that one funny.  ",
#  '',
#  'Artist Sean Hassett created this piece titled “I Am You”, and thought it was so powerful I had to share. Deep.  ',
#  'ʷʰʸ\xa0 \xa0 \xa0 \xa0 ʷʰʸ \xa0 \xa0 \xa0 ʷʰʸ\xa0 \xa0\xa0 \xa0 ʷʰʸ \xa0 \xa0 ʷʰʸ \xa0 \xa0 ʷʰʸ \xa0 \xa0 ʷʰʸ \xa0 ʷʰʸ \xa0 why am i an asshole\xa0\xa0 ʷʰʸ \xa0\xa0 \xa0 \xa0 \xa0 \xa0 \xa0 ʷʰʸ\xa0 \xa0 \xa0 \xa0 \xa0 \xa0 ʷʰʸ',
#  'Reporter confronts white man who calls him the n-word, slave A Virginia man verbally harassed Steve Crump near Mother Emanuel Church. ',
#  'I wish I had teachers like that✊� 2,000 Seattle teachers showed up for work in  shirts. ',
#  "It's official, at 18 years old I co-own B & B's Ice Cream with my parents. Located at 8236 s Racine. COME SUPPORT A BLACK OWNED BUSINESS ",
#  '"Please hold your applause until all of the graduates names have been called"  Black parents: ',
#  'Anthem singer at Heat-76ers game kneels during performance   ',
#  'shit ',
#  'Young Morgan Freeman look like old Morgan Freeman dressed up like young Morgan Freeman ',
#  'Donald Trump has said he wants to bans Muslims, but Hillary Clinton has already bombed Muslims. ',
#  'If he didn’t say he was “live on facebook”, he would have been arrested and assaulted ',
#  'She is gorgeous ',
#  'lmao ',
#  'Little Did He Know ',
#  'The fuck wrong with them? ',
#  'Hey !  ',
#  "'@Virtuous_Queen_ @SweetAs_Kai @watchlar66 @Dontstopnow5 @kidnoble @akacharleswade @SARAH2TURNNT @Russian_Starr @BlackLaughs'",
#  'Hey !  ',
#  'Hey !  ',
#  'Me: damn I have to much to do  Me for 57 minutes: ',
#  'We have to stand up for black children and be prepared to protect them. ',
#  'NAACP demands federal probe after noose allegedly put on black student ',
#  'SOLANGE pro-black and her music has a clear, unapologetic message ',
#  "Students from Steinert High School � this how y'all act? Someone find some  @'s ",
#  'I NEED this! ',
#  "How y'all look at teenage girls when they have an abortion vs how y'all look at her if she keeps the baby ",
#  'Lynching of Thomas Shipp and Abram Smith and a mural dedicated to the white Lynch mob in an urban community hidden in plain sight. ',
#  'Nah, we gotta get this camera off the market. � ',
#  'When your mom show you something "funny" on facebook that you saw on twitter 2 years ago ',
#  'First black, female comic book store owner on the East Coast to appear on variant cover of "Invincible Iron Man ." ',
#  'I don’t think white supremacists have to hide very much in the police. ',
#  'Gucci Mane, ladies and gentlemen. This might be the greatest thing that has ever happened to me. ',
#  'Black high school football player in Mississippi says white students put noose around his neck during practice. ',
#  'How fucking in a motherfucker business to notice four fucking flakes on a dude dashboard. These cops ain’t prioritizing at all ',
#  '� ',
#  'Niya was arrested for challenging police abuse in school. Her story is an important part of our struggle. ',
#  "Then: Me: I want McDonald's  Mom: Do you have McDonald's money?  Now: Mom: I want grandkids  Me: Do you have grandkids money??",
#  'Why Pop Culture Just Can’t Deal With Black Male Sexuality ',
#  'It\'s hard to believe that there are "teachers" like this one  White Teacher Told Blck Students That White People Are More Superior Than Them ',
#  'An affirmative action bake sale from white students at the University of Texas. They actually think they have it harder b/c they are white. ',
#  'Seattle police officer caught lying in the performance of her duties keeps job, raise and PROMOTION thanks to police union ‘agreement’ ',
#  'I respect black women for putting up with daily disrespect. I can’t even imagine that shit',
#  'GTA San Andreas is 12 years old today. Is this the best GTA game or no � ',
#  'But who cares about facts, right? The cops FEEL there is a war being waged against them. ',
#  'Wake yo ass up before you be late to school��� ',
#  'Nigga is that Anne Hathaway? RT @woahaydrian: Dominicans are out of control lmaoo ',
#  '"HARASSED BY POLICE FOR MY HAIR!!"  ',
#  'She was supposed to sing the national anthem – but then they saw her shirt. ',
#  'Haiti President Calls Clinton Thieve Who Should Be In Jail ',
#  'Oh really? So how are the falsely convicted prisoners and their families going to be compensated? ',
#  'A  of Sandra Bland using  of black woman or feminine presenting people. ',
#  ...]

# %%
wordcloud = WordCloud(background_color="white",width=1000, height=860, margin=2).generate(' '.join(content))
plt.imshow(wordcloud)
plt.axis("off")
plt.show()

# %%
wordcloud.to_file('content_without_hashtags.png')

# %%
content = remove_at(content)
content
# Out:
# [' is not a joke!   ',
#  'Thanks God that  i ate few days ago was good.  ',
#  "I hurt easy, I just don't show it. You can hurt someone and not even know it.",
#  "who's got the worst make up ever, don't tell me, mirror",
#  'jade doesn`t love her! ',
#  'Unreal friendship may turn to real. But real friendship, once ended, cannot be mended.',
#  '« The young are permanently in a state resembling intoxication. » Aristotle',
#  'The best thing you can do in your life is to please God. The worst thing you can do in your life is to please everyone.',
#  "Honey, I'll learn! ",
#  'cats giving high fives!!!!! ',
#  'Home is where my bed is',
#  'When the beat drops just keep swinging it',
#  "She gets on you under your skin like a tattoo, she'll always be there, she holds on stuck in your head, like an old song. ",
#  'As usual, there is a great woman behind every idiot',
#  'Music plays a mind trick, watch me forget about missing you',
#  'do u ever look at ur friends like "im so glad these weird losers are mine"',
#  'I consider hitting a girl the most pussy thing a guy could ever possibly do',
#  'When we first met, I had no idea you’d become this important to me.',
#  'what happiness is? Free Wi-Fi!',
#  'Even if my intentions are good, the result is still awful :(',
#  'incredible!!!!! ',
#  'Booty ',
#  'girls winning',
#  'Why did we give a monopoly of creating money out of thin air to a private [Federal Reserve] corporation? – Franklin Saunders',
#  'Despite all the junk food someone still complimented me on my skin',
#  "Love like you'll never be hurt",
#  'so easy I can do them myself! ',
#  "RT if you're ripping that Hustle gang",
#  'queen and anti-queen ',
#  "When love is real, it doesn't lie, cheat, pretend, or hurt you. It cures you of all your worries and makes you truly happy.",
#  'The harder you work, the harder it is to surrender.',
#  '',
#  'you should never care what other people say about you',
#  "Unless you change how you are, you will always have what you've got.",
#  "I'm an instant star. Just add water and stir.",
#  'don`t wear it if !! ',
#  "Took 50 pictures... Don't like a single one. Even IG filters don't help me!",
#  "' gave me shivers...'",
#  'I want my little parrot to speak at last!!! ',
#  'An everyday changing funny church sign ',
#  'I wish look like  ',
#  "Why is someone even against the ? I'll watch you bleeding when some thug shoots your ass off ",
#  'It’s reasonable to ban firearms sales in  areas  ',
#  "' Follow the other half an onion! Mage America Great Again1'",
#  "' Follow another half of the onion. Reveal it's dark side!'",
#  "'  Follow the other side of the onion to Make America Great Again!'",
#  ' defense playing hungry .. Bending and not breaking �',
#  "Let's go offense !!!! Start Up the  !!!!  ... We need to turn up the tempo �� ",
#  "I was shocked and heartbroken when  canceled . I would have shot this show for 50 more years. I'll miss my 2nd family.",
#  "I used to call Eden Hazard 'overrated' as a joke. Nobody's laughing now.  He's dreadful.",
#  'The Holidays are in full swing.  Need gift ideas? Check out my Holiday Gift guide!  ',
#  "My mum had no electricity at here's so she has moved in w/ me. I dressed her up as a � & we are… ",
#  'VOTE for  at  awards. Click here to VOTE: ',
#  "Who’s ready for tWitch & Allison's Dance Challenge? If you know a super talented kid dancer, send in a video! ",
#  ": if trans people 'look like a man in a dress, it makes people uncomfortable' ",
#  "' just tell the horse it won who gives a shit'",
#  '.[2]   ...can share my humanity without shame i see it as an invitation for others to do the same.',
#  'Cleveland Golf + Technology = !!!  Check it: ',
#  'Who wears the pants in ’s family?! ',
#  "' put in so much work on Cabin Fever 3.'",
#  'Tina Fey on The Tonight Show Starring Jimmy Fallon ',
#  '.  and  and ’s  ',
#  "U don't like Carson - u r racist, U don't like Trump - u r loser. That is what tonight's  is about  ",
#  'Some idiotic show on MTV would be more informative than  ',
#  'God is not a franchise of the Republican Party ',
#  ' is the worst candidate for our country ',
#  'Whatever happened to ? Where’s he hiding?  ',
#  "' Why do GOP candidates whine to avoid answering questions?  '",
#  'Trump is an magnate and he doesn’t care about US economy. He cares only about his own money  ',
#  '  All these speeches are empty ',
#  ' Do we really need another ? Every new is worse than the previous one ',
#  'Is there a drinking game for the ? ',
#  "' What are your thoughts on Drake and Meek Mill? '",
#  '  Today we’ll hear a lot of empty promises.  Are you ready? ',
#  'Will corrupted politicians talk about corruption?  ',
#  '  If Jeb loses his wife will lose her last hope to get thr green card ',
#  'It’s just a baby talk  ',
#  "' What is your favorite color... colored person? '",
#  'Common sense isn’t the best friend of the GOP candidates ',
#  "  If Carson doesn't stab Trump it will be waste of time",
#  'Donald Trump at the  ',
#  '"Carter Banned Iranians From Coming To U.S. During Hostage Crisis" ',
#  'Today Only! Save 25% on all 1982 Collection items, and save 40% when you bundle together! ',
#  'What an amazing room today filled with so many strong and inspiring women.. ❤️  ',
#  'You asked. We did it....."Bre 4 Sports Toilet Bowl" !!! Join at ',
#  '�Today\'s the day! My limited edition  lipstick "Von Teese" is now on sale:… ',
#  'Love these wise words from one of the most elegant women ever! : Audrey Hepburn.   ',
#  'but that dont say none of syrian refugees are terrorists ',
#  '   ',
#  ' Thoughts and prayers are with all in Brussels.',
#  'Refugees are not welcome, that my view!  ',
#  ' We may not be at war with Islam, but it sure seems Islam is at war w/us!  ',
#  ' These people need to stay out of America. They are animals. Disgusting animals ',
#  'That\'s it!Not complicated at all. "',
#  '  Keep Canada White',
#  " Why do we destroy ourselves I don't get it, we're destroying our own planet with things like these I'm skdjsiis ",
#  ' This is actually terrifying, love and thoughts go out to everyone ❤️  ',
#  " Why isn't Europe keeping its promise to resettle ?",
#  ' Obama wants to help refugees? Why doesn’t he want to help fellow Americans first? ',
#  "If you don't think all Syrian refugees are terrorists you are part of the problem. ",
#  '  "Immigration without integration is an invasion" prolly smartest thing Bobby Jindals ever said',
#  ' the ‘refugees’ don’t look like those in need, absolutely ',
#  ' "not all refugees are terrorists" not all bears are gonna kill you but do you want bears living in your house',
#  '  All is ok here in Spain. Thank you.  ',
#  " My thoughts and prayers to all the family's who involved in the terror accents in Brussels  ",
#  '  RT : ',
#  '  IS wants to polarize Europe. They seek to create chaos and a religious war between Muslims and non-Muslims',
#  ' but that dont say none of syrian refugees are terrorists ',
#  '    ',
#  "' so? If you pay more taxes you have more rights? This how it works?'",
#  "' some of you?'",
#  'Black Students force the university to divest $25 Million in private prisons  ',
#  "Racist Maine Gov. on 'drug problem'  ",
#  '‘I Can’t Breathe’: Video of  Police Dragging Barbara Dawson from the Hospital   ',
#  'Cop Sentenced To Five Years For Pointing Gun In Man’s Face  ',
#  'Case re-opened. Cop Shoot Man 3 Times as He Was Face Down in Handcuffs  ',
#  "At last! NYPD cop In Eric Garner's Death Faces Departmental Charges    ",
#  'That feel when you find this new great song and listen to it on repeat ',
#  'What the f*ck?  ',
#  'Same old story rich and white your alright. End of story   ',
#  'Obama delivers his final State of the Union address but said nothing about  Why?  ',
#  'Did they count slavery as incarceration?    ',
#  'On this day in 1966,  Johnson appoints first African-American cabinet member - Robert C. Weaver  ',
#  'Cop turns a simple situation into aggressive confrontation  ',
#  "Cop's Passion For Arresting Activists Nah! NYPD does NOT make me feel safe  ",
#  'Chilly  ',
#  'Cop Shot 12yo Girl While Evicting Her Family From Their Home  ',
#  'Idiot Cop Accuses Asian man of Being “an ISIS” and Beats Him  ',
#  'White America Does The Crime, Black America Gets The Time. WTF?   ',
#  'what?    ',
#  'Numbers  is kinda selective.        ',
#  "' what kind of information do you need?'",
#  'A mom and her baby. Some people lose diamonds in search of stones   ',
#  'A mom and her baby. Some people lose diamonds in search of stones    ',
#  'Video of Cedrick Chatman’s Killing by Police will be released     ',
#  'Look to   to make jokes about him being the only Black on stage   ',
#  'Video of cops shooting  released  ',
#  'Somebody  why he completely ignores black issues in final state of the Union Address  ',
#  'Settlement to Freddie Gray’s Family delayed  ',
#  "' worst day of the week'",
#  'Looking for a common sense during      ',
#  'Cop drags man out of car and brutally beats him  ',
#  'Black students not getting the mental health help they need Research: ',
#  'Every one of us, whether a child or a grown up, should pursue the dreams ',
#  'Seriously? wants Arizona to ban shooting cops without their permission  ',
#  "Cops just don't need a real reason    ",
#  'Took a YEAR! Three Baltimore cops charged with assaulting a man at Sinai Hospital.  ',
#  'Cop faces NO charges after  fatally strangling innocent man  ',
#  "Ferguson's History of Racism   Video: ",
#  'Seems like  is about blaming Obama and Clintons on literally everything ',
#  "Only one question about police and back to immigrants.  doesn't matter in the   ",
#  'Luv it! Cops report that a man drove a tractor over eight police vehicles after marijuana arrest   ',
#  ' cops kill unarmed Blacks and never get punished   ',
#  'Jada Pinkett-Smith have criticised Oscar committee! She is so right!    ',
#  '16yo Gynnya McMillen died in police custody last week. Read and RT this  ',
#  "What? Cop: Buy these tickets or I take your car Ain't that illegal AF?  ",
#  '   Find an action near you  ',
#  ': "This is a time for vigorous and positive action."  Action!  ',
#  'Thy shalt not take Tylenol but after  Cop beats ya in the head ya gonna need that Tylenol  ',
#  "Bet he'd say he feared for his life, the judge will believe him, then walks free    ",
#  'Just perfect ',
#  'Sounds like a victory!  ',
#  'Study shows 45 percent increase in death by cops. Mostly among non-whites.  ',
#  'This is a day to honor one man who took initiative and stood up for the minority.  ',
#  '51 years later and the things Martin Luther King said are still relevant  ',
#  'So  walks in the bar and...    ',
#  "' finally. GOPdebate aint touched that'",
#  'So we need a police reform. ASAP!  ',
#  "'  proud to be traitor?'",
#  "Henry Bennett was shot by PBSO deputy on Saturday Cop's name not released. No video of shooting. Nothing  ",
#  'People arrested in LA while protesting the killing of   ',
#  '‘You’re Lucky I Didn’t Shoot You In The Head’!  ',
#  'Shot over 10 Times by cops: the CJay Pettit story  ',
#  'What? Mysterious malfunction?  ',
#  'Black means Beautiful ',
#  'Sick! Alabama hit with KKK flyers, wishing the civil rights icon a “Happy Birthday” just before    ',
#  "' republicans just enjoy doin that'",
#  'Johannes Mehserle, the cop who murdered , did 1 year in jail and is currently still a COP!  Justice? No ',
#  'This proves that police violence doesn\'t happen because of "black on black crime"   ',
#  'Numbers     ',
#  "' come on! Beat the establishment!'",
#  'Cop “Accidentally” Fires 27 Rounds at Own Mom.  "Accidentally" means no need for charges.  ',
#  'White Privilege and its results for all others in USA ',
#  'This cop assaulted 13 black women. Now  is sentenced to 263 years in prison   ',
#  'Will Smith joins wife in not attending the Oscars   ',
#  'Oscars have consistently cinematically robbed Black America     ',
#  "' justice should be served!'",
#  'DA to have press conference at 7:30PM    ',
#  '“It destroyed a whole family " This cop raped a 15yo girl since 15     ',
#  "'  bet those who decided are white AF'",
#  'The  decision would probably be handed down in minutes  ',
#  'DeKalb officer Olsen indicted on all 6 counts in death of Anthony Hill. Arrest warrant issued  ',
#  "Black students speak out on Wheaton's Larycia Hawkins 'problem' Read this   ",
#  'All SIX COUNTS! This is HUGE VICTORY!       ',
#  '“It destroyed a whole family " This cop raped a 15yo girl since 15     ',
#  "What? Cops who killed Michael Marshall won't be prosecuted  ",
#  'Wow! Homeless Black man saves family from fire. Says "I\'m not a hero\'  ',
#  'Tonight, we celebrate. Tonight, we won! All this would be impossible without   ',
#  'Tonight, we celebrate. Tonight, we won! All this would be impossible without    ',
#  "'  ty!'",
#  "Sandra Bland's Arrest Was Cop's Fault. Justice would be served!    ",
#  'Just imagine        ',
#  'Being black be like      ',
#  'when I think I got a handle on shit in my life ',
#  "Being white 'protester' be like: warm food, Wi-Fi and no violence from cops  ",
#  'Missed this  protester interrupts  event   ',
#  'Simple   ',
#  "'  some people recognize threat in literally EVERY black person'",
#  '  ',
#  ' Is coming to Netflix  ',
#  'Walsh and March are off the streets cuz their reports contradict what is seen on video. Oh really?  ',
#  'No parole for  leader who killed Black teen with a crossbow  ',
#  '13 Honest books about  young people should read  ',
#  ' St. Paul wants to charge  cop who posted  “Run them over” in advance of protest they held ',
#  'Redmond, Wash. Black store owners find  robe, rope left for them  ',
#  '? NO Kwame Kilpatrick vs Rick Snyder    ',
#  "'s victims: Our lives changed forever!    ",
#  'Academypresident Cheryl Isaacs  promised to bring  diversity to future shows    ',
#  'The story of Akai Gurley who was shot by cop in Brooklyn   ',
#  'HBO Ordered a  documentary after    ',
#  "America's prosecutors: 95% white and 79% male  Equality? Justice? Diversity? NO NO and NO  ",
#  'Never forget. Never give up   ',
#  'How about being Black woman in Hollywood?  ',
#  "A boy gets kicked outta school for saying 'ISIS' but this is perfectly acceptable?  ",
#  'Won a lottery, spent money on gifts 4 ppl in need Killed 2 months later in home invasion  ',
#  'Voting? Nah Cleveland grand jury never voted to indict the cop who shot   ',
#  'Flint’s water system should be fixed asap  ',
#  'Tennessee cops profiting off drug trade?  ',
#  ' shot this man in the head Now he is suing the dept for $6mil  ',
#  'On January 24, 1956, Emmett Till murderers made magazine confession    ',
#  "'  cant say N word? Write it'",
#  'History repeats. Cops hide behind the badges just like men hid under white hoods   ',
#  "' well tbh I actually support a citizen's right to own a firearm. Not an issue'",
#  'Great job standing your ground! Black man schools cops on his rights  ',
#  'So you got poisoned. Now pay for it! This is what rebellions are made of.  ',
#  'The  murals in a school ',
#  "Just a sacrificial lamb. When ALL cops are held accountable, I'll be happy.  ",
#  "In the coming months, we'll know if those to blame were criminals or merely incompetent jackasses  ",
#  'The fuck? Cops be like: lets hire some murderers.  ',
#  "I'll just leave it here     ",
#  'Half of young black men in Chicago out of work, out of school  ',
#  ' sum up  ',
#  "' the worst part'",
#  'Tf? Man tried to save his dogs from burning house. Got beaten and arrested by !  ',
#  'Reality of   ',
#  ". on : 'Instead of complaining, do Something' Ok. Like dis?  ",
#  'Must read. Understanding white supremacy  ',
#  'Being black is not a crime!    ',
#  "' my bad.  ",
#  'Reality we are facing every day      ',
#  'Not the way it should be  and   and      ',
#  'More  babies aborted than born alive in NY  ',
#  ' is beautiful and always will be!    ',
#  'So powerful!  made the  cover   ',
#  "Cops be like 'I swear to  and '  BS!       ",
#  'Anyone else wondering about this? Help spreading this     ',
#  'Must-read  ',
#  'Powerful historical photos: Black Americans even had to fight for the right to use the ocean  ',
#  "Today's  protest at Albany City Hall    ",
#  "' feeling of absolute weakness'",
#  ' called 911 on the day he was shot by   ',
#  'Some truth   ',
#  'Happy birthday Dr. Angela Davis!    ',
#  'We stand with you! Militia will take up arms to defend flint If necessary  ',
#  'New excuse! My muscles feared for my life Cop blames ‘muscle memory’ after  shooting unarmed driver  ',
#  'Obama bans solitary confinement of juveniles!      ',
#  '"R" girl from N-word T-shirts photo apologizes, says she is not    ',
#  'They blind?? NYPD  zapped wrong man. Victim will file $5M lawsuit  ',
#  "TF? Man ACCIDENTALLY thrown in the steaming shower? Dat's BS  ",
#  'But we will. We will talk and act!      ',
#  "Don't let em mind fuck u   ",
#  "'   Never forget. And never stop fighting'",
#  'White ppl be like "I have black friends crowd, I\'m not racist cuz my bf is black". Dont be deceived by fake smiles ',
#  'Acquiescence - agreement or consent by silence or without objection     ',
#  "Tell me how  doesn't exist     ",
#  'Sick! What next? Braiding salon hiring only white women    ',
#  'Rest in power    ',
#  'Different shades of ! ',
#  'Dont be afraid to    ',
#  'How ,  and  are all connected  ',
#  'Dozens seeking challenge of remaking  police force   ',
#  '4 years later They just be in jail.     ',
#  'A Minnesota cop on  used his FB acc to instruct ppl how to kill black protesters and go unpunished  ',
#  'Feds are forcing policing reforms on . ',
#  'Cop used chokehold on  Protester  ',
#  "'s daughter endorses    ",
#  ' be like ',
#  'To see young black women coming together in the face of these ignorant girls is a beautiful thing  ',
#  "' tryna set new record'",
#  'Flint organizer advising  On    ',
#  "'s murderer had broken his dashcam on purpose  ",
#  "'  ",
#  'Injustice in Louisiana: 16-year-old got life without parole for throwing one punch  ',
#  'Black school kids in US are beaten  disproportionately  ',
#  "Nah! Never met those 'all cops' ",
#  'Chicago cops hid mics to block audio. Every video is silent  ',
#  'Do conservatives give a fuck about ?  ',
#  'Black woman was chased by 6  Members but cops did nothing!  ',
#  'Cops caught on camera beating  an unarmed man  ',
#  "' Carson forgot to take his pills?'",
#  'Bravo! Love this! Totally lost it at mayonnaise monster lmfao  ',
#  '“Due to the corrupt system, I have a dead child" - Samaria Rice  ',
#  'In case you missed it.  ',
#  'Tell me about equality!    ',
#  "'  Is a kid at pool more dangerous than 150 armed thugs in federal building?  ",
#  "'  is a 12 yo black kid with a toy gun more dangerous than 150 armed bigots?'",
#  'Is this accurate?      ',
#  "You can't separate peace from freedom because no one can be at peace unless he has his freedom. ",
#  'Since Xmas, cops in US have killed 14 people. Twice as many people as the British police have killed since 2011! ',
#  'Anyone?           ',
#  "' yeah right. What about their guns? They seem less threatening than Tamir's?'",
#  'Or maybe a 12 year old black kid with a fake gun. Or a guy with a clock    ',
#  "' should i remind you it was open carry state?'",
#  "' he didn't point point a gun at anyone. Watch the video'",
#  "' that was like minute before cops arrived'",
#  "' All they had to say was put the gun down. They dont train cops like that to pull up and basically do a drive by shooting.'",
#  'Cop killed teen, crashed patrol car while high on crack. Still a cop  ',
#  'More black parents to consider homeschooling due to   ',
#  'Can anyone explain this shit?  ',
#  ' cracks down on  cops —  record everything  ',
#  "Didn't know this      ",
#  "' Be strong!  Tell us how we can support you!'",
#  'Dear white ppl! Please stop trying to make yourself oppressed   ',
#  'Another example of cops  escalating an incident  ',
#  'Join Us!!! We need All Of  !   ',
#  'WTF????  currently has a $575M budget SURPLUS  ',
#  'Sexual violence by  deserves the same attention as the Catholic Church scandal   ',
#  ' went to jail monday, but he’s since vanished  ',
#  "America's need for more black male educators  ",
#  'Detroit teachers sue district over horrible conditions  ',
#  'They don’t want us to protect ourselves       ',
#  "There's always an excuse to justify white people.   ",
#  "' we should be able to protect ourselves!'",
#  "' justice in America...'",
#  'White Supremacy Has always Been a War of Power Against Blacks in America  ',
#  ': A Mother’s Response to the  Decision  ',
#  'Govt Pays Millions in Reparations to 57 Victims of this cop. He Still Receives a Pension  ',
#  'Only 5 years? U fuckin kidding? Cop Gave Under Age Girl Ambien to Drug Her, Then Raped Her  ',
#  'Back in the sixties cops organized the mobs to attack black protesters. Cops were always racist. Nothing changed ',
#  '1,200 people killed by police in 2015. 0 cops in jail today 0 convictions Justice? Definitely NO  ',
#  'Chicago cops tried to intimidate Laquan McDonald witnesses  ',
#  "'Raise your kids not to play with fake guns stupid b*tch'  Cop to Tamir's mother Gets paid vacation after that. WTF ",
#  'NYPD Cops act like the Mafia extorting $1k per week from the  pizza shop owner  ',
#  'Off-duty cop sends Maryland State Troopers on a high-speed chase. Gets paid vacation instead of being arrested!  ',
#  '18 cops were arrested for unjustified shootings in 2015. Not a single cop convicted  ',
#  'How to get a paid vacation as a cop 1 Break the law 2 Get vacation  Da phuck? ',
#  'This cop beats and rapes pregnant women. Still not fired  ',
#  'Just think about it     ',
#  'The Deadly Consequences When  Lack Proper Training to Handle  Calls ',
#  ' are made out of brown sugar, cocoa, honey and gold…  And the strength of ten thousand moons ',
#  ' that Laughed about Flash Banging a Toddler, Was Just  By Murderous Rogue  ',
#  'Cop Shoots Mentally Ill Woman in the Chest. Officer Was Justified ',
#  '    ',
#  '      ',
#  'Nobody has the right to take away someone’s freedom      ',
#  '4 those who r out there in  RN  I love U  U can make me happy by posting pic of u w/ a  sign   ',
#  ' refuses 2 file charges against cop, who shot . unlikely the grand jury own will file charges. ',
#  'ATTENTION! remember this motherfucker? you can help get this DANGEROUS  off the streets   ',
#  '',
#  '"Are they for real?"     ',
#  'So now they say  shooting was reasonable! seriously? 12 y/o boy with a pellet gun... smell it? I DO ',
#  'You never become a howling success by just howling.',
#  '2k15 makes me feel the same way... ',
#  ' crowds in  under the banner of “” for 20th anniversary rally. ',
#  'Same shit But now in color today     ',
#  'Look at this bullshit!��� SO topical! everybody be talking about  RN. Not  no no no ',
#  '  We Got The Power ',
#  " legal in Ohio, but , shot'n'killed for open carrying TOYS Fake Gun - Real Tragedy  ",
#  'Utter bullshit! Anyone can be brave with a badge, a gun & a back-up unit round the corner.    ',
#  " legal in Ohio, but , shot'n'killed for open carrying a TOY Fake Gun  Real Tragedy  ",
#  'ISSUE:  SOLUTION:  ',
#  ' high school  grabs 14 y/o by throat, slams teen to ground (VIDEO)  ',
#  "'  Probably the same stuff as Ludacris ",
#  'The patron saint of the internet is Isidore of Seville, who tried to record everything ever known ',
#  "I'm about to get my Deray on  ",
#  '“If  Was White In a Cardigan and Nikes Would that  have thought twice and Stopped and Gave Advice” ',
#  'Photo taken by the  at the     ',
#  'Two leaders of the future generation at the  in Washington DC    ',
#  " lead singer Steven Tyler told  2 stop using 'Dream On'. Because Fuck you, thats why ",
#  'This is precisious! Young feminist warrior on the Million Man March.    ',
#  'This is precisious! Young feminist warrior on the Million Man March today.    ',
#  'Go down in history, baby  ',
#  'Remember  killed by Police in 2014     ',
#  'Dark times. ',
#  'stay to myself cuz these niggas is corny ',
#  'This is what i call a real struggle in America  people have to eat,too ',
#  ' Withhold videos despite vows of transparency  So there is a fair question if  are really working? ',
#  'We need ! So…Release the tapes. ',
#  ':  accused of  a girl at the gunpoint was justified ',
#  'When she asks if your finger game is strong... ',
#  'The reason 50 cent declared bankruptcy    ',
#  ' ',
#  " ran from nothin' but the  ",
#  'Cole at the   in Washington DC ',
#  'Fired Kalamazoo prosecutor gets jail, probation for drunken driving crash ',
#  'fuck you miley ',
#  'WHY THE HELL THEY WERE NOT PUNISHED? are u fucking serious???     ',
#  ' covered w/ the most stupid reason to kill an unarmed man     ',
#  'white VS black people  lol ',
#  "stop being mad ppl we won't stop it at all ",
#  "' was arrested filming a direct action of civil disobedience   ",
#  ' is more afraid of black unity than  rage. —     ',
#  'It’s hard out here for a troll ',
#  'Selma 50 event today. See Congressman John Lewis’ feed, of course deray and the  tag ',
#  'IMPORTANT UPDATE! SPREAD IT! TWEET IT! BE THERE! ',
#  "'  yes bro  should we speak 'bout justice or else?'",
#  '     ',
#  " we won't forget ",
#  '      ',
#  '“If I didn’t define myself for myself, I would be crunched into other people’s fantasies for me and eaten alive.” - Audre Lorde',
#  'wow thanks for support bae  ',
#  "'  equality is the only way to stay alive'",
#  '   ',
#  "there's no reason to turn in white ",
#  'perfect bro ',
#  'last year perfect twitt ',
#  "'  oh yes honey  I agree so'",
#  'wise thoughts ',
#  "' No need for cancerous tanning. Bc of Melanin we do not age as quickly as non-Blacks. '",
#  'We’re using Baltimore’s economic assets for job creation at all skill levels. ',
#  "' some people are using Baltimore victims for their benefit'",
#  "'  their wet lips you know lol'",
#  'I love yours and mine and ours. If reincarnated, i wanna come back Black. ',
#  '  Woman beaten and tackled by Florida  4  of her husband. ',
#  "parents: so what'd yall do when we were out of town   me and friends: um... just chilled.. *has flashback* ",
#  'We have nothing to lose but our chains     ',
#  '"Why\'d u cheat on me" ',
#  ' drew crowds to National Mall in Washington under the banner of  ',
#  'Calls for change at 20th anniversary of Million Man March ',
#  " accused of Inflation nightclub cover-up: 'We are the police and we decide what to do'   ",
#  'Chief Defends “Good ” Who Pepper-Sprayed Man For No Reason as He Walked Down the Street     ',
#  ' VIDEO Cindy Hahn sues City of Carlsbad  Assault caught on tape     ',
#  'Round Rock High police incident caught on camera       ',
#  ' Video Released In The Death Of 21-year-old       ',
#  "2 Reports Say 's  of  Justified      ",
#  ' Councilman Tazed While Defending Friends Being Questioned By The Same Officers Who Arrested   ',
#  'such tactless mudslinging        ',
#  ' holds up the mirror of truth to        ',
#  ' is fucking up so .      ',
#  'While On Desk Duty for Kicking a Cuffed Man in the Face, Cop Manages to Beat an Innocent Teen  ',
#  ' and their tense closed-doors meeting with      ',
#  'Being  in  vs being  in America     ',
#  'These are the people who police the       ',
#  'Black and unarmed!     ',
#  'When you are not trying to hear      ',
#  'society makes these assaults happen,not the perpetrator.Or skewed investigation.Or anything but actual responsibility ',
#  'The same shit       ',
#  'Taxpayer Money Could Be Used To Defend Daniel Holtzclaw In Civil Suit     ',
#  'No matter what they say  have less opportunities in life than white in  ',
#  'This is what i call a real struggle in  ',
#  'This is important.       ',
#  'one in a million wanted  and would have to pay for it     ',
#  '1% of the police officers are convicted in crimes  compared to 94% of the citizens   ',
#  'wow ',
#  'Colin Kaepernick to start this Sunday for the San Francisco 49ers ',
#  "CRAZY! A 14 yr old child who can't pay a small fine to a court can end up in an adult prison instead.  ",
#  "Me when it's time to code-switch for an interview:    ",
#  's/o to this literal icon ',
#  "[RECORD SCRATCH] [FREEZE FRAME]  AMERICA: Yep, that's me. You're probably wondering how I got myself into this. ",
#  "'Mommy,am I gonna die':Mom of 5year-old Ohio girl accidently shot by cop trying to subdue dog says officer left scene ",
#  ' was accidentally shot by a Columbus police officer who was trying to subdue a charging dog  ',
#  'Video Clears Man (M. Jeter) and Cops are Charged!  WATCH ',
#  'LMAO  ',
#  'lol ',
#  'damn straight ',
#  ' beat up and seem to break black teens arm for getting money out of his ATM ',
#  'yes. absolutely right bro ',
#  "Don't take NO for an answer. Agitate against white supremacy.  ",
#  'bastards ',
#  'Video shows  tasing a bloody, restrained  in the testicles before his death.  ',
#  ' Runs Down Suspect with Truck,Beats & Tasers him in the Head, Dept Says it was an Accident   ',
#  'Palestinian Child Bleeds to Death while Israeli Police&Civilians Watch, Shouting Insults    ',
#  'Cleveland  officer charged with abduction appears in court    ',
#  '2 deputies fired after fellow deputy shot in sting     ',
#  'NY Police Say Viral Video Showing  Choking Man Was Actually Life Saving Attempt there was no f*ckin reason ',
#  'Former Cleveland  chief awarded his service      ',
#  "' totally bro. fat pigs'",
#  'lil black girl is runnin from police officcer ',
#  '3 charts that show police forces still have a  problem     ',
#  "'  awful gif image dudes'",
#  'Smart kid! ',
#  "' Since the childhood she has to fear'",
#  "' yes. black children to grow up in fear. why the f*ck can't it stop'",
#  "' She's learning early to run away, from a Brutal Murderer!'",
#  "' Our Government, Supreme Court, Congress, and the DOJ are intertwined in Bigotry and Racism, the DOJ commands Brutal police force!'",
#  "'  awful scene'",
#  'Photo: Badge privilege\xa0     \xa0\xa0 ',
#  'Nicholas Kristof:Gun deaths more numerous for preschoolers than police     ',
#  'Border Patrol agent indicted in 2012 fatal shooting    ',
#  ' Taser kneeling  councilman in  town where  was arrested   ',
#  'Fairfax tickets cars for needing inspection — while they wait for inspections    ',
#  'Cleveland  Justified in Killing 12-Year-Old , Reports State    ',
#  'Councilman Tasered in  over Crime of—Actually There Wasn’t Even a     ',
#  'Me lol ',
#  "when I'm extremely high ",
#  'Me asking for        ',
#  "When I hear people say there's no racism in       ",
#  '       ',
#  'Dank Pineapple Express Nugs � ',
#  'who is the most pretty girls      ',
#  '     ',
#  '      ',
#  'Miss Fantasy       ',
#  'smoke it     ',
#  '     ',
#  'I know when that hotline bling That can only mean one thing �   ',
#  "' hey c'mon I think snickers isn't the worst desicion'",
#  'Mix ',
#  '       ',
#  'lol i cant ��     ',
#  'True     ',
#  'for real ',
#  'for real tho ���dudes I love you all  ������ ',
#  'who can relate to this? ����     ',
#  ' is what we seek       ',
#  ' “ White People Be Like”...     ',
#  "When you get the cops called because a 'Hispanic-looking woman & black man with a suspicious white truck & camera' are near a school � ",
#  'Colin Kaepernick wore pig socks, took a knee in protest, picked out his fro, did NOT back down, spoke his mind and then got his job back: ',
#  '⚡ Report: Actor Tommy Ford has died at 52   ',
#  'Yes, they are. Yes, they are. Yes, they do. ',
#  'Institutionalize racism at its best ',
#  'Transgender woman found dead in Cleveland with plastic bag around head ',
#  'R.I.P. ',
#  "LMAOOOOO  ON  I'M DEADASS CRYING RIGHT NOW ",
#  "Why isn't this all over twitter?         ",
#  'Daughter calls 911 to help suicidal mother,   her by mistake, then  her mom ',
#  "'         ",
#  'so yall niggas ain’t fuckin with this cake i baked ',
#  '17 y/o   was killed by a  after flashing his brights. This is depressing  ',
#  "' fucking bangbangers smh'",
#  'This Man survived a  and became an activist    ',
#  ' has created a corrosion in the justice system of our country We got to fix it ',
#  '  officer clearly stalking man by reason of intimidation tactics. rediculous!  ',
#  '✊�✊�✊� ',
#  'HE SAID  AND I APPROVE THIS MESSAGE!     ',
#  'It is NOW     ',
#  '  He has got my vote ',
#  "' Then I suppose this will have to do until then. ✊⚖☮☯✏ United we stand. ",
#  '‘CUZ THERE’S NO “BUT” IN DIS, BITCH   ',
#  'California starts new Law that says  must get a  2 use   It Works  ',
#  "' oh boy U looooove to hear compliments! Good thing I love 2 say em. Youre DOPE! ������'",
#  "' oh boy U looooove to hear compliments! Good thing I love 2 say em. Youre DOPE! ������'",
#  'Our people are dying...We must unite',
#  ' Missing/Murdered 235 cases of  Girls! ',
#  'Every time something Bad happens all people want is the  Today it is a rarity   ',
#  'Police STILL stonewalling about the killing of . October 14, 2015   ',
#  'no way dude ',
#  "'  THE POLICE IS RUNNING OUT OF FUCKS TO GIVE ABOUT CITIZEN'S LIVES!'",
#  "How search interest in  spiked during last night's debate: ",
#  'During the "talking" period and you realize she might be the other half you been missing: ',
#  "' this is usually triggered by music, related to those memories'",
#  "Where do all those 'fired'  go?  Police welcomes them with open arms  ",
#  'Son of a bitch ',
#  ' teens age 15-19 are 21 times more likely to be shot by police than whites are.  ',
#  'Help Iowa  as a campaign organizer!  Apply here: ',
#  "'  Bae, Its not you, Its me.....'",
#  '"According to the FBI’s Uniform Crime Report, white Americans are responsible for 69.3 percent of crime." ',
#  '69 � ',
#  "We're not talking about a murder mystery here ",
#  'Oh shit. I totally forgot about this. Watch: Michelle Obama Slams Hillary  ',
#  'Woman accused of open container but bodycam shows cop saying "you have an attitude, you\'re under arrest too then"  ',
#  'So... my cousin is trying to teach his cat to use the toilet "to save on kitty litter"  My dude, WTF is this shit?!?  I gotta get my own apt ',
#  '90% rapes go unreported Of those reported, only 30% go to trial Of those who faced trial, only 1/3 were jailed   ',
#  "Come on y'all, spread the word. ",
#  "' I always tell people about their screwed hoods and unzipped bags, just reserving a table in heaven for myself ☺️'",
#  'Ima spray some on you ',
#  'mmmmOh my God � ',
#  'this truth tea is scalding ',
#  'Bae       ',
#  'Sixth Tucson police employee terminated in prostitution probe ',
#  'Resisting charge dropped against woman in heated traffic stop w/ deputy   It works ',
#  ':  Ignore it… and it won’t go away!  ',
#  'and N.W.A. Playing    ',
#  'when your mom comes home and there’s a fork in the sink and you ain’t take that damn chicken out the freezer ',
#  'She’s beauty, she’s grace   She puts panties on her face ',
#  'oh shi....    ',
#  'Bae:  ',
#  'YOU: ',
#  " band together, use  2 help convicted CHILDMOLESTOR Cop get lighter sentence 'serve and protect' ",
#  ' Officer violently arrests, injures cyclist 4 not wearing a helmet video: ',
#  'Alabama man shuts down cops who questioned him for jogging  — and it’s perfect ����  ',
#  'No justice. No peace.  ',
#  'How  comes up with his ideas  ',
#  'current mood: irritatingly sad ',
#  '& every time u hear a black person speaking as loud as possible,sb is going 2 say:‘Look at those niggers over there’ ',
#  "' Trump is always on the wrong side of the argument smh'",
#  'I present this w/ no comments ',
#  'IS THIS FOR REAL?      ',
#  'This shit is NOT OK, Officer! Tackling 14 y/o non-violent  w/ a chokehold? Bad move, Officer! ',
#  '  ',
#  'All of them ',
#  'LIT     ',
#  ' officer slamming 15 y/o  at William Tolman High School in Pawtucket  ',
#  ' Destroyed birth certificates, medication, IDs in  homeless raid more here: ',
#  'State makes it legal to  in self-defense if they violate your rights.  is That the solution? watcha think? ',
#  "' Flag down Flagrant Unsportsmanlike Conduct Lifetime Ejection From the Team Additional Sanctions To Follow ",
#  'But thats gay  (ƃuᴉʞoɾ ɯ,I) ',
#  "' covering murder with homicide... thats not math where two  negatives make positive'",
#  "' but fuck yeah, I'll shoot a cop, who is trying to take me down 4 nothin'",
#  "Jus' want to be clear:  simply means that the lives of African-Americans matter. That’s all. ",
#  'When I meet her vs. When I meet her parents ',
#  ' Stands With MU   ',
#  ' won the  in 1964. This Wednesday (14th) is a day of commemoration of his achievement. ',
#  'That. Was. Awesome.      ',
#  'That. Was. Awesome.     ',
#  "'  Trump never has stated, which side of the Black lives Matter debate he is on. ",
#  'still the most crusial issue above all in the United States   ',
#  'If I die in police custody, I didn’t commit suicide.',
#  " officers' names still secret 3 years after  ",
#  ' ',
#  '�� ',
#  '"Bye Roberta" is the new "Bye Felicia" ✌� ',
#  'We need more good cops to step up and do the right thing. ',
#  'Here’s       ',
#  "'  This we cover each other asses crap must end & not just police  Dr.'s/Dr.'s Lawyers/Lawyers Christians/Christians Priests/Priests'",
#  ' Officer guilty of felony 4 lying about arrest of  photographer ',
#  'ALL  are scum bags and get exactly what they deserve! everyone HATES cops EVERYONE… ever wonder why?  ',
#  "You  have a power which is backed by societal trust.And you're constantly losing that trust!  ",
#  "Stealing this pic.  Thanks! RT : Almost tweeted something really filthy, but it's 6:58 am. ",
#  'We Need Cops With People Skills! ',
#  '  ',
#  " that's my dream ",
#  'Start a segway gang.   won’t be able to infiltrate it ',
#  "'  that's my dream'",
#  "'  that's my dream ",
#  '    ',
#  ' ',
#  'If ever you needed proof that police are there for revenue collection ONLY, here it is.   ',
#  'I wonder how  found the strength to think about other people rather than yourself, I’m not sure if I would ',
#  'Man files civil rights suit against DPD officers. This is LOUD! Read the story: ',
#  ' police will always understate their problems and violence if reporting it is optional ',
#  "'  Man 1 Depraved indifference to human life  8 & 1/2 to Life Because it was a 911 dispatcher on duty. NO Parole. AAARRRRRRRRRGGGGGG'",
#  'Because  is still alive       ',
#  'LMAO no humor ',
#  'I’m just going to leave this right here. ',
#  'SMH ���� ',
#  'So gorgeous.     ',
#  '       ',
#  '    ',
#  'We are the one.We all are power      ',
#  'So Jesus just gonna leave His slides?   ',
#  '         ',
#  'oh no  ',
#  "' ya think his feet have to be dirty than? LMAO'",
#  'Courtesy of ',
#  'In case u fail to see how ridiculous u sound saying unarmed people somehow caused their own murder w/their questions ',
#  'I’m dying! Haha     ',
#  "White people can argue reverse racism day in and day out. And I'ma keep shooting back ",
#  "' I'm just copyin their behavior'",
#  "' or you think I'ma rasist bae???'",
#  "' let me know the thing bae.don't be silent'",
#  'Keep up the important work MUST SEEEE:   ',
#  "' so now i'm confused'",
#  "' ok bae  keep calm'",
#  'Bruh lolol     ',
#  "' My brother locked his door, ONCE The next day all bedroom doors were gone Dad: I sold them Buy your own damn doors Doorless a week'",
#  '17 Powerful Quotes About  In     ',
#  'Behind every color skin is a human just like you and me. Please be respectful.   ',
#  'Join us on the albino campaign JE SUIS ALBINOS Please say stop killing albinos on your profile now  ',
#  ' underreported serious assaults, skewing  for 8 years (!!!) whooooooops ',
#  "' found you from tumblr, MY GOD�. If you don't get em which yo baddazz✊� ",
#  'Man Freed 25 Years After Police tortured him Into a false confession whooops, a broken life ',
#  'Two Brooklyn  arrested a man sitting in the passenger seat of the vehicle, accusing him of damaging their car ',
#  'Pay $250 Fine or Patrol Car Gets Towed, Illegally Parked  Gets a Taste of  Extortion  ',
#  ' Band Together, Use Blue Privilege to Help Convicted Child Molester Cop Get Lighter Sentence  ',
#  'Officer Previously Arrested For Attempted Murder, Arrested Again For Choking Girlfriend ',
#  'Man Freed 25Years After Police Tortured Him Into A False Confession    ',
#  ' and  among those missing from FBI record of  killings    ',
#  "'   Time to start kicking these donkeys in deep depressions OUT of the police forces across this country. ",
#  ' Officer Guilty Of Felony For Lying About Arrest Of NY Times Photographer     ',
#  ' underreported serious assaults, skewing crime stats for 8 years     ',
#  'Virginia cops try to bully family farm over  sign but ignite furious backlash instead  ',
#  'Remember innocent child sufferings ',
#  'thank you! ',
#  'We hear about  on the radio every day. It is like news about show business   ',
#  'This is what happened when  was asked if  or  during the debate ',
#  '2 Chicago  under investigation for sex trafficking 14y.o. girl     ',
#  'JOE ARPAIO "FAILED IN HIS RESPONSIBILITY,"SAYS PRIVATE INVESTIGATOR    ',
#  'Police union head calls for boycott of pumpkin patch over  sign   ',
#  'Michael Wood, ex- officer, tweets about alleged      ',
#  'Settlement Reached After Witnesses Say Cop Broke Mans Jaw With Kick      ',
#  'Resisting charge dropped against woman in heated traffic stop with deputy     ',
#  'war on cops is the best way to solve the problem      ',
#  "'  Mandatory sentencing. ANY Law Enforcement Officer found guilty of a crime gets double normal jail time. ",
#  "'  Mr Carruthers Sir. Time to retire.   As G'ma would say You stepped in it You don't get to come back inside till the stink is gone'",
#  "'  Of all people, Law Enforcment should know better Call  Congress Insist! Remind them.... I VOTE.... ALL MY FRIENDS VOTE. Thank you'",
#  "' plug in baby'",
#  '“F*** your breath!” - Cops curse unarmed man as he dies after they shot him ',
#  'A man says he was left with broken bones and bruising from an encounter with the police    ',
#  '2 deputies charged with killing a college student in a jail cell have been acquitted   ',
#  'why the police still exists in America if It carries more damage than all criminals gather together? ',
#  "' so we must fight 'em'",
#  'we will never forget ',
#  "' I don't wanna sleep honey'",
#  "' I don't wanna sleap honey'",
#  "If you're looking for a Netlix documentary to watch tonight, make it this one about sloths ",
#  "' I still remember when his cousin reached out to us so long ago. It's thankfully getting good coverage now.'",
#  "I'm told that at least 8 Tolman High School students in Pawtucket have been arrested for protesting the police brutality at their school.",
#  '40% of homes with police in them have reported domestic violence.  The national average is 10%  NFL average is 6%.   ',
#  "Just give me the one in the red dress and I'll be happy.  ",
#  'Mood ��  ',
#  'Deputies Acquitted In Killing Of Inmate      ',
#  'Florida SWAT team halts stand-off to allow white couple to finish having sex    ',
#  'Hidden Camera Gets   Sentenced to Prison for Beating & Terrorizing Innocent People  ',
#  'Why Did A  Shoot Robert Chambers In The Head? Disarm the Police!     ',
#  "California deputy caught on live TV First there're two cops  beating unarmed   than one more monster ",
#  'hey ya all girls wanna be w/us  lmao  ',
#  'Yup. ',
#  'My friend said you got to get a bitch with a big ol meaty booty. They keep you warm',
#  'From Chocolate City to Latte City: Being  in the new D.C.     ',
#  ' sheriff furious Obama took his military tank away: People will die because of this decision ',
#  "Cyclist Bangs On  Officer's SUV in Bike Lane Dispute, Gets Handcuffed    ",
#  'Palm Beach Sheriff’s Office Loses Cellphone, Laptop of Cop Who Shot and Killed Seth Adams    ',
#  'Texas Man Plays “Fuck the ” for Cops Who Pulled Him Over for Retaliatory Purposes While Remaining Silent ',
#  'one more case of   &       ',
#  ' on a high school student      ',
#  'Incident between Round Rock, PD & High School Student Caught on Camera    ',
#  "' Strangely Hispanics r counted twice. Included n White census & a Hispanic category. Y count 1 group twice? Atlanta is still Black.'",
#  "' Ur on it tonight! He's an idiot. That's not his tank. He is a replaceable employee. Our tax $'s paid 4 that tank. Citizens own it.'",
#  'Want to see if a police officer has a history of misconduct?These states make it hard   ',
#  ' who shot  used ‘excessive ’ before, lawsuit says   ',
#  'CORRUPT COP GETS MAD WHEN COPWATCH TRIES TO FILE A COMPLAINT AGAINST A COP     ',
#  'Woman Shot in Face by Police Gets $20K     ',
#  'How many people have been killed by police officers in America?     ',
#  'HELP US TRACK IMMIGRANTS KILLED BY       ',
#  "' ",
#  "'    may be its just a guy in Halloween costume?'",
#  "'  She was nice btw'",
#  "and they blame THE TRAFFIC SYSTEM. which they say 'allow suspects to move at greater speeds and make wild turns '��� ",
#  "Im not feeling it today. Kinda sick of it today.  All whats left 4 me 's  2 pray. 'Dont let em take me away' ",
#  "'  Poison!'",
#  "'   thats what you said to your parents?'",
#  "My daddy say i'm geekin' My momma say I'm geekin & when I come around I'm barely fucking speaking ",
#  "'   wow youre a whore! (ƃuᴉʞoɾ)'",
#  "' Doubts? DOUBTS? he is a MAD MAN. I have a permanent confidence that this man is EVIL'",
#  "' she lost it a long time ago.'",
#  'Video shows Officer treating a homeless person 4 NO reason. Now the homeless guy is in jail!  ',
#  'SLAP THAT BITCH ',
#  "' Spit on it'",
#  "' We just feeling it'",
#  ' this shit ',
#  'I NEED TO HAVE A RIGHT TO DEFEND MYSELF FROM POLICE  2k15 Edition ',
#  'MUST READ ',
#  'Rasheed Wallace is furious about Flint.  And he wants you to know the truth. ',
#  'Google it. Its true. ',
#  ' though ',
#  'Oh Shit  ',
#  'They learned it  ',
#  "I'll never tell anyone to not vote, but I will ask you what's the point of it. ",
#  "' stop shaming sex workers— especially if you're a beneficiary of their labor'",
#  'Clinton takes money from big oil bundlers.  ',
#  'Chicago probably needs it the most   ',
#  '7 dirty tricks  Officers will use to get what they want from u.   ',
#  'If your posting smoking pics or vids you better have one rolled when I see you.',
#  'beautiful ',
#  'sure, bae      ',
#  'Queen!        ',
#  "I don't wanna HAVE to have that TALK w/ my kids. ",
#  'Why dafuq he smiling? sick bastard      ',
#  "' ",
#  'spread it  ',
#  "' no doubt'",
#  "'- That phrase on the side of your vehicle, sir?  - Oh, Just a PR slogan. ",
#  "' 50 shades of gay huh?'",
#  "' swim good?'",
#  'Some letters wore off  To Protect and Serve... Wealthy White People ',
#  "' uoeno'",
#  'Think №police can’t use illegally bbtained  against u? Think again. ',
#  "'   Youre doing a great job, Shaun. Massive support from StLouis!  luv ya!'",
#  "We're living in a 21st century,    ",
#  'Anyone in the Joliet IL area, be wary of racist Officer Michael Pauly. Record your encounter.  ',
#  'Its really that simple ',
#  "' ",
#  'fuck that older brother is in trooooooouble ',
#  "They are also mostly white, so this doesn't impress me at all. ",
#  'What we desperately need is a right 2 defend ourslves from    is tryna do a complete opposite  ',
#  'Ever since I left the city ',
#  ' is now coming 4 our guns Whatever she tryna do - we need THE OPPOSITE.  ',
#  '    Rest in power. ',
#  " Mayor:  backlash makes officers 'fetal'  ",
#  "' Bubba the Racist'",
#  ' freaks out and assaults woman 4 taking a tylenol  This is ridiculouis  ',
#  'Woke Af   ',
#  'Shots fired! incompetency is outrageous. Amazing footage WATCH:  ',
#  'Oh Hell no !!! ',
#  'Momma always said to never start a fight, but always be the one to finish it. Thats why im in the movement ',
#  '*Drops mic*   ��� ',
#  'Black City councilman tasered by .officer was also involved in ’s arrest ',
#  'I APPROVE THIS MESSAGE     ',
#  '4 the 2nd time in 6 years, the   constable has found himself under arrest ',
#  'one in a million wanted justice and would have to pay for it ',
#  "Can't say no s**t when I bring that bible quotes!  I love all of these people   ",
#  'Now Facebook lets you order food from restaurants � or buy movie tickets � directly from its pages. ',
#  'I want to experience this ',
#  'Possibly the saddest, most heart breaking "This exhibit is currently out of order" sign ever!! ',
#  'Honestly thought someone was just super excited about the drinks machine ',
#  '"fuck niggers" This is America In 2016. ',
#  'The 2016 news photo of the year contest has closed ',
#  'El Chapo judge gunned down in front of his house in Mexico\xa0 ',
#  'They really not as smart as they try to come off. ',
#  'its that time of year ',
#  'lmao ',
#  'When they talk bout banning guns they bring  shooting But what bout  terror on Black Ppl We NEED  2 protect our lives',
#  'Today I’m so sick of thinking about race, but it’s the first thing on my mind ‘cause it’s the first thing on my face ',
#  'Lit artwork via   ',
#  'Palm Beach Officer Who Killed  Wearing Plain Clothes And Driving Unmarked Car ',
#  "'  Woke AF'",
#  "'    ",
#  'I give a fuck about MY LIFE do you? ',
#  "'     I don't usually political art but here (could be better I admit) ",
#  "' whats wrong about it?'",
#  "' Clear themselves... ugh... theyre never gonna be clean'",
#  "Will there ever be any  4  in this country?!  I'm losing faith...  ",
#  "' come and get these blue pigs. I'll do it myself for all of us '",
#  "Detective Can't Shake Hidden Camera Claims      ",
#  'Maryland police officer accused of biting testicles has left department     ',
#  "' Thank you 2!'",
#  "Mass. town giving 'tickets' for good behavior       ",
#  'Homan Square revealed:How Chicago police ‘disappeared’ 7,000 ppl    ',
#  'Florida  kill  man who pulled over with car trouble-and then refuse to tell family why   ',
#  'The  Is Using Mobile X-Ray Vans to Spy on Unknown Target     ',
#  'Police Kill Man Who Took Officer’s Gun During Struggle In Downtown     ',
#  'hey right  ',
#  '  Have Disappeared More than 7,000 Ppl at Secret Interrogation Warehouse   ',
#  " was dancin' on the roof while it was a fire   are takin' him on a gurney Respect bro!  ",
#  'Nina Simone to the South African rap game when their biggest supporters are under siege.  ',
#  'Never compromise for anything less than you deserve.',
#  'lmao God  ',
#  'LOL so  ',
#  'oh boo I want you to know yall not alone bae  not alone  w/love ',
#  "'     '",
#  'Police arrest 23 as students protest tuition fee-hike plan       ',
#  'This is straight up   ',
#  '“The white man’s happiness cannot be purchased by the  man’s misery.” -Frederick Douglass  ',
#  'Words can be weapons by Hidden Foo    ',
#  'Truth about slavery ',
#  'I have a dream my little children will 1 day live in a nation where they wont be judged by the color of their skin, but by their character',
#  ' Shot In The Head.For the second time this month a black transgender woman has been killed   ',
#  'Statistics speak for themselves       ',
#  "' common sense is great but each of your fam w/common sense is boring no?'",
#  "' hey boopsy i want you to be more polite ugh  '",
#  'How I feel about starting my work on a Monday  ',
#  'LMAO ',
#  "' LOE'",
#  "' LOVE'",
#  "' SO TRUE'",
#  'FRESH AF ',
#  "' YASSS'",
#  'Chicago Mayor blames viral  videos for rising murder numbers ...wait what? ',
#  'You know where it is going ',
#  "'  it works'",
#  "Thats the shit I don't like     ",
#  "I'm dead      ",
#  '  have “Disappeared” more than 7k people at secret interrogation warehouse ',
#  "'  a black guy!'",
#  'JOE ARPAIO USES FAKE RECALL TO FUNDRAISE ',
#  'Star Wars: : Watch the new trailer ',
#  'Police Officer totally provoking a black man he pulled over, escalating situation but gets no response.   ',
#  'Drake is on FLEEEEEK w/ his new video 4 HotlineBling watch here: ',
#  'Video:"Police officer" in SUV hits cyclist, threatens to arrest.   ',
#  'NYPD officer indicted for allegedly stealing home ownership from dead woman’s family    ',
#  'After his car broke down, Florida church drummer shot and killed by plainclothes officer   ',
#  'Florida Cop Literally Just Shot Unarmed  W/His Hands Up, Begging Not To Be Shot   ',
#  'Cop Runs Down Suspect with Truck, Beats Him, Tasers Him, Then Says It Was All An ‘Accident’    ',
#  'Garner chief  graffiti cowardly a hate crime      ',
#  'Pastor: I held my son while Sacramento deputy shot him to death    ',
#  ' Mayor blames viral  brutality videos for rising murder numbers   ',
#  "Homan Square revealed: how Chicago  'disappeared' 7,000 people     ",
#  'A Turkish police officer pointed a gun at the head of a journalist  is all around    ',
#  'Racial Profiling is Real and So Are Its Lingering Effects ',
#  "' share it! '",
#  '7 ways  break the law, use threats, or lie to get what they want     ',
#  '7 ways  break the law, use threats, or lie to get what they want     ',
#  'BOOST ',
#  'Just lemme know why the fuck  ',
#  'Important AF!!! ',
#  "Video: Metro transit police detained and arrested a teenager after she wouldn't throw away her bag of chips. ",
#  'The U.S. constitution has clearly been violated by these MFs. ',
#  'It’s sad and unpleasant times we live in when people have to ride around with messages painted on their cars..   ',
#  'SATELLITE FEED CUT AS SOON AS CONGRESSMAN MENTIONS WIKILEAKS ON CNN  ',
#  'People: if we just be kind and loving to those who want us dead they will eventually affirm our humanity  History: ',
#  "I always feel blindsided and personally attacked when I'm trying to carry out convos via text and they suddenly call me. ",
#  'I had an ancestor who stole the "settler\'s" hearts so they stole her from her family. GENEALOGY = a decidedly white hobby ',
#  "I won't say who it is.But I'm very thankful      ",
#  "' he was harmful to all peace. you know all the troubles inflicted by cops'",
#  "' Cop shot 7 year old  n the head as she slept he also killed the dog. No jail. Did he harm ppl 2? Was Animal cruelty called?'",
#  'Former H.S.  Shot and Killed in Virginia After Allegedly Jumping Into Off-Duty  Officer’s Car ',
#  'Federal court tells the DEA to stop harassing medical marijuana providers    ',
#  " teen's family files federal lawsuit over fatal traffic-stop shooting   ",
#  '$2.25 million settlement reached in Painesville police Taser incident   ',
#  'Is that guy carrying a gun?     ',
#  " fired after failing lie detector test as he was questioned over the disappearance of his brother's girlfriend ",
#  'Tenn. lawmakers urged to keep asset forfeiture law intact    ',
#  'DEMON POSSESSED ARGENTINIAN COP FAKE CAR ACCIDENT AND INJURY: THERE IS NO SUCH THING AS A GOOD COP ',
#  ' at the       ',
#  ' 17, 1968: Olympic protestors stripped of their medals ',
#  'fists in the air      ',
#  '“Hold your head up little man you’re a king!”-Nas     ',
#  "For out Gov't ",
#  '',
#  'in  it is    ',
#  'This is the society that I live in. No humanity…no  ',
#  "' lemme know how can we call him officer? It's total shame. Who to call when police murders'",
#  '  ',
#  ' ',
#  'RIP  ',
#  'more than 920 people were killed by police in 2015 …just in LA',
#  '.  everytime you post this I realy proud of us ',
#  '.  I dream of   I dream of race would be nothing',
#  'nice bro   ',
#  '.  Just thank you are with us.   movement is perfect. Happy to be in',
#  "'  yes man.it is we must be strong'",
#  '.  they hurt us every time they are near by. cops must be more polite to every citizen independently of race and skin colour',
#  '.   say if I can help Shaun',
#  "' thanx bro! you're welcome 2'",
#  '.   I just want America to let justice in. That is decision',
#  "'  I see your point.and I'm agree. Totally'",
#  'cute ',
#  "'        Life isn't about what you earn.'",
#  'Ain’t nothin wrong with a lil bit of chocolat ',
#  'Is Cleveland In a State of Ignorance?     ',
#  ' Protesters Attack Trump Supporters ➠ Trump Supporters Blamed For Violence ',
#  'Queen ',
#  'Do you prefer miracle whip ? ',
#  'LMAOOO RT : Wale says Meek bought a pencil to a gunfight, a piece of paper and tried to paper cut him to death ',
#  'Agawam woman accidentally shot in face by police files $1.5 million suit in federal court ',
#  'Dog shot by Florida City police officer Animal rescue volunteer says dog shot 3 times in head ',
#  'Animal purposely run over, shot in Collingwood; resident believes animal his dog ',
#  'Owner of dog shot, killed by police files lawsuit for $2 million  ',
#  'NBAer in 1Oak club brawl suing cops and city for $50M ',
#  'Soldier Finds His Former Hero Service Dog Being Abused by a Deputy who Won’t Give Him Back   ',
#  'Drug war is a scam,  is a problem and it’s time to stand up: ‘Unfiltered’ GA $cop tells it like it is  ',
#  'Florida  Murders Pet Dog 3 Feet From Terrified Homeowners in Incident Caught on Video    ',
#  'Florida deputies arrest 9 y.o. boy and post mugshot online, prompting criticism and cheers   ',
#  '  stole 4-story townhouse, DA says        ',
#  'mah fam ',
#  'love that       ',
#  'lemme be     ',
#  'staff ',
#  'Yes     ',
#  'nice art ',
#  'True bro ',
#  'Failed  ',
#  "RIP  Officer Randolph Holder  we never forget the other cops'  ",
#  '"4 police officers murdered in the last 11 months that\'s about as bad as it gets."   Worse than 956 killed by police ',
#  'perfect one ',
#  'CURRY REALLY WILDIN ON THESE NIGGAS ',
#  "Rudy Giuliani looks like he hasn't laughed at a joke since the 1920s so I get why he didn't find that one funny.  ",
#  '',
#  'Artist Sean Hassett created this piece titled “I Am You”, and thought it was so powerful I had to share. Deep.  ',
#  'ʷʰʸ\xa0 \xa0 \xa0 \xa0 ʷʰʸ \xa0 \xa0 \xa0 ʷʰʸ\xa0 \xa0\xa0 \xa0 ʷʰʸ \xa0 \xa0 ʷʰʸ \xa0 \xa0 ʷʰʸ \xa0 \xa0 ʷʰʸ \xa0 ʷʰʸ \xa0 why am i an asshole\xa0\xa0 ʷʰʸ \xa0\xa0 \xa0 \xa0 \xa0 \xa0 \xa0 ʷʰʸ\xa0 \xa0 \xa0 \xa0 \xa0 \xa0 ʷʰʸ',
#  'Reporter confronts white man who calls him the n-word, slave A Virginia man verbally harassed Steve Crump near Mother Emanuel Church. ',
#  'I wish I had teachers like that✊� 2,000 Seattle teachers showed up for work in  shirts. ',
#  "It's official, at 18 years old I co-own B & B's Ice Cream with my parents. Located at 8236 s Racine. COME SUPPORT A BLACK OWNED BUSINESS ",
#  '"Please hold your applause until all of the graduates names have been called"  Black parents: ',
#  'Anthem singer at Heat-76ers game kneels during performance   ',
#  'shit ',
#  'Young Morgan Freeman look like old Morgan Freeman dressed up like young Morgan Freeman ',
#  'Donald Trump has said he wants to bans Muslims, but Hillary Clinton has already bombed Muslims. ',
#  'If he didn’t say he was “live on facebook”, he would have been arrested and assaulted ',
#  'She is gorgeous ',
#  'lmao ',
#  'Little Did He Know ',
#  'The fuck wrong with them? ',
#  'Hey !  ',
#  "'        '",
#  'Hey !  ',
#  'Hey !  ',
#  'Me: damn I have to much to do  Me for 57 minutes: ',
#  'We have to stand up for black children and be prepared to protect them. ',
#  'NAACP demands federal probe after noose allegedly put on black student ',
#  'SOLANGE pro-black and her music has a clear, unapologetic message ',
#  "Students from Steinert High School � this how y'all act? Someone find some  @'s ",
#  'I NEED this! ',
#  "How y'all look at teenage girls when they have an abortion vs how y'all look at her if she keeps the baby ",
#  'Lynching of Thomas Shipp and Abram Smith and a mural dedicated to the white Lynch mob in an urban community hidden in plain sight. ',
#  'Nah, we gotta get this camera off the market. � ',
#  'When your mom show you something "funny" on facebook that you saw on twitter 2 years ago ',
#  'First black, female comic book store owner on the East Coast to appear on variant cover of "Invincible Iron Man ." ',
#  'I don’t think white supremacists have to hide very much in the police. ',
#  'Gucci Mane, ladies and gentlemen. This might be the greatest thing that has ever happened to me. ',
#  'Black high school football player in Mississippi says white students put noose around his neck during practice. ',
#  'How fucking in a motherfucker business to notice four fucking flakes on a dude dashboard. These cops ain’t prioritizing at all ',
#  '� ',
#  'Niya was arrested for challenging police abuse in school. Her story is an important part of our struggle. ',
#  "Then: Me: I want McDonald's  Mom: Do you have McDonald's money?  Now: Mom: I want grandkids  Me: Do you have grandkids money??",
#  'Why Pop Culture Just Can’t Deal With Black Male Sexuality ',
#  'It\'s hard to believe that there are "teachers" like this one  White Teacher Told Blck Students That White People Are More Superior Than Them ',
#  'An affirmative action bake sale from white students at the University of Texas. They actually think they have it harder b/c they are white. ',
#  'Seattle police officer caught lying in the performance of her duties keeps job, raise and PROMOTION thanks to police union ‘agreement’ ',
#  'I respect black women for putting up with daily disrespect. I can’t even imagine that shit',
#  'GTA San Andreas is 12 years old today. Is this the best GTA game or no � ',
#  'But who cares about facts, right? The cops FEEL there is a war being waged against them. ',
#  'Wake yo ass up before you be late to school��� ',
#  'Nigga is that Anne Hathaway? RT : Dominicans are out of control lmaoo ',
#  '"HARASSED BY POLICE FOR MY HAIR!!"  ',
#  'She was supposed to sing the national anthem – but then they saw her shirt. ',
#  'Haiti President Calls Clinton Thieve Who Should Be In Jail ',
#  'Oh really? So how are the falsely convicted prisoners and their families going to be compensated? ',
#  'A  of Sandra Bland using  of black woman or feminine presenting people. ',
#  ...]

# %%
wordcloud = WordCloud(background_color="white",width=1000, height=860, margin=2).generate(' '.join(content))
plt.imshow(wordcloud)
plt.axis("off")
plt.show()

# %%
wordcloud.to_file('content_without_hashtags_at.png')
